# %%
import pandas as pd
pd.set_option('display.max_rows', 100)
import re
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from datetime import datetime
import numpy as np

# %%
news = pd.read_csv('bitcoin_news.csv')
news.head()
# Out:
#                         Date  \
# 0  2018-09-04T08:00:04-04:00
# 1  2018-08-02T17:15:26-04:00
# 2  2018-09-05T01:15:31-04:00
# 3  2018-08-04T04:55:54-04:00
# 4  2018-08-06T03:45:21-04:00
#
#                                              Summary  \
# 0  The Tuesday edition of our daily roundup is ja...
# 1  Japan’s SBI Group is reportedly planning to cr...
# 2  Non-custodial crypto trading platform Shapeshi...
# 3  Intercontinental Exchange (ICE), owner of argu...
# 4  Thailand’s central bank has announced the rule...
#
#                                                 Tags  \
# 0  ATM,Blockchain,Brave,Deutsche Börse,Ethereum,G...
# 1  ATM,BCH,Bitcoin,bitcoin cash,BTC,BTM,coin asse...
# 2  AML,anti-money laundering,Bitcoin,BTC,crypto,C...
# 3  401k,Bitcoin,Boston Consulting Group,Canada,CF...
# 4  bank of thailand,banks,Bitcoin,Bot,BTC,commerc...
#
#                                                Title
# 0  The Daily: Wirex Adds Ethereum, Deutsche Börse...
# 1  SBI Plans Derivatives Platform, Huobi Eyes 30%...
# 2  Shapeshift Moves to Membership Model Requiring...
# 3  NYSE Owner: Bitcoin Should Be in Retirement Fu...
# 4  Bank of Thailand Green-Lights Financial Compan...

# %%
news['Datetime'] = list(map(lambda x: datetime.strptime(x[0:10],'%Y-%m-%d'), news['Date']))
news['Year'] = list(map(lambda x: str(datetime.strptime(x[0:10],'%Y-%m-%d').year).zfill(4), news['Date']))
news['Month'] = list(map(lambda x: str(datetime.strptime(x[0:10],'%Y-%m-%d').month).zfill(2), news['Date']))
news['Day'] = list(map(lambda x: str(datetime.strptime(x[0:10],'%Y-%m-%d').day).zfill(2), news['Date']))
news['Numerical_date'] = news['Year'] + news['Month'] + news['Day']
news['Numerical_date'] = [int(i) for i in news['Numerical_date']]
news['Textchunk'] = news['Summary'] + str(' ') + news['Title']
news.head()
# Out:
#                         Date  \
# 0  2018-09-04T08:00:04-04:00
# 1  2018-08-02T17:15:26-04:00
# 2  2018-09-05T01:15:31-04:00
# 3  2018-08-04T04:55:54-04:00
# 4  2018-08-06T03:45:21-04:00
#
#                                              Summary  \
# 0  The Tuesday edition of our daily roundup is ja...
# 1  Japan’s SBI Group is reportedly planning to cr...
# 2  Non-custodial crypto trading platform Shapeshi...
# 3  Intercontinental Exchange (ICE), owner of argu...
# 4  Thailand’s central bank has announced the rule...
#
#                                                 Tags  \
# 0  ATM,Blockchain,Brave,Deutsche Börse,Ethereum,G...
# 1  ATM,BCH,Bitcoin,bitcoin cash,BTC,BTM,coin asse...
# 2  AML,anti-money laundering,Bitcoin,BTC,crypto,C...
# 3  401k,Bitcoin,Boston Consulting Group,Canada,CF...
# 4  bank of thailand,banks,Bitcoin,Bot,BTC,commerc...
#
#                                                Title   Datetime  Year Month  \
# 0  The Daily: Wirex Adds Ethereum, Deutsche Börse... 2018-09-04  2018    09
# 1  SBI Plans Derivatives Platform, Huobi Eyes 30%... 2018-08-02  2018    08
# 2  Shapeshift Moves to Membership Model Requiring... 2018-09-05  2018    09
# 3  NYSE Owner: Bitcoin Should Be in Retirement Fu... 2018-08-04  2018    08
# 4  Bank of Thailand Green-Lights Financial Compan... 2018-08-06  2018    08
#
#   Day  Numerical_date                                          Textchunk
# 0  04        20180904  The Tuesday edition of our daily roundup is ja...
# 1  02        20180802  Japan’s SBI Group is reportedly planning to cr...
# 2  05        20180905  Non-custodial crypto trading platform Shapeshi...
# 3  04        20180804  Intercontinental Exchange (ICE), owner of argu...
# 4  06        20180806  Thailand’s central bank has announced the rule...

# %% [markdown]
# # word2vec

# %%
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess

class MySentences(object): 
    def __iter__(self):
        for i in range(news.shape[0]):
            yield simple_preprocess(news.iloc[i,9])
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
assert gensim.models.doc2vec.FAST_VERSION > -1

# %%
# %%time
import multiprocessing
import os
cores = multiprocessing.cpu_count()

if not os.path.exists('models/word2vec.model'):
    print("start traing word2vec model...")
    sentences = MySentences()
    word2vec_model = gensim.models.Word2Vec(sentences, min_count=20, size=200, workers=cores)
    if not os.path.exists('models'):
        os.makedirs('models')
        word2vec_model.save('models/word2vec.model')
    else:
        word2vec_model.save('models/word2vec.model')
else:
    word2vec_model = Word2Vec.load('models/word2vec.model')
# Out:
# start traing word2vec model...
# Wall time: 6.04 s

# %%
word2vec_model.wv.word_vec('japan')
# Out:
# array([ 0.23099245, -0.40995488, -0.07226684, -0.09342019, -0.2073103 ,
#        -0.28695744, -0.37862435,  0.10322383,  0.2577616 ,  0.00439262,
#        -0.07103091,  0.25559068,  0.27814412, -0.44493124,  0.23690538,
#         0.35899192,  0.04432926, -0.3824167 , -0.09529694, -0.21771577,
#         0.3447758 , -0.3188712 ,  0.04937246,  0.13526675, -0.36076596,
#         0.1755127 ,  0.02825051, -0.0269706 , -0.00277254, -0.32282144,
#         0.02933267,  0.31863832, -0.05808569,  0.20616844, -0.09393807,
#         0.20806278,  0.3890938 , -0.16519515,  0.06242054, -0.49173915,
#         0.15142614, -0.20087399,  0.19304298,  0.19440058,  0.29722986,
#        -0.05419963,  0.23453556, -0.30852005,  0.11068523,  0.30393246,
#        -0.19527276, -0.36275053,  0.1592779 , -0.10435552, -0.04008956,
#         0.31441516,  0.26298535, -0.2601682 , -0.09579869,  0.07881349,
#         0.14664854, -0.1829456 , -0.3219531 ,  0.33483863,  0.10853055,
#        -0.5998203 , -0.05526113, -0.10232022, -0.453147  ,  0.42041206,
#        -0.09562179, -0.16820027,  0.04721231, -0.00395183, -0.10373461,
#         0.02353231, -0.12645021, -0.01140696, -0.05305873, -0.52061737,
#         0.3746923 , -0.39798644,  0.25335738,  0.10335932,  0.17352997,
#        -0.12414423,  0.01089834, -0.0305348 , -0.05585077, -0.11039808,
#         0.16441336,  0.01831204, -0.3469479 ,  0.31501135,  0.00828873,
#        -0.25137383,  0.15766194, -0.05490118,  0.06168668, -0.37727344,
#         0.29613146,  0.20750943, -0.1667565 ,  0.09060374, -0.31901866,
#        -0.07139918,  0.19563535, -0.1647172 ,  0.12617864,  0.09632845,
#        -0.24578676,  0.11636478,  0.15023485,  0.19035947, -0.16503806,
#        -0.13961779,  0.05101509, -0.16611984,  0.32572752,  0.09040209,
#        -0.02727695,  0.21539825,  0.32245633, -0.04665642, -0.05521356,
#        -0.20807257,  0.12726915,  0.16931291,  0.07746206,  0.01947348,
#         0.33783972,  0.3716039 , -0.16669503,  0.04070253,  0.4349284 ,
#         0.11623393,  0.01295109,  0.07218054, -0.24348962,  0.19937162,
#         0.13234608, -0.51025957, -0.4204688 , -0.19302596,  0.10982174,
#         0.05132266, -0.20186275, -0.30009803, -0.15944846,  0.04402702,
#         0.29990897,  0.07753125,  0.1309591 , -0.14286567, -0.11032598,
#        -0.3227471 ,  0.13566288,  0.18061757,  0.27706665, -0.2554363 ,
#         0.10253662,  0.08100051, -0.05805767, -0.11235752,  0.20641603,
#        -0.00625601, -0.10291041, -0.15333413, -0.04530981,  0.15766719,
#         0.19181885, -0.1621212 ,  0.09097861,  0.22731946,  0.05078431,
#        -0.1710488 , -0.2944428 , -0.28397903,  0.04609836,  0.01019136,
#        -0.04838401, -0.3157043 ,  0.31908798, -0.1848846 , -0.05728724,
#        -0.02073705, -0.18787573, -0.01193986,  0.00579657, -0.15365334,
#        -0.06724241, -0.35255224,  0.06896104, -0.04117491, -0.0435395 ,
#        -0.5428009 , -0.06681309,  0.15186313, -0.29159167, -0.3185672 ],
#       dtype=float32)

# %%
word2vec_model.wv.most_similar(positive=['japan'], negative=['regulation'], topn=100)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('trading', 0.4962330162525177),
#  ('exchange', 0.48667895793914795),
#  ('launched', 0.453437864780426),
#  ('news', 0.4526098072528839),
#  ('recently', 0.44129276275634766),
#  ('recent', 0.4158521890640259),
#  ('com', 0.4090777635574341),
#  ('launch', 0.3981197476387024),
#  ('commission', 0.3778550326824188),
#  ('based', 0.3678431510925293),
#  ('largest', 0.35360029339790344),
#  ('million', 0.32774606347084045),
#  ('week', 0.32407522201538086),
#  ('volume', 0.3150397837162018),
#  ('after', 0.3148190379142761),
#  ('founder', 0.3030170798301697),
#  ('futures', 0.30291688442230225),
#  ('south', 0.3009553551673889),
#  ('published', 0.2993319630622864),
#  ('launches', 0.2982444763183594),
#  ('announced', 0.2981336712837219),
#  ('reported', 0.28790533542633057),
#  ('hong', 0.28764626383781433),
#  ('ceo', 0.2863397002220154),
#  ('has', 0.2849130630493164),
#  ('last', 0.2839438319206238),
#  ('firm', 0.28222978115081787),
#  ('securities', 0.2799607217311859),
#  ('sec', 0.27879172563552856),
#  ('company', 0.2714632749557495),
#  ('during', 0.27024251222610474),
#  ('japanese', 0.2666394114494324),
#  ('report', 0.2614699900150299),
#  ('new', 0.26086828112602234),
#  ('kong', 0.2573678493499756),
#  ('month', 0.25172579288482666),
#  ('past', 0.24894601106643677),
#  ('platform', 0.24754486978054047),
#  ('market', 0.24599115550518036),
#  ('korea', 0.2456934154033661),
#  ('following', 0.23648673295974731),
#  ('first', 0.23338356614112854),
#  ('fund', 0.22654908895492554),
#  ('revealed', 0.22584420442581177),
#  ('weeks', 0.22211551666259766),
#  ('mining', 0.21996408700942993),
#  ('coinbase', 0.2198733389377594),
#  ('startup', 0.21851550042629242),
#  ('usd', 0.21378383040428162),
#  ('two', 0.20605722069740295),
#  ('months', 0.2053719162940979),
#  ('co', 0.2050882875919342),
#  ('three', 0.20496541261672974),
#  ('korean', 0.20362691581249237),
#  ('traded', 0.2033558189868927),
#  ('leading', 0.20128987729549408),
#  ('podcast', 0.1979764997959137),
#  ('its', 0.1969434916973114),
#  ('released', 0.19054239988327026),
#  ('francisco', 0.18342691659927368),
#  ('bitcoin', 0.18191823363304138),
#  ('markets', 0.1791822910308838),
#  ('since', 0.17528319358825684),
#  ('etf', 0.17399626970291138),
#  ('united', 0.17266392707824707),
#  ('over', 0.16815698146820068),
#  ('december', 0.1612265706062317),
#  ('hours', 0.1597346067428589),
#  ('san', 0.15778927505016327),
#  ('stock', 0.1555333286523819),
#  ('team', 0.15428747236728668),
#  ('plans', 0.15293312072753906),
#  ('price', 0.15263138711452484),
#  ('brief', 0.14967510104179382),
#  ('chicago', 0.14786899089813232),
#  ('states', 0.1466521918773651),
#  ('group', 0.1449437439441681),
#  ('year', 0.14302891492843628),
#  ('developer', 0.14256411790847778),
#  ('provider', 0.13996726274490356),
#  ('second', 0.1381726861000061),
#  ('filed', 0.13742409646511078),
#  ('gmo', 0.1356942504644394),
#  ('app', 0.13389086723327637),
#  ('chinese', 0.1325497180223465),
#  ('partnered', 0.12942901253700256),
#  ('wallet', 0.1281682252883911),
#  ('june', 0.12719783186912537),
#  ('weekend', 0.1244000717997551),
#  ('th', 0.12258950620889664),
#  ('service', 0.1223793476819992),
#  ('update', 0.12233076989650726),
#  ('pool', 0.12085141241550446),
#  ('march', 0.1195458173751831),
#  ('according', 0.11871182918548584),
#  ('bitfinex', 0.11582740396261215),
#  ('sessions', 0.1143353059887886),
#  ('north', 0.1143055260181427),
#  ('on', 0.11359952390193939),
#  ('been', 0.11202167719602585)]

# %% [markdown]
# # doc2vec

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

class MyDocs(object):
    def __iter__(self):
        for i in range(news.shape[0]):
            yield TaggedDocument(words=simple_preprocess(news.iloc[i,9]), tags=['%d' % news.iloc[i,8]])

# %%
# %%time

if not os.path.exists('models/doc2vec.model'):
    print("start traing doc2vec model...")
    documents = MyDocs()
    doc2vec_model = Doc2Vec(dm=1, dbow_words=1, vector_size=200, window=8, min_count=20, workers=cores)
    doc2vec_model.build_vocab(documents)
    doc2vec_model.train(documents, total_examples=doc2vec_model.corpus_count, epochs=doc2vec_model.epochs)
    if not os.path.exists('models'):
        os.makedirs('models')
        doc2vec_model.save('models/doc2vec.model')
    else:
        doc2vec_model.save('models/doc2vec.model')
else:
    doc2vec_model = Doc2Vec.load('models/doc2vec.model')
# Out:
# start traing doc2vec model...
# Wall time: 10.4 s

# %%
doc2vec_model.docvecs.most_similar('20180118', topn = 100)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('20170927', 0.9927163124084473),
#  ('20180315', 0.9926577806472778),
#  ('20170512', 0.9926438331604004),
#  ('20160519', 0.9924439191818237),
#  ('20180217', 0.9924414157867432),
#  ('20150822', 0.9910603761672974),
#  ('20160926', 0.9904611110687256),
#  ('20180507', 0.9899706840515137),
#  ('20170704', 0.9898616075515747),
#  ('20180727', 0.9896129369735718),
#  ('20180115', 0.9895788431167603),
#  ('20161113', 0.9895451068878174),
#  ('20160529', 0.9893954396247864),
