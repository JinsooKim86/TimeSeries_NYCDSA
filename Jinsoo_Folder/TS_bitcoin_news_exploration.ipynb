# %%
import pandas as pd
import numpy as np
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
import nltk
from datetime import datetime
lmtizer=nltk.stem.WordNetLemmatizer()
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
news = pd.read_csv('bitcoin_news.csv')
news.head()
# Out:
#                         Date  \
# 0  2018-09-04T08:00:04-04:00
# 1  2018-08-02T17:15:26-04:00
# 2  2018-09-05T01:15:31-04:00
# 3  2018-08-04T04:55:54-04:00
# 4  2018-08-06T03:45:21-04:00
#
#                                              Summary  \
# 0  The Tuesday edition of our daily roundup is ja...
# 1  Japan’s SBI Group is reportedly planning to cr...
# 2  Non-custodial crypto trading platform Shapeshi...
# 3  Intercontinental Exchange (ICE), owner of argu...
# 4  Thailand’s central bank has announced the rule...
#
#                                                 Tags  \
# 0  ATM,Blockchain,Brave,Deutsche Börse,Ethereum,G...
# 1  ATM,BCH,Bitcoin,bitcoin cash,BTC,BTM,coin asse...
# 2  AML,anti-money laundering,Bitcoin,BTC,crypto,C...
# 3  401k,Bitcoin,Boston Consulting Group,Canada,CF...
# 4  bank of thailand,banks,Bitcoin,Bot,BTC,commerc...
#
#                                                Title
# 0  The Daily: Wirex Adds Ethereum, Deutsche Börse...
# 1  SBI Plans Derivatives Platform, Huobi Eyes 30%...
# 2  Shapeshift Moves to Membership Model Requiring...
# 3  NYSE Owner: Bitcoin Should Be in Retirement Fu...
# 4  Bank of Thailand Green-Lights Financial Compan...

# %% [markdown]
# # Date Mutation

# %%
news['Datetime'] = list(map(lambda x: datetime.strptime(x[0:10],'%Y-%m-%d'), news['Date']))
news.head()
# Out:
#                         Date  \
# 0  2018-09-04T08:00:04-04:00
# 1  2018-08-02T17:15:26-04:00
# 2  2018-09-05T01:15:31-04:00
# 3  2018-08-04T04:55:54-04:00
# 4  2018-08-06T03:45:21-04:00
#
#                                              Summary  \
# 0  The Tuesday edition of our daily roundup is ja...
# 1  Japan’s SBI Group is reportedly planning to cr...
# 2  Non-custodial crypto trading platform Shapeshi...
# 3  Intercontinental Exchange (ICE), owner of argu...
# 4  Thailand’s central bank has announced the rule...
#
#                                                 Tags  \
# 0  ATM,Blockchain,Brave,Deutsche Börse,Ethereum,G...
# 1  ATM,BCH,Bitcoin,bitcoin cash,BTC,BTM,coin asse...
# 2  AML,anti-money laundering,Bitcoin,BTC,crypto,C...
# 3  401k,Bitcoin,Boston Consulting Group,Canada,CF...
# 4  bank of thailand,banks,Bitcoin,Bot,BTC,commerc...
#
#                                                Title   Datetime
# 0  The Daily: Wirex Adds Ethereum, Deutsche Börse... 2018-09-04
# 1  SBI Plans Derivatives Platform, Huobi Eyes 30%... 2018-08-02
# 2  Shapeshift Moves to Membership Model Requiring... 2018-09-05
# 3  NYSE Owner: Bitcoin Should Be in Retirement Fu... 2018-08-04
# 4  Bank of Thailand Green-Lights Financial Compan... 2018-08-06

# %% [markdown]
# # Tags

# %%
tags = sum(list(map(lambda x: lmtizer.lemmatize(x).split(','), news.Tags[news.Tags.isnull() == False])), [])

# %%
tag = []
count = []

for i in set(tags):
    num = tags.count(i)
    tag.append(i)
    count.append(num)
    
df_tag = pd.DataFrame({'tag':tag, 'count':count}).sort_values(by = 'count', ascending = False)

# %%
df_tag
# Out:
#                                   tag  count
# 18165                         Bitcoin   2776
# 7132                       N-Featured   2341
# 10985                  Cryptocurrency   1752
# 13895                       N-Economy    997
# 14037                             BTC    992
# 18727                          crypto    721
# 7375                     bitcoin cash    719
# 16297                Cryptocurrencies    584
# 9331                 Digital Currency    580
# 14415                             BCH    567
# 3455                         Ethereum    538
# 20174                Virtual Currency    517
# 11993                      Blockchain    494
# 1559                       Regulation    482
# 22256            N-Markets and Prices    431
# 10648                    N-Technology    391
# 639                               ICO    388
# 18021                           China    362
# 21087                           Japan    354
# 4210                        Exchanges    341
# 15046                        Coinbase    310
# 12481                          mining    307
# 2745                           Russia    295
# 17178               bitcoin exchanges    266
# 12629                     South Korea    257
# 4236                         Exchange    252
# 5754                      Regulations    232
# 5631                   Digital Assets    228
# 10156                         cryptos    222
# 16784                    Bitcoin Core    219
# ...                               ...    ...
# 9188                 Ledger Unplugged      1
# 9187                      Cryptonomex      1
# 9184                 Segwit Addresses      1
# 9182                    Jakob de Haan      1
# 9180                       hike rates      1
# 9216                        Magazines      1
# 9177                            Birds      1
# 9176                closing exchanges      1
# 9175                     Toby Fiennes      1
# 9173              Tokyo Olympics 2020      1
# 9172                       Validators      1
# 9171                       tokenomics      1
# 9193                          Bicycle      1
# 9194                               MS      1
# 9195                      Sun Guofeng      1
# 9197                          ordania      1
# 9198                   Ameri Holdings      1
# 9199                  human discovery      1
# 9200                 biometric device      1
# 9202                     ltc. bitcoin      1
# 9203                             1070      1
# 9204   Secure Bitcoin Traders Pvt Ltd      1
# 9205                Kwong Wah Mansion      1
# 9208                          Jaitley      1
# 9209               immutable messages      1
# 9211                          shibuya      1
# 9212                     Rusty Russel      1
# 9214                      Complicates      1
# 9215                           muscat      1
# 22690                  bitcoininfо.ru      1
#
# [22691 rows x 2 columns]

# %% [markdown]
# # Titles

# %%
title = ' '.join(news['Title'])
title = list(map(lambda x: lmtizer.lemmatize(x), simple_preprocess(title)))
title = nltk.pos_tag(title, tagset='universal')

# %%
title
# Out:
# [('the', 'DET'),
#  ('daily', 'ADJ'),
#  ('wirex', 'NOUN'),
#  ('add', 'VERB'),
#  ('ethereum', 'NOUN'),
#  ('deutsche', 'NOUN'),
#  ('börse', 'NOUN'),
#  ('embrace', 'NOUN'),
#  ('blockchain', 'NOUN'),
#  ('sbi', 'NOUN'),
#  ('plan', 'NOUN'),
#  ('derivative', 'ADJ'),
#  ('platform', 'NOUN'),
#  ('huobi', 'NOUN'),
#  ('eye', 'NOUN'),
#  ('korean', 'ADJ'),
#  ('market', 'NOUN'),
#  ('thai', 'NOUN'),
#  ('crypto', 'NOUN'),
#  ('atm', 'NOUN'),
#  ('unveiled', 'VERB'),
#  ('shapeshift', 'ADJ'),
#  ('move', 'NOUN'),
#  ('to', 'PRT'),
#  ('membership', 'NOUN'),
#  ('model', 'NOUN'),
#  ('requiring', 'VERB'),
#  ('user', 'ADJ'),
#  ('information', 'NOUN'),
#  ('nyse', 'NOUN'),
#  ('owner', 'NOUN'),
#  ('bitcoin', 'NOUN'),
#  ('should', 'VERB'),
#  ('be', 'VERB'),
#  ('in', 'ADP'),
#  ('retirement', 'NOUN'),
#  ('fund', 'NOUN'),
#  ('credit', 'NOUN'),
#  ('card', 'NOUN'),
#  ('retail', 'ADJ'),
#  ('store', 'NOUN'),
#  ('bank', 'NOUN'),
#  ('of', 'ADP'),
#  ('thailand', 'NOUN'),
#  ('green', 'ADJ'),
#  ('light', 'ADJ'),
#  ('financial', 'ADJ'),
#  ('company', 'NOUN'),
#  ('for', 'ADP'),
#  ('crypto', 'NOUN'),
#  ('activity', 'NOUN'),
#  ('coinbase', 'NOUN'),
#  ('seek', 'ADJ'),
#  ('online', 'NOUN'),
#  ('merchant', 'NOUN'),
#  ('crypto', 'NOUN'),
#  ('adoption', 'NOUN'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('million', 'NUM'),
#  ('the', 'DET'),
#  ('weekly', 'ADJ'),
#  ('china', 'NOUN'),
#  ('hire', 'NOUN'),
#  ('cryptographer', 'NOUN'),
#  ('mcdonald', 'NOUN'),
#  ('unveils', 'VERB'),
#  ('maccoin', 'ADJ'),
#  ('treasure', 'NOUN'),
#  ('ship', 'NOUN'),
#  ('ico', 'ADJ'),
#  ('dupe', 'NOUN'),
#  ('investor', 'NOUN'),
#  ('south', 'ADJ'),
#  ('korea', 'ADJ'),
#  ('asks', 'NOUN'),
#  ('interpol', 'NOUN'),
#  ('for', 'ADP'),
#  ('help', 'NOUN'),
#  ('study', 'NOUN'),
#  ('provides', 'VERB'),
#  ('an', 'DET'),
#  ('interesting', 'ADJ'),
#  ('look', 'NOUN'),
#  ('at', 'ADP'),
#  ('changing', 'VERB'),
#  ('bitcoin', 'NOUN'),
#  ('narrative', 'ADJ'),
#  ('bitmain', 'NOUN'),
#  ('offer', 'NOUN'),
#  ('wi', 'VERB'),
#  ('fi', 'ADJ'),
#  ('router', 'NOUN'),
#  ('mining', 'NOUN'),
#  ('crypto', 'NOUN'),
#  ('lender', 'NOUN'),
#  ('salt', 'NOUN'),
#  ('now', 'ADV'),
#  ('available', 'ADJ'),
#  ('in', 'ADP'),
#  ('state', 'NOUN'),
#  ('cryptowhispers', 'NOUN'),
#  ('binance', 'VERB'),
#  ('token', 'ADJ'),
#  ('listing', 'NOUN'),
#  ('quote', 'NOUN'),
#  ('btc', 'ADP'),
#  ('million', 'NUM'),
#  ('wendy', 'ADJ'),
#  ('mcelroy', 'NOUN'),
#  ('free', 'ADJ'),
#  ('market', 'NOUN'),
#  ('law', 'NOUN'),
#  ('enforcement', 'NOUN'),
#  ('for', 'ADP'),
#  ('crypto', 'NOUN'),
#  ('which', 'DET'),
#  ('cryptocurrency', 'NOUN'),
#  ('hardware', 'NOUN'),
#  ('wallet', 'NOUN'),
#  ('is', 'VERB'),
#  ('best', 'ADV'),
#  ('for', 'ADP'),
#  ('you', 'PRON'),
#  ('coingeek', 'VERB'),
#  ('speaks', 'NOUN'),
#  ('on', 'ADP'),
#  ('consensus', 'NOUN'),
#  ('change', 'NOUN'),
#  ('and', 'CONJ'),
#  ('next', 'ADJ'),
#  ('gen', 'NOUN'),
#  ('asic', 'ADJ'),
#  ('chip', 'NOUN'),
#  ('the', 'DET'),
#  ('daily', 'ADJ'),
#  ('altcoin', 'NOUN'),
#  ('panic', 'ADJ'),
#  ('stablecoin', 'NOUN'),
#  ('takeover', 'NOUN'),
#  ('report', 'NOUN'),
#  ('india', 'VERB'),
#  ('crypto', 'ADJ'),
#  ('regulation', 'NOUN'),
#  ('delayed', 'VERB'),
#  ('government', 'NOUN'),
#  ('considers', 'NOUN'),
#  ('crypto', 'VERB'),
#  ('token', 'ADJ'),
#  ('firm', 'NOUN'),
#  ('behind', 'ADP'),
#  ('japanese', 'ADJ'),
#  ('cryptocurrency', 'NOUN'),
#  ('spindle', 'NOUN'),
#  ('to', 'PRT'),
#  ('relocate', 'VERB'),
#  ('to', 'PRT'),
#  ('london', 'VERB'),
#  ('amid', 'ADP'),
#  ('investigation', 'NOUN'),
#  ('market', 'NOUN'),
#  ('update', 'ADJ'),
#  ('bloody', 'NOUN'),
#  ('crypto', 'NOUN'),
#  ('market', 'NOUN'),
#  ('suffer', 'VERB'),
#  ('more', 'ADJ'),
#  ('loss', 'NOUN'),
#  ('venezuela', 'NOUN'),
#  ('to', 'PRT'),
#  ('have', 'VERB'),
#  ('two', 'NUM'),
#  ('unit', 'NOUN'),
#  ('of', 'ADP'),
#  ('account', 'NOUN'),
#  ('petro', 'NOUN'),
#  ('and', 'CONJ'),
#  ('petro', 'NOUN'),
#  ('pegged', 'VERB'),
#  ('bolivar', 'NOUN'),
#  ('jamaica', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('exchange', 'NOUN'),
#  ('plan', 'NOUN'),
#  ('to', 'PRT'),
#  ('offer', 'VERB'),
#  ('cryptocurrency', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('ico', 'NOUN'),
#  ('regulation', 'NOUN'),
#  ('round', 'VERB'),
#  ('up', 'PRT'),
#  ('fundraising', 'VERB'),
#  ('law', 'NOUN'),
#  ('jeju', 'NOUN'),
#  ('island', 'VERB'),
#  ('self', 'PRON'),
#  ('directed', 'VERB'),
#  ('ira', 'ADJ'),
#  ('caribbean', 'ADJ'),
#  ('central', 'ADJ'),
#  ('bank', 'NOUN'),
#  ('explores', 'VERB'),
#  ('issuing', 'VERB'),
#  ('it', 'PRON'),
#  ('own', 'ADJ'),
#  ('digital', 'ADJ'),
#  ('coin', 'NOUN'),
#  ('an', 'DET'),
#  ('ico', 'ADJ'),
#  ('venture', 'NOUN'),
#  ('is', 'VERB'),
#  ('trying', 'VERB'),
#  ('to', 'PRT'),
#  ('take', 'VERB'),
#  ('over', 'PRT'),
#  ('tokyo', 'ADJ'),
#  ('stock', 'NOUN'),
#  ('exchange', 'NOUN'),
#  ('listed', 'VERB'),
#  ('company', 'NOUN'),
#  ('crypto', 'NOUN'),
#  ('cafe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('coworking', 'VERB'),
#  ('space', 'NOUN'),
#  ('hash', 'NOUN'),
#  ('house', 'NOUN'),
#  ('established', 'VERB'),
#  ('in', 'ADP'),
#  ('xi', 'NOUN'),
#  ('an', 'DET'),
#  ('china', 'NOUN'),
#  ('binance', 'NOUN'),
#  ('denies', 'VERB'),
#  ('btc', 'ADP'),
#  ('listing', 'VERB'),
#  ('quote', 'NOUN'),
#  ('accuser', 'NOUN'),
#  ('responds', 'VERB'),
#  ('you', 'PRON'),
#  ('are', 'VERB'),
#  ('king', 'VERB'),
#  ('liar', 'ADJ'),
#  ('silk', 'NOUN'),
#  ('road', 'NOUN'),
#  ('question', 'NOUN'),
#  ('unanswered', 'VERB'),
#  ('a', 'DET'),
#  ('ulbricht', 'ADJ'),
#  ('gather', 'NOUN'),
#  ('clemency', 'NOUN'),
#  ('signature', 'NOUN'),
#  ('bitcoin', 'NOUN'),
#  ('is', 'VERB'),
#  ('permissionless', 'ADJ'),
#  ('decentralized', 'VERB'),
#  ('firearm', 'NOUN'),
#  ('cody', 'NOUN'),
#  ('wilson', 'NOUN'),
#  ('is', 'VERB'),
#  ('satoshi', 'ADJ'),
#  ('nakamoto', 'ADJ'),
#  ('turkish', 'ADJ'),
#  ('bitcoin', 'NOUN'),
#  ('volume', 'NOUN'),
#  ('soar', 'VERB'),
#  ('a', 'DET'),
#  ('trader', 'NOUN'),
#  ('flee', 'VERB'),
#  ('the', 'DET'),
#  ('lira', 'NOUN'),
#  ('venezuela', 'X'),
#  ('constituent', 'NOUN'),
#  ('assembly', 'NOUN'),
#  ('draft', 'NOUN'),
#  ('law', 'NOUN'),
#  ('to', 'PRT'),
#  ('create', 'VERB'),
#  ('central', 'ADJ'),
#  ('bank', 'NOUN'),
#  ('for', 'ADP'),
#  ('crypto', 'NOUN'),
#  ('japan', 'NOUN'),
#  ('internet', 'NOUN'),
#  ('giant', 'NOUN'),
#  ('gmo', 'NOUN'),
#  ('unveils', 'ADJ'),
#  ('new', 'ADJ'),
#  ('crypto', 'NOUN'),
#  ('priority', 'NOUN'),
#  ('exchange', 'NOUN'),
#  ('profit', 'NOUN'),
#  ('up', 'PRT'),
#  ('fold', 'ADJ'),
#  ('bitcoin', 'NOUN'),
#  ('news', 'NOUN'),
#  ('roundup', 'NOUN'),
#  ('january', 'ADJ'),
#  ('th', 'NOUN'),
#  ('bitcoin', 'NOUN'),
#  ('news', 'NOUN'),
#  ('roundup', 'NOUN'),
#  ('january', 'ADJ'),
#  ('th', 'NOUN'),
#  ('introducing', 'VERB'),
#  ('bitcoin', 'ADJ'),
#  ('cash', 'NOUN'),
#  ('chart', 'NOUN'),
#  ('graphical', 'ADJ'),
#  ('constellation', 'NOUN'),
#  ('of', 'ADP'),
#  ('bch', 'NOUN'),
#  ('data', 'NOUN'),
#  ('malta', 'NOUN'),
#  ('top', 'ADJ'),
#  ('exchange', 'NOUN'),
#  ('based', 'VERB'),
#  ('crypto', 'ADJ'),
#  ('trade', 'NOUN'),
#  ('russia', 'NOUN'),
#  ('lead', 'NOUN'),
#  ('in', 'ADP'),
#  ('otc', 'ADJ'),
#  ('volume', 'NOUN'),
#  ('u', 'ADJ'),
#  ('government', 'NOUN'),
#  ('to', 'PRT'),
#  ('aggressively', 'ADV'),
#  ('pursue', 'VERB'),
#  ('unregulated', 'ADJ'),
#  ('service', 'NOUN'),
#  ('around', 'ADP'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ('an', 'DET'),
#  ('in', 'ADP'),
#  ('depth', 'ADJ'),
#  ('look', 'NOUN'),
#  ('at', 'ADP'),
#  ('the', 'DET'),
#  ('cryptocurrency', 'NOUN'),
#  ('economy', 'NOUN'),
#  ('stablecoin', 'ADJ'),
#  ('trend', 'NOUN'),
#  ('vietnamese', 'ADJ'),
#  ('stop', 'VERB'),
#  ('importing', 'VERB'),
#  ('bitcoin', 'ADP'),
#  ('mining', 'VERB'),
#  ('rig', 'NOUN'),
#  ('a', 'DET'),
#  ('import', 'NOUN'),
#  ('ban', 'NOUN'),
#  ('loom', 'NOUN'),
#  ('stablecoins', 'VERB'),
#  ('gaining', 'VERB'),
#  ('popularity', 'NOUN'),
#  ('in', 'ADP'),
#  ('india', 'NOUN'),
#  ('to', 'PRT'),
#  ('minimize', 'VERB'),
#  ('central', 'ADJ'),
#  ('bank', 'NOUN'),
#  ('impact', 'NOUN'),
#  ('exchange', 'NOUN'),
#  ('round', 'NOUN'),
#  ('up', 'ADP'),
#  ('chinese', 'ADJ'),
#  ('court', 'NOUN'),
#  ('back', 'ADV'),
#  ('coinnice', 'ADJ'),
#  ('repatriation', 'NOUN'),
#  ('cz', 'NOUN'),
#  ('demo', 'NOUN'),
#  ('binance', 'NOUN'),
#  ('dex', 'NOUN'),
#  ('create', 'VERB'),
#  ('an', 'DET'),
#  ('unforgettable', 'ADJ'),
#  ('wallet', 'NOUN'),
#  ('seed', 'NOUN'),
#  ('by', 'ADP'),
#  ('building', 'VERB'),
#  ('memory', 'NOUN'),
#  ('palace', 'NOUN'),
#  ('the', 'DET'),
#  ('daily', 'ADJ'),
#  ('huobi', 'NOUN'),
#  ('otc', 'NOUN'),
#  ('to', 'PRT'),
#  ('support', 'VERB'),
#  ('dồng', 'NOUN'),
#  ('dymon', 'NOUN'),
#  ('asia', 'NOUN'),
#  ('back', 'ADV'),
#  ('crypto', 'ADJ'),
#  ('platform', 'NOUN'),
#  ('wormhole', 'ADJ'),
#  ('mainnet', 'NOUN'),
#  ('and', 'CONJ'),
#  ('developer', 'NOUN'),
#  ('guide', 'NOUN'),
#  ('launched', 'VERB'),
#  ('satoshi', 'ADJ'),
#  ('nakamoto', 'NOUN'),
#  ('hunted', 'VERB'),
#  ('internationally', 'ADV'),
#  ('bounty', 'ADJ'),
#  ('grows', 'NOUN'),
#  ('market', 'NOUN'),
#  ('update', 'ADJ'),
#  ('crypto', 'ADJ'),
#  ('price', 'NOUN'),
#  ('consolidate', 'NOUN'),
#  ('after', 'ADP'),
#  ('some', 'DET'),
#  ('volatility', 'NOUN'),
#  ('study', 'VERB'),
#  ('crypto', 'NOUN'),
#  ('fund', 'NOUN'),
#  ('number', 'NOUN'),
#  ('despite', 'ADP'),
#  ('trend', 'NOUN'),
#  ('uncertainty', 'NOUN'),
#  ('brazil', 'ADJ'),
#  ('pro', 'ADJ'),
#  ('bitcoin', 'X'),
#  ('presidential', 'ADJ'),
#  ('candidate', 'NOUN'),
#  ('boa', 'NOUN'),
#  ('pra', 'NOUN'),
#  ('caramba', 'NOUN'),
#  ('bitcoin', 'NOUN'),
#  ('return', 'NOUN'),
#  ('to', 'PRT'),
#  ('innovation', 'NOUN'),
#  ('changing', 'VERB'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ('through', 'ADP'),
#  ('peer', 'NOUN'),
#  ('to', 'PRT'),
#  ('peer', 'VERB'),
#  ('electronic', 'ADJ'),
#  ('cash', 'NOUN'),
#  ('the', 'DET'),
#  ('weekly', 'ADJ'),
#  ('coinbase', 'NOUN'),
#  ('increase', 'NOUN'),
#  ('limit', 'NOUN'),
#  ('shapeshift', 'NOUN'),
#  ('acquires', 'VERB'),
#  ('bitfract', 'ADJ'),
#  ('okex', 'ADP'),
#  ('launch', 'ADJ'),
#  ('coinall', 'NOUN'),
#  ('regulation', 'NOUN'),
#  ('round', 'VERB'),
#  ('up', 'PRT'),
#  ('central', 'ADJ'),
#  ('bank', 'NOUN'),
#  ('issued', 'VERB'),
#  ('digital', 'ADJ'),
#  ('currency', 'NOUN'),
#  ('regulatory', 'ADJ'),
#  ('clarity', 'NOUN'),
#  ('apocalyptic', 'ADJ'),
#  ('prediction', 'NOUN'),
#  ('about', 'ADP'),
#  ('privacy', 'NOUN'),
#  ('coin', 'NOUN'),
#  ('are', 'VERB'),
#  ('very', 'ADV'),
#  ('wide', 'ADJ'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('mark', 'NOUN'),
#  ('the', 'DET'),
#  ('opposition', 'NOUN'),
#  ('towards', 'ADP'),
#  ('bitcoin', 'NOUN'),
#  ('abc', 'NOUN'),
#  ('proposed', 'VERB'),
#  ('upgrade', 'ADJ'),
#  ('change', 'NOUN'),
#  ('on', 'ADP'),
#  ('chain', 'NOUN'),
#  ('bch', 'NOUN'),
#  ('used', 'VERB'),
#  ('in', 'ADP'),
#  ('submarine', 'NOUN'),
#  ('swap', 'NOUN'),
#  ('for', 'ADP'),
#  ('off', 'PRT'),
#  ('chain', 'NOUN'),
#  ('btc', 'NOUN'),
#  ('huge', 'ADJ'),
#  ('demand', 'NOUN'),
#  ('for', 'ADP'),
#  ('crypto', 'ADJ'),
#  ('trading', 'NOUN'),
#  ('seen', 'VERB'),
#  ('in', 'ADP'),
#  ('india', 'NOUN'),
#  ('after', 'ADP'),
#  ('rbi', 'ADJ'),
#  ('ban', 'NOUN'),
#  ('iran', 'NOUN'),
#  ('step', 'VERB'),
#  ('up', 'PRT'),
#  ('plan', 'NOUN'),
#  ('for', 'ADP'),
#  ('national', 'ADJ'),
#  ('crypto', 'NOUN'),
#  ('after', 'ADP'),
#  ('u', 'ADJ'),
#  ('sanction', 'NOUN'),
#  ('japan', 'NOUN'),
#  ('unveils', 'ADJ'),
#  ('result', 'NOUN'),
#  ('of', 'ADP'),
#  ('on', 'ADP'),
#  ('site', 'NOUN'),
#  ('inspection', 'NOUN'),
#  ('of', 'ADP'),
#  ('crypto', 'ADJ'),
#  ('exchange', 'NOUN'),
#  ('bitcoin', 'NOUN'),
#  ('in', 'ADP'),
#  ('brief', 'ADJ'),
#  ('btc', 'ADJ'),
#  ('via', 'ADP'),
#  ('sm', 'NOUN'),
#  ('patented', 'VERB'),
#  ('brave', 'VERB'),
#  ('bat', 'NOUN'),
#  ('tip', 'NOUN'),
#  ('for', 'ADP'),
#  ('tweet', 'NOUN'),
#  ('and', 'CONJ'),
#  ('post', 'NOUN'),
#  ('another', 'DET'),
#  ('u', 'ADJ'),
#  ('city', 'NOUN'),
#  ('imposes', 'NOUN'),
#  ('moratorium', 'VERB'),
#  ('on', 'ADP'),
#  ('crypto', 'NOUN'),
#  ('mining', 'NOUN'),
#  ('this', 'DET'),
#  ('cryptocurrency', 'NOUN'),
#  ('data', 'VERB'),
#  ('site', 'NOUN'),
#  ('list', 'NOUN'),
#  ('coin', 'NOUN'),
#  ('by', 'ADP'),
#  ('fair', 'ADJ'),
#  ('market', 'NOUN'),
#  ('value', 'NOUN'),
#  ('new', 'ADJ'),
#  ('bill', 'NOUN'),
#  ('proposes', 'VERB'),
#  ('tax', 'NOUN'),
#  ('on', 'ADP'),
#  ('crypto', 'ADJ'),
#  ('income', 'NOUN'),
#  ('in', 'ADP'),
#  ('ukraine', 'ADJ'),
#  ('bitcoin', 'NOUN'),
#  ('cash', 'NOUN'),
#  ('acceptance', 'NOUN'),
#  ('grows', 'VERB'),
#  ('dish', 'ADJ'),
#  ('network', 'NOUN'),
#  ('and', 'CONJ'),
#  ('flow', 'NOUN'),
#  ('partner', 'NOUN'),
#  ('with', 'ADP'),
#  ('bitpay', 'ADJ'),
#  ('illegal', 'ADJ'),
#  ('activity', 'NOUN'),
#  ('no', 'ADV'),
#  ('longer', 'ADV'),
#  ('dominant', 'ADJ'),
#  ('use', 'NOUN'),
#  ('of', 'ADP'),
#  ('bitcoin', 'NOUN'),
#  ('dea', 'NOUN'),
#  ('agent', 'VERB'),
#  ('the', 'DET'),
#  ('ico', 'NOUN'),
#  ('market', 'NOUN'),
#  ('ha', 'NOUN'),
#  ('hit', 'VERB'),
#  ('the', 'DET'),
#  ('brake', 'NOUN'),
#  ('ecobank', 'ADJ'),
#  ('report', 'NOUN'),
#  ('find', 'VERB'),
#  ('significant', 'ADJ'),
#  ('presence', 'NOUN'),
#  ('of', 'ADP'),
#  ('crypto', 'NOUN'),
#  ('in', 'ADP'),
#  ('african', 'ADJ'),
#  ('country', 'NOUN'),
#  ('crypto', 'VERB'),
#  ('friendly', 'ADJ'),
#  ('policy', 'NOUN'),
#  ('rapidly', 'ADV'),
#  ('drawing', 'VERB'),
#  ('company', 'NOUN'),
#  ('to', 'PRT'),
#  ('thailand', 'VERB'),
#  ('the', 'DET'),
#  ('daily', 'ADJ'),
#  ('ledger', 'NOUN'),
#  ('add', 'VERB'),
#  ('coin', 'ADJ'),
#  ('okex', 'ADJ'),
#  ('launch', 'NOUN'),
#  ('coinall', 'NOUN'),
#  ('exmo', 'ADJ'),
#  ('partner', 'NOUN'),
#  ('with', 'ADP'),
#  ('mistertango', 'ADJ'),
#  ('electron', 'NOUN'),
#  ('cash', 'NOUN'),
#  ('wallet', 'NOUN'),
#  ('now', 'ADV'),
#  ('available', 'ADJ'),
#  ('for', 'ADP'),
#  ('basic', 'ADJ'),
#  ('feature', 'NOUN'),
#  ('phone', 'NOUN'),
#  ('philippine', 'NOUN'),
#  ('building', 'NOUN'),
#  ('crypto', 'NOUN'),
#  ('valley', 'NOUN'),
#  ('of', 'ADP'),
#  ('asia', 'ADJ'),
#  ('exchange', 'NOUN'),
#  ('round', 'NOUN'),
#  ('up', 'ADP'),
#  ('goldman', 'NOUN'),
#  ('considers', 'NOUN'),
#  ('crypto', 'VERB'),
#  ('custody', 'NOUN'),
#  ('sa', 'ADJ'),
#  ('exchange', 'NOUN'),
#  ('launch', 'NOUN'),
#  ('usdt', 'ADJ'),
#  ('report', 'NOUN'),
#  ('twitter', 'NOUN'),
#  ('crypto', 'NOUN'),
#  ('scam', 'VERB'),
#  ('giveaway', 'ADV'),
#  ('bot', 'ADJ'),
#  ('canaan', 'NOUN'),
#  ('unveils', 'NOUN'),
#  ('nm', 'VERB'),
#  ('chip', 'NOUN'),
#  ('equipped', 'VERB'),
#  ('miner', 'ADJ'),
#  ('at', 'ADP'),
#  ('press', 'NOUN'),
#  ('conference', 'NOUN'),
#  ('the', 'DET'),
#  ('daily', 'ADJ'),
#  ('shapeshift', 'NOUN'),
#  ('acquires', 'VERB'),
#  ('bitfract', 'ADJ'),
#  ('bitmain', 'NOUN'),
#  ('invests', 'NOUN'),
#  ('in', 'ADP'),
#  ('tribeos', 'ADJ'),
#  ('bitcoiners', 'NOUN'),
#  ('flee', 'VERB'),
#  ('to', 'PRT'),
#  ('censorship', 'VERB'),
#  ('resistant', 'ADJ'),
#  ('platform', 'NOUN'),
#  ('amidst', 'NOUN'),
#  ('social', 'ADJ'),
#  ('medium', 'NOUN'),
#  ('clampdown', 'NOUN'),
#  ('blockchain', 'NOUN'),
#  ('data', 'NOUN'),
#  ('now', 'ADV'),
#  ('ha', 'VERB'),
#  ('legal', 'ADJ'),
#  ('bearing', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('state', 'NOUN'),
#  ('of', 'ADP'),
#  ('ohio', 'NOUN'),
#  ('sec', 'NOUN'),
#  ('postpones', 'NOUN'),
#  ('decision', 'NOUN'),
#  ('on', 'ADP'),
#  ('vaneck', 'NOUN'),
#  ('solidx', 'NOUN'),
#  ('bitcoin', 'NOUN'),
#  ('etf', 'NOUN'),
#  ('but', 'CONJ'),
#  ('previous', 'ADJ'),
#  ('concern', 'NOUN'),
#  ('resolved', 'VERB'),
#  ('opera', 'ADV'),
#  ('browser', 'ADV'),
#  ('open', 'ADJ'),
#  ('it', 'PRON'),
#  ('built', 'VERB'),
#  ('in', 'ADP'),
#  ('cryptocurrency', 'NOUN'),
#  ('wallet', 'NOUN'),
#  ('to', 'PRT'),
#  ('desktop', 'VERB'),
#  ('user', 'NOUN'),
#  ('bettergram', 'NOUN'),
#  ('aim', 'NOUN'),
#  ('to', 'PRT'),
#  ('become', 'VERB'),
#  ('the', 'DET'),
#  ('crypto', 'ADJ'),
#  ('version', 'NOUN'),
#  ('of', 'ADP'),
#  ('telegram', 'NOUN'),
#  ('the', 'DET'),
#  ('daily', 'ADJ'),
#  ('coinbase', 'NOUN'),
#  ('increase', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('limit', 'NOUN'),
#  ('abcc', 'VERB'),
#  ('open', 'ADJ'),
#  ('in', 'ADP'),
#  ('malta', 'ADJ'),
#  ('omniex', 'NOUN'),
#  ('hire', 'NOUN'),
#  ('former', 'ADJ'),
#  ('regulator', 'NOUN'),
#  ('cftc', 'NOUN'),
#  ('regulated', 'VERB'),
#  ('ledgerx', 'ADJ'),
#  ('launch', 'ADJ'),
#  ('interest', 'NOUN'),
#  ('bearing', 'NOUN'),
#  ('btc', 'NOUN'),
#  ('saving', 'VERB'),
#  ('platform', 'NOUN'),
#  ('market', 'NOUN'),
#  ('update', 'ADJ'),
#  ('crypto', 'ADJ'),
#  ('price', 'NOUN'),
#  ('slide', 'NOUN'),
#  ('after', 'ADP'),
#  ('sec', 'ADJ'),
#  ('announcement', 'NOUN'),
#  ('crypto', 'NOUN'),
#  ('tax', 'NOUN'),
#  ('and', 'CONJ'),
#  ('accounting', 'NOUN'),
#  ('software', 'NOUN'),
#  ('libra', 'ADJ'),
#  ('raise', 'NOUN'),
#  ('in', 'ADP'),
#  ('series', 'NOUN'),
#  ('funding', 'NOUN'),
#  ('swiss', 'ADJ'),
#  ('bank', 'NOUN'),
#  ('are', 'VERB'),
#  ('onboarding', 'VERB'),
#  ('crypto', 'ADJ'),
#  ('client', 'NOUN'),
#  ('and', 'CONJ'),
#  ('asset', 'NOUN'),
#  ('u', 'ADJ'),
#  ('court', 'NOUN'),
#  ('seizes', 'VERB'),
#  ('btc', 'ADJ'),
#  ('sends', 'NOUN'),
#  ('bitcoin', 'ADJ'),
#  ('trader', 'NOUN'),
#  ('to', 'PRT'),
#  ('jail', 'NOUN'),
#  ('for', 'ADP'),
#  ('month', 'NOUN'),
#  ('for', 'ADP'),
#  ('money', 'NOUN'),
#  ('laundering', 'VERB'),
#  ('market', 'NOUN'),
#  ('update', 'ADJ'),
#  ('monster', 'NOUN'),
#  ('liquidation', 'NOUN'),
#  ('and', 'CONJ'),
#  ('flash', 'NOUN'),
#  ('crash', 'NOUN'),
#  ('fear', 'VERB'),
#  ('high', 'ADJ'),
#  ('time', 'NOUN'),
#  ('becomes', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('ipo', 'NOUN'),
#  ('to', 'PRT'),
#  ('accept', 'VERB'),
#  ('japan', 'ADJ'),
#  ('labor', 'NOUN'),
#  ('ministry', 'NOUN'),
#  ('confused', 'VERB'),
#  ('a', 'DET'),
#  ('crypto', 'NOUN'),
#  ('salary', 'ADJ'),
#  ('demand', 'NOUN'),
#  ('increased', 'VERB'),
#  ('report', 'ADJ'),
#  ('crypto', 'NOUN'),
#  ('market', 'NOUN'),
#  ('mood', 'NOUN'),
#  ('change', 'NOUN'),
#  ('two', 'NUM'),
#  ('month', 'NOUN'),
#  ('after', 'ADP'),
#  ('new', 'ADJ'),
#  ('trend', 'NOUN'),
#  ('japanese', 'ADJ'),
#  ('association', 'NOUN'),
#  ('seek', 'ADJ'),
#  ('authority', 'NOUN'),
#  ('to', 'PRT'),
#  ('enforce', 'VERB'),
#  ('self', 'PRON'),
#  ('regulation', 'NOUN'),
#  ('on', 'ADP'),
#  ('crypto', 'ADJ'),
#  ('exchange', 'NOUN'),
#  ('russian', 'ADJ'),
#  ('extradition', 'NOUN'),
#  ('request', 'NOUN'),
#  ('complicates', 'VERB'),
#  ('fate', 'NOUN'),
#  ('of', 'ADP'),
#  ('suspected', 'ADJ'),
#  ('btc', 'NOUN'),
#  ('owner', 'NOUN'),
#  ('canaan', 'VERB'),
#  ('creative', 'ADJ'),
#  ('announces', 'NOUN'),
#  ('world', 'NOUN'),
#  ('first', 'ADV'),
#  ('mining', 'VERB'),
#  ('tv', 'NOUN'),
#  ('set', 'VERB'),
#  ('bitpico', 'VERB'),
#  ('cash', 'NOUN'),
#  ('out', 'ADP'),
#  ('claiming', 'VERB'),
#  ('btc', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('world', 'NOUN'),
#  ('most', 'ADV'),
#  ('manipulated', 'ADJ'),
#  ('commodity', 'NOUN'),
#  ('binance', 'NOUN'),
#  ('ceo', 'NOUN'),
#  ('changpeng', 'NOUN'),
#  ('zhao', 'NOUN'),
#  ('with', 'ADP'),
#  ('tether', 'NOUN'),
#  ('concern', 'NOUN'),
#  ('is', 'VERB'),
#  ('always', 'ADV'),
#  ('there', 'DET'),
#  ('okex', 'ADJ'),
#  ('socializes', 'NOUN'),
#  ('loss', 'NOUN'),
#  ('from', 'ADP'),
#  ('over', 'ADP'),
#  ('million', 'NUM'),
#  ('bet', 'NOUN'),
#  ('among', 'ADP'),
#  ('btc', 'ADJ'),
#  ('future', 'ADJ'),
#  ('trader', 'NOUN'),
#  ('blockchain', 'NOUN'),
#  ('state', 'NOUN'),
#  ('lure', 'NOUN'),
#  ('citizen', 'NOUN'),
#  ('with', 'ADP'),
#  ('political', 'ADJ'),
#  ('nostalgia', 'NOUN'),
#  ('and', 'CONJ'),
#  ('voting', 'NOUN'),
#  ('right', 'ADV'),
#  ('queensland', 'NOUN'),
#  ('australia', 'ADJ'),
#  ('invests', 'VERB'),
#  ('portion', 'NOUN'),
#  ('of', 'ADP'),
#  ('it', 'PRON'),
#  ('mil', 'VERB'),
#  ('ignite', 'ADJ'),
#  ('idea', 'NOUN'),
#  ('fund', 'NOUN'),
#  ('in', 'ADP'),
#  ('crypto', 'ADJ'),
#  ('startup', 'ADJ'),
#  ('look', 'NOUN'),
#  ('at', 'ADP'),
#  ('stylometry', 'NOUN'),
#  ('can', 'VERB'),
#  ('we', 'PRON'),
#  ('uncover', 'VERB'),
#  ('satoshi', 'VERB'),
#  ('through', 'ADP'),
#  ('literary', 'ADJ'),
#  ('quirk', 'NOUN'),
#  ('chinese', 'ADJ'),
#  ('investor', 'NOUN'),
#  ('sue', 'NOUN'),
#  ('okcoin', 'NOUN'),
#  ('over', 'ADP'),
#  ('unclaimed', 'ADJ'),
#  ('bch', 'ADJ'),
#  ('market', 'NOUN'),
#  ('report', 'NOUN'),
#  ('selling', 'VERB'),
#  ('drive', 'ADJ'),
#  ('upswing', 'NOUN'),
#  ('in', 'ADP'),
#  ('emerging', 'VERB'),
#  ('market', 'NOUN'),
#  ('volume', 'NOUN'),
#  ('people', 'NOUN'),
#  ('money', 'NOUN'),
#  ('crypto', 'NOUN'),
#  ('to', 'PRT'),
#  ('outlast', 'VERB'),
#  ('fiat', 'ADJ'),
#  ('scam', 'NOUN'),
#  ('rich', 'ADJ'),
#  ('dad', 'NOUN'),
#  ('poor', 'ADJ'),
#  ('dad', 'NOUN'),
#  ('author', 'NOUN'),
#  ('bob', 'NOUN'),
#  ('goodlatte', 'NOUN'),
#  ('becomes', 'VERB'),
#  ('first', 'ADJ'),
#  ('member', 'NOUN'),
#  ('of', 'ADP'),
#  ('congress', 'NOUN'),
#  ('to', 'PRT'),
#  ('disclose', 'VERB'),
#  ('crypto', 'ADJ'),
#  ('holding', 'VERB'),
#  ('bitmain', 'NOUN'),
#  ('launch', 'NOUN'),
#  ('key', 'ADJ'),
#  ('crypto', 'NOUN'),
#  ('mining', 'NOUN'),
#  ('facility', 'NOUN'),
#  ('in', 'ADP'),
#  ('texas', 'CONJ'),
#  ('the', 'DET'),
#  ('daily', 'ADJ'),
#  ('robinhood', 'NOUN'),
#  ('reach', 'NOUN'),
#  ('iowa', 'NOUN'),
#  ('and', 'CONJ'),
#  ('georgia', 'ADJ'),
#  ('coinbase', 'NOUN'),
#  ('return', 'NOUN'),
#  ('to', 'PRT'),
#  ('wyoming', 'VERB'),
#  ('bitcoin', 'ADJ'),
#  ('atm', 'NOUN'),
#  ('now', 'ADV'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('thousand', 'NOUN'),
#  ('around', 'ADP'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ('decentralized', 'VERB'),
#  ('apps', 'NOUN'),
#  ('might', 'VERB'),
#  ('be', 'VERB'),
#  ('the', 'DET'),
#  ('future', 'NOUN'),
#  ('but', 'CONJ'),
#  ('they', 'PRON'),
#  ('re', 'VERB'),
#  ('not', 'ADV'),
#  ('the', 'DET'),
#  ('present', 'ADJ'),
#  ...]

# %%
nouns_title = [i for i in title if i[1] == 'NOUN']
noun_title = []
noun_title_count = []

noun_title_counting_list = list(map(lambda x: x[0], nouns_title))

for i in set(nouns_title):
    noun_title.append(i[0])
    noun_title_count.append(noun_title_counting_list.count(i[0]))
    
df_nouns_title = pd.DataFrame({'noun_title':noun_title, 'noun_title_count':noun_title_count}).sort_values(by = 'noun_title_count', ascending = False)

# %%
df_nouns_title.head(50)
# Out:
#           noun_title  noun_title_count
# 1640         bitcoin              2333
# 1819        exchange               658
# 3402  cryptocurrency               548
# 269           crypto               491
# 1060      blockchain               428
# 2355          market               387
# 2612            bank               335
# 4156            cash               304
# 1400          wallet               231
# 3678           price               216
# 1043         trading               199
# 2972          mining               198
# 1503          launch               179
# 3450      regulation               164
# 2344         company               138
# 3879        currency               133
# 2198         payment               127
# 645             fund               125
# 4550        coinbase               123
# 169          service               123
# 4494      government               123
# 1703         network               115
# 3800             com               112
# 3136           japan               109
# 904         platform               107
# 4361        security               104
# 4349            plan               104
# 2650           miner               100
# 3670            week               100
# 2747        investor                98
# 3551            year                97
# 3715          report                96
# 1473             tax                96
# 4593     transaction                95
# 1560             btc                95
# 2141            fork                94
# 251            money                93
# 376         ethereum                92
# 2604           world                91
# 493        regulator                84
# 2861      investment                78
# 4189             ico                77
# 172             coin                77
# 1301            card                76
# 1502      technology                76
# 4003          future                76
# 1285        business                75
# 4038           china                75
# 2814             ban                72
# 1063           brief                71

# %%
adjectives_title = [i for i in title if i[1] == 'ADJ']
adjective_title = []
adjective_title_count = []

adjective_title_counting_list = list(map(lambda x: x[0], adjectives_title))

for i in set(adjectives_title):
    adjective_title.append(i[0])
    adjective_title_count.append(adjective_title_counting_list.count(i[0]))
    
df_adjectives_title = pd.DataFrame({'adjective_title':adjective_title, 'adjective_title_count':adjective_title_count}).sort_values(by = 'adjective_title_count', ascending = False)

# %%
df_adjectives_title
# Out:
#      adjective_title  adjective_title_count
# 314          bitcoin                    584
# 620              new                    510
# 2203          crypto                    252
# 589           update                    144
# 326                u                    119
# 1149           south                    118
# 1504        japanese                    117
# 1802         chinese                    110
# 1557          korean                    106
# 1116         central                    104
# 454          digital                     99
# 1055         russian                     92
# 1558       financial                     80
# 2201             big                     71
# 981           launch                     69
# 1464            open                     68
# 286             more                     68
# 2214          indian                     67
# 675             high                     65
# 768            daily                     65
# 1134           first                     64
# 990           global                     62
# 742            korea                     56
# 1060              uk                     55
# 415            major                     55
# 898          largest                     53
# 1366          future                     52
# 1785             btc                     48
# 722           public                     47
# 1042             top                     46
# ...              ...                    ...
# 922           sofort                      1
# 921      requirement                      1
# 920        murderous                      1
# 918             usms                      1
# 955               mb                      1
# 956           greece                      1
# 957            steam                      1
# 958            grade                      1
# 994          lottery                      1
# 991          october                      1
# 988             apis                      1
# 987          alaskan                      1
# 984               im                      1
# 983              sim                      1
# 982      apocalyptic                      1
# 980           binary                      1
# 979     incentivizes                      1
# 976          synereo                      1
# 975          bermuda                      1
# 972           father                      1
# 971          support                      1
# 970             ross                      1
# 967        defensive                      1
# 966        challenge                      1
# 965        leveraged                      1
# 964       unabridged                      1
# 963             flow                      1
# 961         coinkite                      1
# 960          numerai                      1
# 2278           loved                      1
#
# [2279 rows x 2 columns]

# %% [markdown]
# # Summaries

# %%
summary = ' '.join(news['Summary'])
summary = list(map(lambda x: lmtizer.lemmatize(x), simple_preprocess(summary)))
summary = nltk.pos_tag(summary, tagset='universal')

# %%
summary
# Out:
# [('the', 'DET'),
#  ('tuesday', 'ADJ'),
#  ('edition', 'NOUN'),
#  ('of', 'ADP'),
#  ('our', 'PRON'),
#  ('daily', 'ADJ'),
#  ('roundup', 'NOUN'),
#  ('is', 'VERB'),
#  ('jam', 'ADJ'),
#  ('packed', 'VERB'),
#  ('with', 'ADP'),
#  ('tidbit', 'NOUN'),
#  ('snippet', 'NOUN'),
#  ('and', 'CONJ'),
#  ('other', 'ADJ'),
#  ('term', 'NOUN'),
#  ('used', 'VERB'),
#  ('to', 'PRT'),
#  ('describe', 'VERB'),
#  ('story', 'NOUN'),
#  ('in', 'ADP'),
#  ('brief', 'NOUN'),
#  ('that', 'ADP'),
#  ('deserve', 'NOUN'),
#  ('telling', 'VERB'),
#  ('on', 'ADP'),
#  ('this', 'DET'),
#  ('day', 'NOUN'),
#  ('september', 'VERB'),
#  ('we', 'PRON'),
#  ('bring', 'VERB'),
#  ('you', 'PRON'),
#  ('news', 'NOUN'),
#  ('of', 'ADP'),
#  ('major', 'ADJ'),
#  ('security', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('firm', 'NOUN'),
#  ('boarding', 'VERB'),
#  ('the', 'DET'),
#  ('blockchain', 'NOUN'),
#  ('bandwagon', 'NOUN'),
#  ('bitcoin', 'NOUN'),
#  ('atm', 'NOUN'),
#  ('proliferating', 'VERB'),
#  ('in', 'ADP'),
#  ('europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('brave', 'VERB'),
#  ('browser', 'NOUN'),
#  ('hitting', 'VERB'),
#  ('another', 'DET'),
#  ('milestone', 'NOUN'),
#  ('japan', 'NOUN'),
#  ('sbi', 'NOUN'),
#  ('group', 'NOUN'),
#  ('is', 'VERB'),
#  ('reportedly', 'ADV'),
#  ('planning', 'VERB'),
#  ('to', 'PRT'),
#  ('create', 'VERB'),
#  ('crypto', 'ADJ'),
#  ('derivative', 'ADJ'),
#  ('platform', 'NOUN'),
#  ('in', 'ADP'),
#  ('south', 'ADJ'),
#  ('korea', 'ADJ'),
#  ('huobi', 'NOUN'),
#  ('is', 'VERB'),
#  ('taking', 'VERB'),
#  ('an', 'DET'),
#  ('aggressive', 'ADJ'),
#  ('approach', 'NOUN'),
#  ('and', 'CONJ'),
#  ('expects', 'VERB'),
#  ('to', 'PRT'),
#  ('achieve', 'VERB'),
#  ('crypto', 'NOUN'),
#  ('market', 'NOUN'),
#  ('share', 'NOUN'),
#  ('meanwhile', 'ADJ'),
#  ('thai', 'NOUN'),
#  ('crypto', 'NOUN'),
#  ('exchange', 'NOUN'),
#  ('ha', 'NOUN'),
#  ('unveiled', 'VERB'),
#  ('an', 'DET'),
#  ('atm', 'NOUN'),
#  ('that', 'DET'),
#  ('support', 'NOUN'),
#  ('number', 'NOUN'),
#  ('of', 'ADP'),
#  ('non', 'ADJ'),
#  ('custodial', 'ADJ'),
#  ('crypto', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('platform', 'NOUN'),
#  ('shapeshift', 'NOUN'),
#  ('ha', 'NOUN'),
#  ('introduced', 'VERB'),
#  ('membership', 'NOUN'),
#  ('program', 'NOUN'),
#  ('which', 'DET'),
#  ('will', 'VERB'),
#  ('soon', 'ADV'),
#  ('be', 'VERB'),
#  ('mandatory', 'ADJ'),
#  ('ceo', 'ADJ'),
#  ('erik', 'NOUN'),
#  ('voorhees', 'NOUN'),
#  ('explains', 'VERB'),
#  ('that', 'ADP'),
#  ('his', 'PRON'),
#  ('exchange', 'NOUN'),
#  ('will', 'VERB'),
#  ('have', 'VERB'),
#  ('to', 'PRT'),
#  ('begin', 'VERB'),
#  ('collecting', 'VERB'),
#  ('basic', 'ADJ'),
#  ('personal', 'ADJ'),
#  ('information', 'NOUN'),
#  ('of', 'ADP'),
#  ('it', 'PRON'),
#  ('user', 'ADJ'),
#  ('and', 'CONJ'),
#  ('there', 'DET'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('five', 'NUM'),
#  ('membership', 'NOUN'),
#  ('level', 'NOUN'),
#  ('exchange', 'NOUN'),
#  ('ice', 'NOUN'),
#  ('owner', 'NOUN'),
#  ('of', 'ADP'),
#  ('arguably', 'ADV'),
#  ('the', 'DET'),
#  ('most', 'ADV'),
#  ('important', 'ADJ'),
#  ('stock', 'NOUN'),
#  ('exchange', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('world', 'NOUN'),
#  ('the', 'DET'),
#  ('new', 'ADJ'),
#  ('york', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('exchange', 'NOUN'),
#  ('nyse', 'NOUN'),
#  ('is', 'VERB'),
#  ('introducing', 'VERB'),
#  ('new', 'ADJ'),
#  ('company', 'NOUN'),
#  ('bakkt', 'VERB'),
#  ('the', 'DET'),
#  ('idea', 'NOUN'),
#  ('is', 'VERB'),
#  ('to', 'PRT'),
#  ('weave', 'VERB'),
#  ('bitcoin', 'NOUN'),
#  ('core', 'NOUN'),
#  ('btc', 'NOUN'),
#  ('into', 'ADP'),
#  ('credit', 'NOUN'),
#  ('card', 'NOUN'),
#  ('and', 'CONJ'),
#  ('retail', 'VERB'),
#  ('the', 'DET'),
#  ('project', 'NOUN'),
#  ('is', 'VERB'),
#  ('getting', 'VERB'),
#  ('lot', 'NOUN'),
#  ('of', 'ADP'),
#  ('hype', 'NOUN'),
#  ('due', 'ADJ'),
#  ('in', 'ADP'),
#  ('large', 'ADJ'),
#  ('measure', 'NOUN'),
#  ('to', 'PRT'),
#  ('two', 'NUM'),
#  ('very', 'ADV'),
#  ('powerful', 'ADJ'),
#  ('backer', 'NOUN'),
#  ('microsoft', 'NOUN'),
#  ('and', 'CONJ'),
#  ('starbucks', 'NOUN'),
#  ('is', 'VERB'),
#  ('this', 'DET'),
#  ('the', 'DET'),
#  ('mainstreaming', 'NOUN'),
#  ('ecosystem', 'NOUN'),
#  ('enthusiast', 'DET'),
#  ('have', 'VERB'),
#  ('been', 'VERB'),
#  ('urging', 'VERB'),
#  ('thailand', 'ADJ'),
#  ('central', 'ADJ'),
#  ('bank', 'NOUN'),
#  ('ha', 'NOUN'),
#  ('announced', 'VERB'),
#  ('the', 'DET'),
#  ('rule', 'NOUN'),
#  ('under', 'ADP'),
#  ('which', 'DET'),
#  ('financial', 'ADJ'),
#  ('institution', 'NOUN'),
#  ('including', 'VERB'),
#  ('commercial', 'ADJ'),
#  ('bank', 'NOUN'),
#  ('and', 'CONJ'),
#  ('their', 'PRON'),
#  ('subsidiary', 'NOUN'),
#  ('can', 'VERB'),
#  ('engage', 'VERB'),
#  ('in', 'ADP'),
#  ('cryptocurrency', 'NOUN'),
#  ('activity', 'NOUN'),
#  ('they', 'PRON'),
#  ('include', 'VERB'),
#  ('security', 'NOUN'),
#  ('asset', 'NOUN'),
#  ('management', 'NOUN'),
#  ('and', 'CONJ'),
#  ('insurance', 'NOUN'),
#  ('firm', 'NOUN'),
#  ('this', 'DET'),
#  ('follows', 'VERB'),
#  ('the', 'DET'),
#  ('country', 'NOUN'),
#  ('crypto', 'VERB'),
#  ('regulatory', 'ADJ'),
#  ('framework', 'NOUN'),
#  ('that', 'DET'),
#  ('went', 'VERB'),
#  ('into', 'ADP'),
#  ('effect', 'NOUN'),
#  ('last', 'ADJ'),
#  ('month', 'NOUN'),
#  ('adoption', 'NOUN'),
#  ('news', 'NOUN'),
#  ('keep', 'VERB'),
#  ('flowing', 'VERB'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('from', 'ADP'),
#  ('wall', 'ADJ'),
#  ('street', 'NOUN'),
#  ('to', 'PRT'),
#  ('australia', 'VERB'),
#  ('and', 'CONJ'),
#  ('now', 'ADV'),
#  ('san', 'ADJ'),
#  ('francisco', 'VERB'),
#  ('the', 'DET'),
#  ('united', 'ADJ'),
#  ('state', 'NOUN'),
#  ('largest', 'ADJ'),
#  ('cryptocurrency', 'NOUN'),
#  ('bank', 'NOUN'),
#  ('coinbase', 'NOUN'),
#  ('announced', 'VERB'),
#  ('it', 'PRON'),
#  ('is', 'VERB'),
#  ('expanding', 'VERB'),
#  ('it', 'PRON'),
#  ('commerce', 'ADJ'),
#  ('section', 'NOUN'),
#  ('to', 'PRT'),
#  ('include', 'VERB'),
#  ('woo', 'ADJ'),
#  ('commerce', 'NOUN'),
#  ('via', 'ADP'),
#  ('plugin', 'NOUN'),
#  ('downloadable', 'ADJ'),
#  ('from', 'ADP'),
#  ('github', 'NOUN'),
#  ('it', 'PRON'),
#  ('could', 'VERB'),
#  ('be', 'VERB'),
#  ('just', 'ADV'),
#  ('what', 'PRON'),
#  ('more', 'ADJ'),
#  ('online', 'ADJ'),
#  ('merchant', 'NOUN'),
#  ('need', 'NOUN'),
#  ('to', 'PRT'),
#  ('get', 'VERB'),
#  ('comfortable', 'ADJ'),
#  ('with', 'ADP'),
#  ('cryptocurrency', 'NOUN'),
#  ('in', 'ADP'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('daily', 'ADJ'),
#  ('edition', 'NOUN'),
#  ('of', 'ADP'),
#  ('bitcoin', 'NOUN'),
#  ('in', 'ADP'),
#  ('brief', 'NOUN'),
#  ('we', 'PRON'),
#  ('reported', 'VERB'),
#  ('about', 'ADP'),
#  ('china', 'NOUN'),
#  ('hiring', 'VERB'),
#  ('cryptographer', 'NOUN'),
#  ('mcdonald', 'NOUN'),
#  ('unveiling', 'VERB'),
#  ('maccoin', 'NOUN'),
#  ('bitmain', 'NOUN'),
#  ('getting', 'VERB'),
#  ('richer', 'ADJ'),
#  ('and', 'CONJ'),
#  ('much', 'ADV'),
#  ('more', 'ADJ'),
#  ('south', 'ADJ'),
#  ('korean', 'ADJ'),
#  ('police', 'NOUN'),
#  ('have', 'VERB'),
#  ('asked', 'VERB'),
#  ('interpol', 'NOUN'),
#  ('for', 'ADP'),
#  ('help', 'NOUN'),
#  ('with', 'ADP'),
#  ('an', 'DET'),
#  ('investigation', 'NOUN'),
#  ('into', 'ADP'),
#  ('the', 'DET'),
#  ('fraudulent', 'ADJ'),
#  ('token', 'ADJ'),
#  ('sale', 'NOUN'),
#  ('of', 'ADP'),
#  ('shinil', 'ADJ'),
#  ('gold', 'NOUN'),
#  ('coin', 'NOUN'),
#  ('that', 'DET'),
#  ('were', 'VERB'),
#  ('claimed', 'VERB'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('backed', 'VERB'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('treasure', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('sunken', 'ADJ'),
#  ('dmitrii', 'NOUN'),
#  ('donskoi', 'NOUN'),
#  ('local', 'ADJ'),
#  ('medium', 'NOUN'),
#  ('reported', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('sale', 'NOUN'),
#  ('raised', 'VERB'),
#  ('an', 'DET'),
#  ('estimated', 'VERB'),
#  ('million', 'NUM'),
#  ('from', 'ADP'),
#  ('last', 'ADJ'),
#  ('week', 'NOUN'),
#  ('nic', 'ADJ'),
#  ('carter', 'NOUN'),
#  ('the', 'DET'),
#  ('partner', 'NOUN'),
#  ('at', 'ADP'),
#  ('castle', 'ADJ'),
#  ('island', 'NOUN'),
#  ('venture', 'NOUN'),
#  ('and', 'CONJ'),
#  ('co', 'ADJ'),
#  ('founder', 'NOUN'),
#  ('of', 'ADP'),
#  ('coinmetrics', 'NOUN'),
#  ('io', 'VERB'),
#  ('published', 'VERB'),
#  ('an', 'DET'),
#  ('interesting', 'NOUN'),
#  ('study', 'NOUN'),
#  ('that', 'DET'),
#  ('look', 'VERB'),
#  ('at', 'ADP'),
#  ('the', 'DET'),
#  ('ever', 'ADV'),
#  ('changing', 'VERB'),
#  ('narrative', 'ADJ'),
#  ('tied', 'VERB'),
#  ('to', 'PRT'),
#  ('bitcoin', 'VERB'),
#  ('technology', 'NOUN'),
#  ('carter', 'NOUN'),
#  ('and', 'CONJ'),
#  ('his', 'PRON'),
#  ('fellow', 'ADJ'),
#  ('researcher', 'NOUN'),
#  ('hasufly', 'NOUN'),
#  ('scraped', 'VERB'),
#  ('up', 'PRT'),
#  ('lot', 'NOUN'),
#  ('of', 'ADP'),
#  ('data', 'NOUN'),
#  ('stemming', 'VERB'),
#  ('from', 'ADP'),
#  ('bitcointalk', 'NOUN'),
#  ('org', 'NOUN'),
#  ('post', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('year', 'NOUN'),
#  ('that', 'DET'),
#  ('highlight', 'VERB'),
#  ('some', 'DET'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('community', 'NOUN'),
#  ('derived', 'VERB'),
#  ('vision', 'NOUN'),
#  ('of', 'ADP'),
#  ('what', 'PRON'),
#  ('bitcoin', 'NOUN'),
#  ('should', 'VERB'),
#  ('be', 'VERB'),
#  ('and', 'CONJ'),
#  ('how', 'ADV'),
#  ('these', 'DET'),
#  ('vision', 'NOUN'),
#  ('have', 'VERB'),
#  ('changed', 'VERB'),
#  ('over', 'ADP'),
#  ('time', 'NOUN'),
#  ('have', 'VERB'),
#  ('you', 'PRON'),
#  ('ever', 'ADV'),
#  ('thought', 'VERB'),
#  ('about', 'ADP'),
#  ('mining', 'VERB'),
#  ('cryptos', 'NOUN'),
#  ('while', 'ADP'),
#  ('surfing', 'VERB'),
#  ('the', 'DET'),
#  ('web', 'NOUN'),
#  ('without', 'ADP'),
#  ('being', 'VERB'),
#  ('victim', 'NOUN'),
#  ('of', 'ADP'),
#  ('some', 'DET'),
#  ('malware', 'NOUN'),
#  ('of', 'ADP'),
#  ('course', 'NOUN'),
#  ('if', 'ADP'),
#  ('so', 'ADV'),
#  ('bitmain', 'ADJ'),
#  ('ha', 'NOUN'),
#  ('an', 'DET'),
#  ('offer', 'NOUN'),
#  ('you', 'PRON'),
#  ('might', 'VERB'),
#  ('be', 'VERB'),
#  ('interested', 'ADJ'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('chinese', 'ADJ'),
#  ('mining', 'NOUN'),
#  ('giant', 'ADJ'),
#  ('ha', 'NOUN'),
#  ('just', 'ADV'),
#  ('announced', 'VERB'),
#  ('it', 'PRON'),
#  ('offering', 'VERB'),
#  ('couple', 'NOUN'),
#  ('of', 'ADP'),
#  ('wi', 'NOUN'),
#  ('fi', 'NOUN'),
#  ('router', 'NOUN'),
#  ('capable', 'ADJ'),
#  ('of', 'ADP'),
#  ('minting', 'VERB'),
#  ('digital', 'ADJ'),
#  ('coin', 'NOUN'),
#  ('while', 'ADP'),
#  ('connecting', 'VERB'),
#  ('you', 'PRON'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('internet', 'NOUN'),
#  ('salt', 'VERB'),
#  ('one', 'NUM'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('earliest', 'ADJ'),
#  ('cryptocurrency', 'NOUN'),
#  ('backed', 'VERB'),
#  ('lending', 'NOUN'),
#  ('provider', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('space', 'NOUN'),
#  ('announced', 'VERB'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('it', 'PRON'),
#  ('wa', 'VERB'),
#  ('expanding', 'VERB'),
#  ('into', 'ADP'),
#  ('more', 'ADV'),
#  ('state', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('u', 'ADJ'),
#  ('bringing', 'NOUN'),
#  ('it', 'PRON'),
#  ('total', 'ADJ'),
#  ('market', 'NOUN'),
#  ('penetration', 'NOUN'),
#  ('to', 'PRT'),
#  ('including', 'VERB'),
#  ('washington', 'NOUN'),
#  ('dc', 'NOUN'),
#  ('across', 'ADP'),
#  ('america', 'NOUN'),
#  ('and', 'CONJ'),
#  ('while', 'ADP'),
#  ('that', 'DET'),
#  ('number', 'NOUN'),
#  ('is', 'VERB'),
#  ('impressive', 'ADJ'),
#  ('on', 'ADP'),
#  ('it', 'PRON'),
#  ('own', 'ADJ'),
#  ('salt', 'NOUN'),
#  ('accomplished', 'VERB'),
#  ('this', 'DET'),
#  ('during', 'ADP'),
#  ('an', 'DET'),
#  ('extended', 'ADJ'),
#  ('bear', 'NOUN'),
#  ('market', 'NOUN'),
#  ('tantalizing', 'VERB'),
#  ('unconfirmed', 'ADJ'),
#  ('rumor', 'NOUN'),
#  ('are', 'VERB'),
#  ('bouncing', 'VERB'),
#  ('from', 'ADP'),
#  ('crypto', 'NOUN'),
#  ('twitter', 'NOUN'),
#  ('and', 'CONJ'),
#  ('this', 'DET'),
#  ('time', 'NOUN'),
#  ('it', 'PRON'),
#  ('expanse', 'VERB'),
#  ('co', 'ADJ'),
#  ('founder', 'NOUN'),
#  ('christopher', 'NOUN'),
#  ('franko', 'NOUN'),
#  ('leading', 'VERB'),
#  ('the', 'DET'),
#  ('charge', 'NOUN'),
#  ('mr', 'NOUN'),
#  ('franko', 'NOUN'),
#  ('insists', 'VERB'),
#  ('he', 'PRON'),
#  ('wa', 'ADV'),
#  ('quoted', 'VERB'),
#  ('btc', 'PRT'),
#  ('roughly', 'ADV'),
#  ('million', 'NUM'),
#  ('a', 'DET'),
#  ('of', 'ADP'),
#  ('this', 'DET'),
#  ('writing', 'NOUN'),
#  ('for', 'ADP'),
#  ('token', 'ADJ'),
#  ('listing', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('exchange', 'NOUN'),
#  ('binance', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('cross', 'NOUN'),
#  ('accusation', 'NOUN'),
#  ('that', 'ADP'),
#  ('he', 'PRON'),
#  ('is', 'VERB'),
#  ('lying', 'VERB'),
#  ('mr', 'ADJ'),
#  ('franko', 'NOUN'),
#  ('further', 'ADV'),
#  ('insisted', 'VERB'),
#  ('literally', 'ADV'),
#  ('have', 'VERB'),
#  ('nothing', 'NOUN'),
#  ('to', 'PRT'),
#  ('gain', 'VERB'),
#  ('from', 'ADP'),
#  ('this', 'DET'),
#  ('the', 'DET'),
#  ('satoshi', 'ADJ'),
#  ('revolution', 'NOUN'),
#  ('revolution', 'NOUN'),
#  ('of', 'ADP'),
#  ('rising', 'VERB'),
#  ('expectation', 'NOUN'),
#  ('the', 'DET'),
#  ('number', 'NOUN'),
#  ('of', 'ADP'),
#  ('hardware', 'ADJ'),
#  ('wallet', 'NOUN'),
#  ('ha', 'NOUN'),
#  ('proliferated', 'VERB'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('number', 'NOUN'),
#  ('of', 'ADP'),
#  ('in', 'ADP'),
#  ('recent', 'ADJ'),
#  ('year', 'NOUN'),
#  ('today', 'NOUN'),
#  ('consumer', 'NOUN'),
#  ('enjoy', 'VERB'),
#  ('an', 'DET'),
#  ('unprecedented', 'ADJ'),
#  ('choice', 'NOUN'),
#  ('of', 'ADP'),
#  ('hardware', 'NOUN'),
#  ('device', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('to', 'PRT'),
#  ('store', 'VERB'),
#  ('their', 'PRON'),
#  ('bitcoin', 'NOUN'),
#  ('and', 'CONJ'),
#  ('altcoins', 'VERB'),
#  ('though', 'ADJ'),
#  ('market', 'NOUN'),
#  ('leader', 'NOUN'),
#  ('ledger', 'NOUN'),
#  ('and', 'CONJ'),
#  ('trezor', 'NOUN'),
#  ('still', 'ADV'),
#  ('dominate', 'VERB'),
#  ('for', 'ADP'),
#  ('anyone', 'NOUN'),
#  ('agonizing', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('best', 'ADJ'),
#  ('device', 'NOUN'),
#  ('for', 'ADP'),
#  ('their', 'PRON'),
#  ('need', 'NOUN'),
#  ('the', 'DET'),
#  ('following', 'ADJ'),
#  ('model', 'NOUN'),
#  ('are', 'VERB'),
#  ('worthy', 'ADJ'),
#  ('of', 'ADP'),
#  ('consideration', 'NOUN'),
#  ('last', 'ADJ'),
#  ('week', 'NOUN'),
#  ('news', 'NOUN'),
#  ('bitcoin', 'NOUN'),
#  ('com', 'NOUN'),
#  ('reported', 'VERB'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('proposed', 'VERB'),
#  ('consensus', 'NOUN'),
#  ('change', 'NOUN'),
#  ('published', 'VERB'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('bitcoin', 'NOUN'),
#  ('abc', 'NOUN'),
#  ('development', 'NOUN'),
#  ('team', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('opposition', 'NOUN'),
#  ('towards', 'NOUN'),
#  ('certain', 'ADJ'),
#  ('element', 'NOUN'),
#  ('of', 'ADP'),
#  ('that', 'DET'),
#  ('proposal', 'NOUN'),
#  ('from', 'ADP'),
#  ('few', 'ADJ'),
#  ('bch', 'NOUN'),
#  ('community', 'NOUN'),
#  ('member', 'NOUN'),
#  ('now', 'ADV'),
#  ('the', 'DET'),
#  ('blockchain', 'NOUN'),
#  ('firm', 'NOUN'),
#  ('and', 'CONJ'),
#  ('mining', 'NOUN'),
#  ('organization', 'NOUN'),
#  ('coingeek', 'NOUN'),
#  ('led', 'VERB'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('billionaire', 'NOUN'),
#  ('tycoon', 'NOUN'),
#  ('calvin', 'NOUN'),
#  ('ayre', 'NOUN'),
#  ('ha', 'NOUN'),
#  ('revealed', 'VERB'),
#  ('some', 'DET'),
#  ('different', 'ADJ'),
#  ('proposed', 'VERB'),
#  ('change', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('bch', 'NOUN'),
#  ('protocol', 'NOUN'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('group', 'NOUN'),
#  ('would', 'VERB'),
#  ('rather', 'ADV'),
#  ('support', 'VERB'),
#  ('moreover', 'NOUN'),
#  ('coingeek', 'NOUN'),
#  ('also', 'ADV'),
#  ('explains', 'VERB'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('ha', 'NOUN'),
#  ('designed', 'VERB'),
#  ('next', 'ADJ'),
#  ('generation', 'NOUN'),
#  ('asic', 'ADJ'),
#  ('chip', 'NOUN'),
#  ('that', 'DET'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('unveiled', 'VERB'),
#  ('during', 'ADP'),
#  ('the', 'DET'),
#  ('last', 'ADJ'),
#  ('week', 'NOUN'),
#  ('of', 'ADP'),
#  ('november', 'NOUN'),
#  ('in', 'ADP'),
#  ('london', 'NOUN'),
#  ('there', 'ADV'),
#  ('blood', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('street', 'NOUN'),
#  ('the', 'DET'),
#  ('water', 'NOUN'),
#  ('and', 'CONJ'),
#  ('everywhere', 'ADV'),
#  ('else', 'ADV'),
#  ('you', 'PRON'),
#  ('may', 'VERB'),
#  ('care', 'VERB'),
#  ('to', 'PRT'),
#  ('look', 'VERB'),
#  ('today', 'NOUN'),
#  ('a', 'DET'),
#  ('the', 'DET'),
#  ('cryptocurrency', 'NOUN'),
#  ('market', 'NOUN'),
#  ('plunge', 'NOUN'),
#  ('below', 'ADP'),
#  ('billion', 'NUM'),
#  ('with', 'ADP'),
#  ('vengeance', 'NOUN'),
#  ('we', 'PRON'),
#  ('ve', 'VERB'),
#  ('got', 'VERB'),
#  ('the', 'DET'),
#  ('reaction', 'NOUN'),
#  ('from', 'ADP'),
#  ('across', 'ADP'),
#  ('the', 'DET'),
#  ('web', 'NOUN'),
#  ('in', 'ADP'),
#  ('today', 'NOUN'),
#  ('bitcoin', 'NOUN'),
#  ('in', 'ADP'),
#  ('brief', 'NOUN'),
#  ('a', 'DET'),
#  ('well', 'ADV'),
#  ('a', 'DET'),
#  ('the', 'DET'),
#  ('latest', 'ADJ'),
#  ('development', 'NOUN'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('realm', 'NOUN'),
#  ('of', 'ADP'),
#  ('stablecoins', 'NOUN'),
#  ('which', 'DET'),
#  ('have', 'VERB'),
#  ('been', 'VERB'),
#  ('an', 'DET'),
#  ('oasis', 'NOUN'),
#  ('of', 'ADP'),
#  ('calm', 'ADJ'),
#  ('amidst', 'NOUN'),
#  ('all', 'DET'),
#  ('the', 'DET'),
#  ('blood', 'NOUN'),
#  ('letting', 'VERB'),
#  ('the', 'DET'),
#  ('indian', 'ADJ'),
#  ('government', 'NOUN'),
#  ('previously', 'ADV'),
#  ('planned', 'VERB'),
#  ('to', 'PRT'),
#  ('submit', 'VERB'),
#  ('the', 'DET'),
#  ('proposal', 'NOUN'),
#  ('for', 'ADP'),
#  ('crypto', 'ADJ'),
#  ('regulation', 'NOUN'),
#  ('in', 'ADP'),
#  ('july', 'NOUN'),
#  ('however', 'ADV'),
#  ('senior', 'ADJ'),
#  ('official', 'ADJ'),
#  ('ha', 'NOUN'),
#  ('revealed', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('regulatory', 'ADJ'),
#  ('framework', 'NOUN'),
#  ('for', 'ADP'),
#  ('in', 'ADP'),
#  ('india', 'ADJ'),
#  ('ha', 'NOUN'),
#  ('been', 'VERB'),
#  ('delayed', 'VERB'),
#  ('and', 'CONJ'),
#  ('will', 'VERB'),
#  ('likely', 'ADV'),
#  ('be', 'VERB'),
#  ('ready', 'ADJ'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('year', 'NOUN'),
#  ('end', 'NOUN'),
#  ('meanwhile', 'ADP'),
#  ('the', 'DET'),
#  ('government', 'NOUN'),
#  ('is', 'VERB'),
#  ('reportedly', 'ADV'),
#  ('considering', 'VERB'),
#  ('launching', 'VERB'),
#  ('crypto', 'NOUN'),
#  ('token', 'NOUN'),
#  ('for', 'ADP'),
#  ('financial', 'ADJ'),
#  ('transaction', 'NOUN'),
#  ('the', 'DET'),
#  ('japanese', 'ADJ'),
#  ('cryptocurrency', 'NOUN'),
#  ('spindle', 'VERB'),
#  ('known', 'VERB'),
#  ('for', 'ADP'),
#  ('being', 'VERB'),
#  ('promoted', 'VERB'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('japanese', 'ADJ'),
#  ('popular', 'ADJ'),
#  ('singer', 'NOUN'),
#  ('actor', 'NOUN'),
#  ('and', 'CONJ'),
#  ('talent', 'ADJ'),
#  ('gakuto', 'NOUN'),
#  ('oshiro', 'NOUN'),
#  ('aka', 'NOUN'),
#  ('gackt', 'NOUN'),
#  ('ha', 'NOUN'),
#  ('announced', 'VERB'),
#  ('it', 'PRON'),
#  ('withdrawing', 'VERB'),
#  ('from', 'ADP'),
#  ('tokyo', 'NOUN'),
#  ('to', 'PRT'),
#  ('relocate', 'VERB'),
#  ('it', 'PRON'),
#  ('headquarters', 'VERB'),
#  ('in', 'ADP'),
#  ('london', 'ADJ'),
#  ('amidst', 'ADJ'),
#  ('rumor', 'NOUN'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('tokyo', 'NOUN'),
#  ('metropolitan', 'ADJ'),
#  ('police', 'NOUN'),
#  ('is', 'VERB'),
#  ('investigating', 'VERB'),
#  ('unregistered', 'ADJ'),
#  ('sale', 'NOUN'),
#  ('of', 'ADP'),
#  ('made', 'VERB'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('leading', 'VERB'),
#  ('up', 'PRT'),
#  ('until', 'ADP'),
#  ('this', 'DET'),
#  ('tuesday', 'ADJ'),
#  ('great', 'ADJ'),
#  ('majority', 'NOUN'),
#  ('of', 'ADP'),
#  ('cryptocurrency', 'NOUN'),
#  ('market', 'NOUN'),
#  ('have', 'VERB'),
#  ('lost', 'VERB'),
#  ('considerable', 'ADJ'),
#  ('value', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('past', 'ADJ'),
#  ('few', 'ADJ'),
#  ('day', 'NOUN'),
#  ('since', 'ADP'),
#  ('our', 'PRON'),
#  ('last', 'ADJ'),
#  ('market', 'NOUN'),
#  ('update', 'VERB'),
#  ('this', 'DET'),
#  ('past', 'ADJ'),
#  ('saturday', 'NOUN'),
#  ('the', 'DET'),
#  ('overall', 'ADJ'),
#  ('cryptocurrency', 'NOUN'),
#  ('capitalization', 'NOUN'),
#  ('a', 'DET'),
#  ('whole', 'ADJ'),
#  ('ha', 'NOUN'),
#  ('dropped', 'VERB'),
#  ('significantly', 'ADV'),
#  ('by', 'ADP'),
#  ('losing', 'VERB'),
#  ('billion', 'NUM'),
#  ('usd', 'ADP'),
#  ('all', 'DET'),
#  ('eye', 'NOUN'),
#  ('will', 'VERB'),
#  ('surely', 'ADV'),
#  ('be', 'VERB'),
#  ('fixed', 'VERB'),
#  ('on', 'ADP'),
#  ('digital', 'ADJ'),
#  ('asset', 'NOUN'),
#  ('chart', 'NOUN'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('a', 'DET'),
#  ('there', 'ADV'),
#  ('been', 'VERB'),
#  ('plague', 'NOUN'),
#  ('of', 'ADP'),
#  ('bearish', 'ADJ'),
#  ('market', 'NOUN'),
#  ('sentiment', 'NOUN'),
#  ('cast', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('entire', 'ADJ'),
#  ('crypto', 'NOUN'),
#  ('economy', 'NOUN'),
#  ('president', 'NOUN'),
#  ('maduro', 'ADJ'),
#  ('venezuela', 'NOUN'),
#  ('is', 'VERB'),
#  ('preparing', 'VERB'),
#  ('to', 'PRT'),
#  ('effectively', 'ADV'),
#  ('adopt', 'VERB'),
#  ('next', 'ADJ'),
#  ('week', 'NOUN'),
#  ('two', 'NUM'),
#  ('official', 'ADJ'),
#  ('unit', 'NOUN'),
#  ('of', 'ADP'),
#  ('account', 'NOUN'),
#  ('the', 'DET'),
#  ('nation', 'NOUN'),
#  ('crypto', 'NOUN'),
#  ('el', 'X'),
#  ('petro', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('new', 'ADJ'),
#  ('petro', 'NOUN'),
#  ('pegged', 'VERB'),
#  ('bolivar', 'NOUN'),
#  ...]

# %%
nouns_summary = [i for i in summary if i[1] == 'NOUN']
noun_summary = []
noun_summary_count = []

noun_summary_counting_list = list(map(lambda x: x[0], nouns_summary))

for i in set(nouns_summary):
    noun_summary.append(i[0])
    noun_summary_count.append(noun_summary_counting_list.count(i[0]))
    
df_nouns_summary = pd.DataFrame({'noun_summary':noun_summary, 'noun_summary_count':noun_summary_count}).sort_values(by = 'noun_summary_count', ascending = False)

# %%
df_nouns_summary.head(50)
# Out:
#         noun_summary  noun_summary_count
# 6790         bitcoin                4257
# 5294              ha                2591
# 7573  cryptocurrency                1991
# 2805        exchange                1790
# 5037         company                 977
# 996           market                 977
# 1550            week                 899
# 7242            bank                 809
# 7768        currency                 786
# 1513            year                 751
# 2124          crypto                 736
# 3582           price                 697
# 456       blockchain                 658
# 68           service                 639
# 5153           world                 597
# 6763         country                 582
# 2484         trading                 565
# 7769            time                 563
# 7886            cash                 556
# 4442        platform                 517
# 2928          people                 505
# 4683      technology                 495
# 7396          mining                 479
# 6435             day                 465
# 3929      government                 460
# 2088            coin                 446
# 925          payment                 420
# 2996             bch                 409
# 4709             btc                 401
# 2635          wallet                 398
# 5886           month                 390
# 6816         network                 387
# 3634             com                 378
# 5800           state                 373
# 3866        security                 370
# 6001     transaction                 368
# 1358              wa                 362
# 2585        business                 359
# 8146           asset                 358
# 104            money                 353
# 7644            news                 353
# 329            today                 334
# 3200        investor                 322
# 6400         project                 308
# 2290            fund                 305
# 1054           value                 299
# 3593          report                 298
# 7149            firm                 280
# 1192            user                 276
# 3820       community                 275

# %%
adjectives_summary = [i for i in summary if i[1] == 'ADJ']
adjective_summary = []
adjective_summary_count = []

adjective_summary_counting_list = list(map(lambda x: x[0], adjectives_summary))

for i in set(adjectives_summary):
    adjective_summary.append(i[0])
    adjective_summary_count.append(adjective_summary_counting_list.count(i[0]))
    
df_adjectives = pd.DataFrame({'adjective_summary':adjective_summary, 'adjective_summary_count':adjective_summary_count}).sort_values(by = 'adjective_summary_count', ascending = False)

# %%
df_adjectives.head(50)
# Out:
#      adjective_summary  adjective_summary_count
# 1110               new                     1290
# 559            bitcoin                      720
# 819            digital                      712
# 2844         financial                      614
# 3822              many                      535
# 1479              last                      406
# 521               more                      397
# 2725            recent                      392
# 344               past                      388
# 4007             other                      367
# 2044             first                      364
# 946                few                      337
# 3916            crypto                      285
# 2020           central                      273
# 584                  u                      258
# 303            popular                      254
# 2070             south                      246
# 1640           largest                      240
# 1225              high                      240
# 760              major                      232
# 2526        regulatory                      220
# 1819            global                      220
# 3833           initial                      207
# 2738          japanese                      204
# 1917           russian                      201
# 3261           chinese                      185
# 993                usd                      184
# 512            virtual                      171
# 2270            latest                      166
# 3008             local                      163
# 2843            korean                      150
# 2818              most                      142
# 740               next                      141
# 1320            public                      141
# 627                due                      139
# 333                own                      135
# 17               legal                      132
# 3046              such                      131
# 2139           several                      130
# 762      international                      129
# 1958          economic                      127
# 1832            united                      125
# 1901               top                      124
# 118          different                      124
# 1794              hard                      122
# 1456              real                      122
# 665           national                      119
# 2745            social                      117
# 435           european                      115
# 3665           current                      115
