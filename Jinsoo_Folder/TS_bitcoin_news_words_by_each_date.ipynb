# %%
import pandas as pd
import numpy as np
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
import nltk
from datetime import datetime
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
news = pd.read_csv('bitcoin_news.csv')
news.head()
# Out:
#                         Date  \
# 0  2018-09-04T08:00:04-04:00
# 1  2018-08-02T17:15:26-04:00
# 2  2018-09-05T01:15:31-04:00
# 3  2018-08-04T04:55:54-04:00
# 4  2018-08-06T03:45:21-04:00
#
#                                              Summary  \
# 0  The Tuesday edition of our daily roundup is ja...
# 1  Japan’s SBI Group is reportedly planning to cr...
# 2  Non-custodial crypto trading platform Shapeshi...
# 3  Intercontinental Exchange (ICE), owner of argu...
# 4  Thailand’s central bank has announced the rule...
#
#                                                 Tags  \
# 0  ATM,Blockchain,Brave,Deutsche Börse,Ethereum,G...
# 1  ATM,BCH,Bitcoin,bitcoin cash,BTC,BTM,coin asse...
# 2  AML,anti-money laundering,Bitcoin,BTC,crypto,C...
# 3  401k,Bitcoin,Boston Consulting Group,Canada,CF...
# 4  bank of thailand,banks,Bitcoin,Bot,BTC,commerc...
#
#                                                Title
# 0  The Daily: Wirex Adds Ethereum, Deutsche Börse...
# 1  SBI Plans Derivatives Platform, Huobi Eyes 30%...
# 2  Shapeshift Moves to Membership Model Requiring...
# 3  NYSE Owner: Bitcoin Should Be in Retirement Fu...
# 4  Bank of Thailand Green-Lights Financial Compan...

# %% [markdown]
# # Date Mutation

# %%
news['Datetime'] = list(map(lambda x: datetime.strptime(x[0:10],'%Y-%m-%d'), news['Date']))
news['Year'] = list(map(lambda x: str(datetime.strptime(x[0:10],'%Y-%m-%d').year).zfill(4), news['Date']))
news['Month'] = list(map(lambda x: str(datetime.strptime(x[0:10],'%Y-%m-%d').month).zfill(2), news['Date']))
news['Day'] = list(map(lambda x: str(datetime.strptime(x[0:10],'%Y-%m-%d').day).zfill(2), news['Date']))
news['Numerical_date'] = news['Year'] + news['Month'] + news['Day']
news['Numerical_date'] = [int(i) for i in news['Numerical_date']]

# %% [markdown]
# # Date-token dictionary

# %%
date_list = list(np.unique(news['Numerical_date']))

# %%
lmtizer=nltk.stem.WordNetLemmatizer()

date_token_dict = {}

for i in date_list:
    word_class = nltk.pos_tag(simple_preprocess(news[news['Numerical_date'] == i][['Summary','Title']].to_string(header = False)), tagset = 'universal')
    date_token_dict.update({i : [lmtizer.lemmatize(i[0]) for i in word_class if i[1] in ['NOUN', 'ADJ']], ''})
    
date_token_dict
# Out:
# {20150118: ['week',
#   'beginning',
#   'alleged',
#   'silk',
#   'ro',
#   'bitcoin',
#   'news',
#   'roundup',
#   'january',
#   'th'],
#  20150125: ['coinbase',
#   'completion',
#   'bitcoin',
#   'news',
#   'roundup',
#   'january',
#   'th'],
#  20150201: ['last', 'week', 'timer', 'news', 'roundup', 'february', 'st'],
#  20150222: ['few',
#   'week',
#   'new',
#   'hampshire',
#   'house',
#   're',
#   'bitcoin',
#   'news',
#   'roundup',
#   'february',
#   'nd'],
#  20150301: ['move',
#   'reminiscent',
#   'time',
#   'bitcoin',
#   'news',
#   'roundup',
#   'march',
#   'st'],
#  20150315: ['ultra',
#   'stealth',
#   'bitcoin',
#   'company',
#   'name',
#   'bitcoin',
#   'news',
#   'roundup',
#   'march',
#   'th'],
#  20150322: ['commerce', 'giant', 'bitcoin', 'news', 'roundup', 'march', 'nd'],
#  20150329: ['bitcoin', 'news', 'roundup', 'march', 'th'],
#  20150503: ['circle', 'internet', 'financial', 'ltd', 'news', 'roundup'],
#  20150504: ['welcome', 'new', 'bitcoin', 'com'],
#  20150524: ['close', 'bitcoin', 'news', 'roundup'],
#  20150609: ['future',
#   'bitcoin',
#   'journalism',
#   'current',
#   'financial',
#   'infrastructure',
#   'ecosy',
#   'red',
#   'cross',
#   'donation',
#   'astray',
#   'time'],
#  20150611: ['bitcoin', 'encryption', 'freedo'],
#  20150612: ['sidechains',
#   'development',
#   'blockstream',
#   'release',
#   'sidechain',
#   'prototype'],
#  20150618: ['wednesday',
#   'june',
#   'rd',
#   'new',
#   'york',
#   'department',
#   'bitcoin',
#   'news',
#   'roundup',
#   'june',
#   'th',
#   'regardless',
#   'thing',
#   'bitcoin',
#   'charitable',
#   'cause',
#   'bi'],
#  20150620: ['mainstream', 'medium', 'blockchain', 'ownership'],
#  20150621: ['bitcoin', 'bank', 'bi'],
#  20150622: ['various', 'company', 'world', 'consumerism', 'debit', 'card'],
#  20150626: ['think', 'business', 'blockchain', 'digitization'],
#  20150629: ['blockchain', 'technology', 'data'],
#  20150701: ['video', 'game', 'play', 'role', 'mo'],
#  20150702: ['prolific',
#   'aspect',
#   'bitcoin',
#   'bitcoin',
#   'way',
#   'value',
#   'technology',
#   'power',
#   'digital',
#   'technology',
#   'bu'],
#  20150703: ['most',
#   'people',
#   'bitcoin',
#   'community',
#   'tha',
#   'credit',
#   'work',
#   'bitcoin',
#   'economy'],
#  20150704: ['bitcoin',
#   'network',
#   'improper',
#   'network',
#   'block',
#   'validation',
#   'mastercard',
#   'test',
#   'facial',
#   'recognition',
#   'technology'],
#  20150705: ['more',
#   'popular',
#   'way',
#   'bitco',
#   'bitcoin',
#   'documentary',
#   'oudated',
#   'time',
#   'blockchain',
#   'technology',
#   'corporation',
#   'btc',
#   'global',
#   'inc',
#   'blockchai'],
#  20150706: ['complex',
#   'greek',
#   'crisis',
#   'professor',
#   'crisis',
#   'solution',
#   'pressing',
#   'debate',
#   'world',
#   'european',
#   'head',
#   'data',
#   'protection',
#   'le'],
#  20150707: ['first',
#   'time',
#   'history',
#   'gold',
#   'gold',
#   'backseat',
#   'greek',
#   'mtgox',
#   'bankruptcy',
#   'truste',
#   'deadline',
#   'mtgox',
#   'bankruptcy',
#   'claim',
#   'bitcoin',
#   'blockchain',
#   'technology',
#   'bitmessage',
#   'proper',
#   'peer'],
#  20150708: ['editor',
#   'note',
#   'article',
#   'legal',
#   'fear',
#   'ross',
#   'ulbricht',
#   'appeal',
#   'many',
#   'eye',
#   'greece',
#   'china',
#   'stock',
#   'market'],
#  20150709: ['debate',
#   'bitcoin',
#   'gold',
#   'gold',
#   'innovative',
#   're',
#   'current',
#   'age',
#   'digital',
#   'technology',
#   'power',
#   'consumer',
#   'bitcoin',
#   'digital',
#   'currency',
#   'heralde',
#   'bitcoin',
#   'pillar'],
#  20150710: ['june',
#   'nyse',
#   'tra',
#   'bitcoin',
#   'do',
#   'light',
#   'matter',
#   'security',
#   'privacy',
#   'director',
#   'call',
#   'decryption',
#   'tool'],
#  20150711: ['bitcoin',
#   'other',
#   'technology',
#   'interactive',
#   'education',
#   'robot',
#   'bitlicense',
#   'controversial',
#   'ben',
#   'lawsky',
#   'door',
#   'bitcoin',
#   'recent',
#   'talk',
#   'discussion',
#   'digital',
#   'governance'],
#  20150712: ['surprise',
#   'anyone',
#   'world',
#   'next',
#   'logical',
#   'step',
#   'rise',
#   'inside',
#   'chicago',
#   'conference',
#   'bitgive',
#   'foundation',
#   'new',
#   'initiative',
#   'adoption',
#   'rate',
#   'bitcoin',
#   'center',
#   'chicago',
#   'bitcoin',
#   'incu'],
#  20150713: ['bitcoin',
#   'regardless',
#   'coinbase',
#   'outage',
#   'reminder',
#   'bit',
#   'article',
#   'sterlin',
#   'blockchain',
#   'towards',
#   'sovereignty'],
#  20150714: ['august',
#   'rd',
#   'keynote',
#   'fintech',
#   'conferenc',
#   'keynote',
#   'ledger',
#   'main',
#   'concern',
#   'bitcoin',
#   'whet',
#   'bitcoin',
#   'review',
#   'interesting',
#   'trend',
#   'bitcoin',
#   'service',
#   'user',
#   'account',
#   'data'],
#  20150715: ['bitcoin',
#   'uphill',
#   'battle',
#   'cash',
#   'v',
#   'bitcoin',
#   'bitcoin',
#   'superior',
#   'people',
#   'dollar',
#   'force',
#   'mathematics',
#   'fiat',
#   'v',
#   'cryptocurrency',
#   'overstock',
#   'patrick',
#   'byrne',
#   'com',
#   'able'],
#  20150716: ['first',
#   'quarter',
#   'bitcoin',
#   'venture',
#   'bitcoin',
#   'investment',
#   'numbe',
#   'week',
#   'vladimir',
#   'russian',
#   'vladimir',
#   'putin',
#   'favor',
#   'bitcoin',
#   'online',
#   'marketplace',
#   'bitcoin',
#   'transparent',
#   'marketplace'],
#  20150717: ['imagine', 'mother', 'pretend', 'bitcoin', 'mom', 'advice'],
#  20150718: ['article',
#   'natalie',
#   'johnson',
#   'country',
#   'jersey',
#   'release',
#   'new',
#   'bitcoin',
#   'regulat',
#   'government',
#   'official',
#   'world',
#   'california',
#   'uber',
#   'attempt',
#   'san',
#   'francisco',
#   'announces',
#   'new',
#   'fee',
#   'structure',
#   'article',
#   'sterlin',
#   'lujan',
#   'bitcoin',
#   'skimmer',
#   'fraudsters'],
#  20150719: ['heard',
#   'criticism',
#   'gender',
#   'diversity',
#   'bitcoin',
#   'tech',
#   'recent',
#   'block',
#   'size',
#   'debate',
#   'sock',
#   'puppet',
#   'accusa',
#   'bitcoin',
#   'many',
#   'thing',
#   'mai',
#   'bitcoin',
#   'digital',
#   'currency',
#   'virtual',
#   'cur'],
#  20150720: ['article',
#   'sterlin',
#   'economic',
#   'reformation',
#   'new',
#   'ninety',
#   'th',
#   'article',
#   'steven',
#   'decsesznak',
#   'bitlicense',
#   'implication',
#   'bitcoin',
#   'credibility'],
#  20150721: ['new',
#   'open',
#   'source',
#   'project',
#   'moneypacket',
#   'org',
#   'user',
#   'bitcoin',
#   'email',
#   'hefty',
#   'debate',
#   'sc',
#   'con',
#   'bitcoin',
#   'block',
#   'pruning',
#   'video',
#   'clip',
#   'paul',
#   'krugman',
#   'krugman',
#   'clueless',
#   'bitcoin'],
#  20150722: ['article',
#   'steven',
#   'decsesznak',
#   'biometric',
#   'application',
#   'bitcoin',
#   'hiera',
#   'good',
#   'cop',
#   'video',
#   'cam',
#   'police',
#   'violence',
#   'urgency',
#   'bitcoin',
#   'bitcoin',
#   'core',
#   'handful',
#   'bitcoin',
#   'digital',
#   'currency'],
#  20150723: ['innovation',
#   'financial',
#   'fintech',
#   'innovation',
#   'blockch',
#   'past',
#   'year',
#   'many',
#   'website',
#   'company',
#   'visited',
#   'website',
#   'bitcoin',
#   'eco',
#   'backpage',
#   'com',
#   'chicago',
#   'sheriff',
#   'thomas',
#   'backpage',
#   'sue',
#   'sheriff'],
#  20150724: ['day',
#   'age',
#   'lot',
#   'people',
#   'verification',
#   'procedure',
#   'core',
#   'developer',
#   'gavin',
#   'andresen',
#   'great',
#   'big',
#   'block',
#   'size',
#   'debate',
#   'hypr',
#   'corp',
#   'hypr',
#   'corp',
#   'first',
#   'biometric',
#   'tokeni'],
#  20150725: ['bitcoin',
#   'com',
#   'bitcoin',
#   'interview',
#   'bitcoin',
#   'graphic',
#   'artist',
#   'phneep',
#   'untapped',
#   'potential',
#   'digital',
#   'blockchain',
#   'tech',
#   'wizardry',
#   'ec',
#   'day',
#   'age',
#   'online',
#   'commerce',
#   'smart',
#   'contract',
#   'new'],
#  20150726: ['company',
#   'technology',
#   'warp',
#   'hewlett',
#   'packard',
#   'interest',
#   'bitcoin',
#   'digital',
#   'wallet',
#   'bitcoin',
#   'wallet',
#   'lack'],
#  20150727: ['user',
#   'gem',
#   'app',
#   'getgems',
#   'telebit',
#   'bitcoin',
#   'bitcoin',
#   'blockchain',
#   'differe',
#   'apple',
#   'pay',
#   'same',
#   'old',
#   'ball',
#   'chain'],
#  20150728: ['bitmesh',
#   'wi',
#   'fi',
#   'marketplace',
#   'people',
#   'bitmesh',
#   'internet',
#   'connectivity',
#   'exc',
#   'service',
#   'platform',
#   'service',
#   'contin'],
#  20150729: ['dead',
#   'last',
#   'show',
#   'summer',
#   'festival',
#   'scene',
#   'technological',
#   'innovation',
#   'many',
#   'bitcoin',
#   'company',
#   'hacker',
#   'tyson',
#   'miketyson',
#   'tyson',
#   'bitcoin',
#   'drama'],
#  20150801: ['cryptocurrency', 'fed', 'part'],
#  20150803: ['year',
#   'porcfest',
#   'project',
#   'meet',
#   'metalith',
#   'bitcoin',
#   'important',
#   'people',
#   'dif',
#   'reinvent',
#   'money',
#   'conference',
#   'tech',
#   'cryptocurrency',
#   'cryptocurrency',
#   'fed',
#   'part'],
#  20150804: ['people',
#   'bitcoin',
#   'child',
#   'high',
#   'en',
#   'future',
#   'use',
#   'case',
#   'blockchain',
#   'technology',
#   'co'],
#  20150805: ['bitcoin',
#   'shop',
#   'inc',
#   'bitcoin',
#   'shop',
#   'inc',
#   'strategic',
#   'partnership',
#   'finance',
#   'desperate',
#   'situ',
#   'finance',
#   'lover',
#   'future',
#   'use',
#   'case',
#   'blockchain',
#   'technology',
#   'di'],
#  20150806: ['regardless',
#   'email',
#   'provider',
#   'consumer',
#   'future',
#   'use',
#   'case',
#   'blockhain',
#   'technology',
#   'dis',
#   'avid',
#   'fan',
#   'bitcoin',
#   'rapper',
#   'depth',
#   'interview',
#   'rob',
#   'hustle'],
#  20150807: ['bitcoin',
#   'life',
#   'bitcoin',
#   'new',
#   'em',
#   'many',
#   'everyday',
#   'consumer',
#   'technology',
#   'bitcoin',
#   'technological',
#   'innovation',
#   'bitcoin',
#   'business',
#   'new',
#   'york',
#   'poloniex',
#   'new',
#   'york',
#   'due',
#   'blockchain',
#   'technology',
#   'platform',
#   'allow',
#   'future',
#   'use',
#   'case',
#   'blockchain',
#   'technology',
#   'many',
#   'attempt',
#   'current',
#   'bloc',
#   'bitcoin',
#   'xt',
#   'editorial',
#   'aim',
#   'ph',
#   'subjective',
#   'valuation',
#   'bitcoin',
#   'gold',
#   'saturday',
#   'mark',
#   'karpeles',
#   'mainstream',
#   'medias',
#   'failure',
#   'bitcoin',
#   'reporti',
#   'article',
#   'framework',
#   'bitcoin',
#   'v',
#   'forex',
#   'fintech',
#   'term',
#   'fintech',
#   'rehashing',
#   'old',
#   'payment',
#   'method',
#   'author',
#   'following',
#   'article',
#   'future',
#   'use',
#   'case',
#   'blockchain',
#   'technology',
#   'hearn',
#   'mike',
#   'hearn',
#   'gregory',
#   'great',
#   'bitcoin',
#   'bitcoin',
#   'way',
#   'people',
#   'buenos',
#   'first',
#   'bitcoin',
#   'forum'],
#  20150808: ['crowdfunding',
#   'way',
#   'projec',
#   'future',
#   'use',
#   'case',
#   'blockchain',
#   'technology',
#   'pr',
#   'uber',
#   'statement',
#   'several',
#   'medium',
#   'uber',
#   'million',
#   'dollar',
#   'money',
#   'phrase',
#   'cryptocurrency',
#   'constitutes',
#   'money',
#   'regardless'],
#  20150809: ['bitcoin',
#   'network',
#   'consensus',
#   'meet',
#   'alice',
#   'foundation',
#   'bitcoin',
#   'everyone',
#   'bitcoin',
#   'community',
#   'japan',
#   'japan',
#   'land',
#   'bitcoin'],
#  20150810: ['help',
#   'ben',
#   'new',
#   'york',
#   'depar',
#   'bitlicense',
#   'force',
#   'major',
#   'bitcoin',
#   'business',
#   'millennials',
#   'perfect',
#   'candidate',
#   'millennial',
#   'analysis',
#   'bitcoin',
#   'v',
#   'competitor'],
#  20150811: ['reddit',
#   'popular',
#   'platform',
#   'future',
#   'use',
#   'case',
#   'blockchain',
#   'technology',
#   'many',
#   'people',
#   'afraid',
#   'bitcoin',
#   'bitcoin',
#   'risk',
#   'assessment',
#   'fear',
#   'dig'],
#  20150812: ['dutyfree',
#   'io',
#   'dutyfree',
#   'io',
#   'offering',
#   'discount',
#   'cigarette',
#   'main',
#   'aspect',
#   'life',
#   'future',
#   'use',
#   'case',
#   'blockchain',
#   'technology',
#   'carphone',
#   'warehouse',
#   'cell',
#   'phone',
#   'retailer',
#   'customer',
#   'credit',
#   'card'],
#  20150813: ['report',
#   'bitcoin',
#   'communication',
#   'everyday',
#   'part',
#   'future',
#   'use',
#   'case',
#   'blockchain',
#   'technology',
#   'dec',
#   'bitcoin',
#   'other',
#   'virtual',
#   'currency',
#   'unifying',
#   'bitcoin',
#   'payment',
#   'solution'],
#  20150814: ['multiple',
#   'factor',
#   'responsible',
#   'bitcoin',
#   'community',
#   'responsible',
#   'lack',
#   'virt',
#   'bitcoin',
#   'family',
#   'easy',
#   'bitcoin',
#   'family',
#   'friend',
#   'fed',
#   'cryptocurrency',
#   'fed',
#   'part'],
#  20150815: ['bitcoin',
#   'launch',
#   'negative',
#   'consequence',
#   'improper',
#   'bitcoin',
#   'august',
#   'th',
#   'interesting',
#   'day',
#   'cry',
#   'real',
#   'satoshi',
#   'please',
#   'everyone',
#   'different',
#   'opinion',
#   'low',
#   'fruit',
#   'bitcoin',
#   'adoption',
#   'bitcoin',
#   'supporter',
#   'miner',
#   'coin'],
#  20150816: ['cameron', 'tyler', 'winklevoss', 'exchange', 'gemini'],
#  20150817: ['blockchain',
#   'world',
#   'popular',
#   'bitcoi',
#   'blockchain',
#   'info',
#   'user',
#   'worldwide',
#   'reuters',
#   'news',
#   'article',
#   'bitcoin',
#   'currency',
#   'world',
#   'gradual',
#   'economic',
#   'migratio',
#   'bitcoin',
#   'data',
#   'center',
#   'bitcoin'],
#  20150818: ['safety',
#   'bitcoin',
#   'protocol',
#   'android',
#   'security',
#   'day',
#   'vulnerability',
#   'coinffeine',
#   'new',
#   'peer',
#   'next',
#   'gen',
#   'bitcoin',
#   'exchange',
#   'kristopher',
#   'ives',
#   'software',
#   'developer',
#   'ec',
#   'executive',
#   'order',
#   'reddit',
#   'censorship'],
#  20150819: ['uproar',
#   'bitco',
#   'bigger',
#   'block',
#   'more',
#   'robert',
#   'robert',
#   'rrbi',
#   'bullion',
#   'brokerag',
#   'robert',
#   'robert',
#   'bank',
#   'physical',
#   'bitcoin',
#   'memorabilia',
#   'qui',
#   'review',
#   'bitcoin',
#   'penny',
#   'commemorative',
#   'coin'],
#  20150820: ['company',
#   'service',
#   'daily',
#   'bitcoin',
#   'company',
#   'securi',
#   'many',
#   'people',
#   'death',
#   'damnation',
#   'ba',
#   'nostradamus',
#   'death',
#   'bitcoin',
#   'technical',
#   'analysis',
#   'technical',
#   'analysis',
#   'suitable',
#   'tool',
#   'bitc'],
#  20150821: ['largest',
#   'cryptocurrency',
#   'conference',
#   'south',
#   'inside',
#   'bitcoins',
#   'conference',
#   'korea',
#   'internet',
#   'bitcoin',
#   'promotin',
#   'bitcoin',
#   'bitcoin',
#   'network',
#   'strong',
#   'bitcoin',
#   'node',
#   'day',
#   'bitcoin',
#   'awareness',
#   'ar'],
#  20150822: ['internet',
#   'user',
#   'able',
#   'student',
#   'fingerprint',
#   'authentication',
#   'direct',
#   'relief',
#   'direct',
#   'relief',
#   'changetip',
#   'providing',
#   'vitamin'],
#  20150823: ['idea',
#   'citizen',
#   'specific',
#   'citizenship',
#   'blockchain',
#   'tech',
#   'airbitz',
#   'unique',
#   'bitcoin',
#   'wallet',
#   'service',
#   'wit',
#   'bitcoin',
#   'business',
#   'directory',
#   'wa'],
#  20150824: ['political', 'pundit', 'presidential', 'enemy', 'economy'],
#  20150825: ['cannabis',
#   'industry',
#   'environment',
#   'cannabis',
#   'startup',
#   'bitcoin',
#   'humanity',
#   'age',
#   'disruptio',
#   'age',
#   'disruption',
#   'individual',
#   'anarchism',
#   'gr',
#   'bitfilm',
#   'feature',
#   'film',
#   'satos',
#   'bitfilm',
#   'feature',
#   'film',
#   'satoshi',
#   'la'],
#  20150826: ['advent',
#   'cryptocurrency',
#   'bitcoin',
#   'bitcoin',
#   'blockchain',
#   'case',
#   'new',
#   'reeng',
#   'btcs',
#   'inc',
#   'early',
#   'mover',
#   'bl',
#   'btcs',
#   'report',
#   'loss',
#   'year'],
#  20150827: ['bitcoin', 'eventful', 'summer', 'currency', 'summer', 'bitcoin'],
#  20150828: ['red',
#   'state',
#   'bitcoin',
#   'need',
#   'professional',
#   'digi',
#   'stanford',
#   'university',
#   'bitcoin',
#   'security'],
#  20150829: ['paxful', 'paxful', 'new', 'bitcoin', 'buyer'],
#  20150830: ['new',
#   'initiative',
#   'battle',
#   'california',
#   'shrug',
#   'bill',
#   'internet',
#   'accessible',
#   'introduction',
#   'cypherpunk',
#   'tale'],
#  20150831: ['bitcoin', 'due', 'merchant', 'illusion', 'discount', 'mo'],
#  20150901: ['technology',
#   'everyday',
#   'consumer',
#   'man',
#   'developer',
#   'charge',
#   'new',
#   'day',
#   'encryption',
#   'battle',
#   'encryption'],
#  20150902: ['female',
#   'entrepreneur',
#   'risky',
#   'bitcoin',
#   'entrepreneur',
#   'arou',
#   'bitcoin',
#   'life',
#   'ether',
#   'bitcoin',
#   'introduction',
#   'part'],
#  20150903: ['global',
#   'payment',
#   'system',
#   'hot',
#   'bre',
#   'paypal',
#   'new',
#   'feature',
#   'whit',
#   'jackson',
#   'whit',
#   'jack',
#   'whit',
#   'jack',
#   'bitcoin',
#   'kid'],
#  20150904: ['security',
#   'concern',
#   'intern',
#   'ashley',
#   'madison',
#   'hack',
#   'bitcoin',
#   'money',
#   'bitcoin',
#   'improved',
#   'teller',
#   'machine'],
#  20150905: ['hollywood',
#   'movie',
#   'infamo',
#   'hollywood',
#   'film',
#   'mark',
#   'puerto',
#   'rican',
#   'economy',
#   'volatile',
#   'righ',
#   'puerto',
#   'rico',
#   'benefit'],
#  20150906: ['bitcoin', 'community', 'pillar', 'bitcoin', 'community'],
#  20150907: ['zug',
#   'new',
#   'crypto',
#   'fintech',
#   'netherlands',
#   'state',
#   'bank',
#   'bitcoin',
#   'bank',
#   'acceptance',
#   'dutch',
#   'natio'],
#  20150908: ['own',
#   'bank',
#   'revolution',
#   'chile',
#   'bitcoin',
#   'splendid',
#   'future',
#   'pirate',
#   'party',
#   'offer',
#   'free',
#   'dns',
#   'server'],
#  20150909: ['mother',
#   'dy',
#   'case',
#   'ro',
#   'depth',
#   'interview',
#   'lyn',
#   'ulbricht',
#   'family',
#   'th',
#   'creditor',
#   'meeting',
#   'tokyo',
#   'mt',
#   'gox',
#   'bankruptcy',
#   'dollar',
#   'recent',
#   'day',
#   'lot',
#   'talk',
#   'fcc',
#   'wi',
#   'fi',
#   'proposal',
#   'bitcoin',
#   'node'],
#  20150910: ['payment',
#   'solution',
#   'currency',
#   'answer',
#   'financial',
#   'infrastructur',
#   'bitcoin',
#   'free',
#   'speech',
#   'hand',
#   'hand',
#   'bitcoin',
#   'moderator'],
#  20150911: ['omni',
#   'layer',
#   'bitcoin',
#   'name',
#   'blythe',
#   'master',
#   'prediction',
#   'marketplace',
#   'pivit',
#   'blockcha'],
#  20150912: ['bitcoin',
#   'group',
#   'group',
#   'third',
#   'time',
#   'charm',
#   'scotland',
#   'own',
#   'digita',
#   'scotland',
#   'plan',
#   'own',
#   'digital'],
#  20150913: ['news',
#   'mainstream',
#   'medium',
#   'kid',
#   'bitcoin',
#   'purse',
#   'io',
#   'purse',
#   'io',
#   'plenty',
#   'bitcoin',
#   'arbitrage',
#   'op'],
#  20150914: ['recent',
#   'event',
#   'sentencin',
#   'open',
#   'letter',
#   'ulbricht',
#   'series',
#   'charity',
#   'bitcoin',
#   'charitable',
#   'donation',
#   'table'],
#  20150915: ['many',
#   'bank',
#   'potential',
#   'bank',
#   'blockchain',
#   'dig',
#   'bitfinex',
#   'bitfinex',
#   'clef',
#   'fa',
#   'security',
#   'september',
#   'leading',
#   'expert',
#   'exclusive',
#   'interview',
#   'marc',
#   'bernegger',
#   'fin'],
#  20150916: ['bitcoin',
#   'dominant',
#   'world',
#   'top',
#   'reason',
#   'people',
#   'bitcoin',
#   'barclays',
#   'big',
#   'technology',
#   'uk',
#   'barclays',
#   'bank',
#   'blockchain'],
#  20150917: ['last',
#   'week',
#   'interesting',
#   'topic',
#   'europe',
#   'future',
#   'bitcoin',
#   'new',
#   'kind',
#   'transaction',
#   'platform',
#   'com',
#   'anything',
#   'le',
#   'unacceptable'],
#  20150918: ['surprising',
#   'turn',
#   'event',
#   'popular',
#   'changetip',
#   'enables',
#   'usd',
#   'support',
#   'secret',
#   'most',
#   'everyday',
#   'consumer',
#   'more',
#   'value',
#   'fiat',
#   'currency'],
#  20150919: ['china',
#   'country',
#   'th',
#   'bitcoin',
#   'golden',
#   'ticket',
#   'china',
#   'caput',
#   'jp',
#   'fifth',
#   'largest',
#   'bank',
#   'world',
#   'bitcoin',
#   'bank',
#   'acceptance',
#   'jp',
#   'technology',
#   'bitcoin',
#   'fintechedu',
#   'financial',
#   'giant',
#   'flock',
#   'baft',
#   'bitcoin',
#   'blockchain',
#   'initiative'],
#  20150920: ['brock',
#   'pierce',
#   'member',
#   'bit',
#   'depth',
#   'interview',
#   'brock',
#   'pierce',
#   'multiple',
#   'way',
#   'bitcoin',
#   'bitcoin',
#   'service'],
#  20150921: ['bitcoin', 'network', 'few', 'great', 'bitcoin'],
#  20150922: ['bank',
#   'australia',
#   'australian',
#   'bank',
#   'bitcoin',
#   'arnhem',
#   'city',
#   'eastern',
#   'part',
#   'ne',
#   'discussion',
#   'arnhem',
#   'bitcoinstad',
#   'bitcoin',
#   'major',
#   'financial',
#   'exchange',
#   'provider',
#   'second',
#   'bitcoin',
#   'tracker',
#   'shrem',
#   'bitcoin',
#   'cult',
#   'figure',
#   'shrem',
#   'host',
#   'session',
#   'feder'],
#  20150923: ['bitcoin',
#   'gold',
#   'vaultoro',
#   'surpasses',
#   'gold',
#   'trading',
#   'volume',
#   'boston',
#   'bitcoin',
#   'startup',
#   'circle',
#   'financial',
#   'bitlicense',
#   'circle',
#   'early',
#   'day',
#   'bitcoin',
#   'thing',
#   'quit',
#   'bitcoin',
#   'personality',
#   'gpu',
#   'arm'],
#  20150924: ['bitcoin',
#   'com',
#   'overwhelming',
#   'undertaki',
#   'official',
#   'bitcoin',
#   'com',
#   'forum',
#   'launch',
#   'chance',
#   'fidelity',
#   'bank',
#   'list',
#   'numb',
#   'factom',
#   'blockchain',
#   'bitcoin',
#   'use',
#   'steam',
#   'africa',
#   'africa',
#   'central',
#   'banker',
#   'bit'],
#  20150925: ['passion',
#   'blockchain',
#   'technology',
#   'blockchain',
#   'time',
#   'man',
#   'journey',
#   'kid',
#   'phe',
#   'game',
#   'equal',
#   'job',
#   'russia',
#   'report',
#   'russia',
#   'bitcoin',
#   'criminal',
#   'liability',
#   'biggest',
#   'chinese',
#   'currency',
#   'intervention',
#   'china',
#   'latin',
#   'american',
#   'business'],
#  20150926: ['bitcoin',
#   'business',
#   'key',
#   'mijin',
#   'combine',
#   'blockchains',
#   'citigroup',
#   'inc',
#   'bank',
#   'acceptance',
#   'citi',
#   'piece',
#   'hardware',
#   'bitcoi',
#   'bitcoin',
#   'hardware',
#   'software',
#   'que'],
#  20150927: ['south',
#   'american',
#   'country',
#   'south',
#   'american',
#   'economy',
#   'recession',
#   'brazil',
#   'bitfury',
#   'bitfury',
#   'georgian',
#   'technology',
#   'park',
#   'ashley',
#   'madison',
#   'titcoin',
#   'co',
#   'founder',
#   'ashley',
#   'madison'],
#  20150928: ['revelation',
#   'silk',
#   'road',
#   'federal',
#   'agent',
#   'btc',
#   'silk',
#   'roa',
#   'letter',
#   'second',
#   'series',
#   'open',
#   'open',
#   'letter',
#   'ulbricht',
#   'reflection',
#   'bitcoin',
#   'easy',
#   'ch',
#   'binary',
#   'option',
#   'bitcoin',
#   'lot',
#   'criticism',
#   'sin',
#   'bitcoin',
#   'commodity',
#   'label',
#   'positive',
#   'news'],
#  20150929: ['editor',
#   'article',
#   'bitpay',
#   'attack',
#   'bitcoin',
#   'conference',
#   'event',
#   'similarity',
#   'difference',
#   'maker',
#   'mov'],
#  20150930: ['administrator',
#   'bitcoin',
#   'com',
#   'ashley',
#   'madison',
#   'user',
#   'com',
#   'help'],
#  20151001: ['trutv',
#   'premiere',
#   'trutv',
#   'adam',
#   'conover',
#   'cannot',
#   'bitcoin',
#   'year',
#   'old',
#   'louison',
#   'dumont',
#   'french',
#   'interview',
#   'bitproof',
#   'creator',
#   'louison',
#   'dumont',
#   'startup',
#   'accelerator',
#   'major',
#   'com',
#   'startup',
#   'accelerator',
#   'sponsorship'],
#  20151002: ['japan',
#   'largest',
#   'platform',
#   'okwave',
#   'bitcoin',
#   'bittorrent',
#   'client',
#   'joystream',
#   'user',
#   'bandwidth',
#   'bitfilm',
#   'festival',
#   'bitfilm',
#   'festival',
#   'competition'],
#  20151003: ['time',
#   'machine',
#   'dark',
#   'journey',
#   'bi',
#   'bitlanders',
#   'bitcharities',
#   'social',
#   'medium',
#   'dif',
#   'lot',
#   'people',
#   'mainstream',
#   'medium',
#   'money',
#   'bitcoin',
#   'fiat',
#   'unlikely'],
#  20151004: ['day',
#   'age',
#   'accelerated',
#   'role',
#   'blockchain',
#   'technology',
#   'freedom',
#   'gambling',
#   'oldest',
#   'form',
#   'enterta',
#   'peer',
#   'solution',
#   'way',
#   'forward'],
#  20151005: ['hardware',
#   'wallet',
#   'reality',
#   'mo',
#   'conversation',
#   'alena',
#   'vranova',
#   'satoshila',
#   'long',
#   'awaited',
#   'launch',
#   'gemini',
#   'bitcoin',
#   'exchange',
#   'first',
#   'look',
#   'year',
#   'bank',
#   'acceptance',
#   'street',
#   'investor',
#   'wall',
#   'street',
#   'woe',
#   'bitcoin',
#   'investm'],
#  20151006: ['bitcoin',
#   'com',
#   'bitcoin',
#   'com',
#   'warrant',
#   'canary',
#   'first',
#   'first',
#   'russian',
#   'language',
#   'bitcoin',
#   'documentary',
#   'bitcoin',
#   'adoption',
#   'world',
#   'patient',
#   'internet',
#   'connectivity',
#   'boost',
#   'bitc'],
#  20151007: ['post',
#   'circle',
#   'bitcoin',
#   'remittance',
#   'reddit',
#   'safe',
#   'haven',
#   'fo',
#   'reddit',
#   'launch',
#   'upvoted',
#   'news',
#   'site',
#   'bitcoin'],
#  20151008: ['bitpay',
#   'bitpay',
#   'ingenico',
#   'bitcoin',
#   'terminal',
#   'online',
#   'marketplace',
#   'bitmarkets',
#   'party',
#   'escrow'],
#  20151009: ['anyone',
#   'world',
#   'financial',
#   'bitcoin',
#   'economy',
#   'hand',
#   'hand',
#   'european',
#   'court',
#   'justice',
#   'saf',
#   'end',
#   'safe',
#   'harbor',
#   'agreement',
#   'new',
#   'bitcoin',
#   'atm',
#   'ocean',
#   'beach',
#   'san',
#   'diego',
#   'new',
#   'ocean',
#   'beach',
#   'bitcoin',
#   'welcome',
#   'fall',
#   'edition',
#   'top',
#   'ra',
#   'fall',
#   'top',
#   'bitcoin',
#   'exchange',
#   'fall',
#   'edition',
#   'top',
#   'ra',
#   'fall',
#   'top',
#   'bitcoin',
#   'wallet'],
#  20151010: ['recent',
#   'medium',
#   'boost',
#   'vc',
#   'stats',
#   'investe',
#   'ernit',
#   'rea',
#   'meet',
#   'digital',
#   'currency',
#   'bank',
#   'bitcoin',
#   'hand',
#   'mainstream',
#   'starbucks',
#   'customer',
#   'bit'],
#  20151011: ['month', 'year', 'end', 'bitcoin', 'final', 'countdown'],
#  20151012: ['system',
#   'platform',
#   'blockchain',
#   'technology',
#   'future',
#   'fac',
#   'com',
#   'bitcoin',
#   'com',
#   'wiki',
#   'money',
#   'past',
#   'year',
#   'bitcoin',
#   'exchange',
#   'bitcoin',
#   'exchange',
#   'climate',
#   'australia'],
#  20151013: ['computer',
#   'giant',
#   'dell',
#   'crypto',
#   'company',
#   'openledger',
#   'fintech',
#   'exchange',
#   'openledger',
#   'la',
#   'igot',
#   'bitcoin',
#   'exchange',
#   'bitcoin',
#   'exchange',
#   'update',
#   'cu',
#   'financial',
#   'sector',
#   'global',
#   'tr',
#   'finance',
#   'fintech',
#   'bitcoin',
#   'boomin'],
#  20151014: ['technological',
#   'advancement',
#   'day',
#   'age',
#   'holy',
#   'trinity',
#   'medical',
#   'record',
#   'commerce',
#   'trend',
#   'wor',
#   'role',
#   'bitcoin',
#   'mobile',
#   'commerce',
#   'blockstream',
#   'seed',
#   'several',
#   'bitcoin',
#   'exchange',
#   'partner',
#   'blockst',
#   'many',
#   'indicator',
#   'civiliz',
#   'programmable',
#   'economy',
#   'internet',
#   'thin'],
#  20151015: ['bitcoin',
#   'price',
#   'btc',
#   'usd',
#   'bitcoin',
#   'price',
#   'bit',
#   'bitcoin',
#   'california',
#   'bitcoin',
#   'wallet',
#   'airbitz',
#   'beta',
#   'exchange',
#   'bi',
#   'coindesk',
#   'latest',
#   'coindesk',
#   'state',
#   'bitcoin',
#   'report',
#   'couple',
#   'week',
#   'blockchains',
#   'interview',
#   'ta'],
#  20151016: ['exceptional',
#   'case',
#   'power',
#   'mainstream',
#   'medium',
#   'outlet',
#   'popular',
#   'gaming',
#   'marketplace',
#   'kinguin'],
#  20151017: ['announcement',
#   'january',
#   'anticip',
#   'gemini',
#   'volume',
#   'bitc',
#   'everybody',
#   'world',
#   'chance',
#   'behavioral',
#   'analytics',
#   'insight',
#   'angus',
#   'deaton',
#   'nob',
#   'economics',
#   'nobel',
#   'winner',
#   'deaton',
#   'pair',
#   'san',
#   'francisco',
#   'sibling',
#   'parlay',
#   'phone',
#   'app',
#   'friend',
#   'wag',
#   'due',
#   'rapid',
#   'acceleration',
#   'technology',
#   'blockchain',
#   'technology',
#   'supply',
#   'chain',
#   'ev'],
#  20151018: ['bitcoin',
#   'accessible',
#   'convenient',
#   'bitcoin',
#   'payment',
#   'terminal',
#   'bitcoin',
#   'atm',
#   'whi',
#   'private',
#   'network',
#   'different',
#   'bl',
#   'private',
#   'network',
#   'blockchains',
#   'time',
#   'money',
#   'sure',
#   'interview',
#   'ceo',
#   'wallach'],
#  20151019: ['alma',
#   'sommer',
#   'brian',
#   'stith',
#   'parent',
#   'undocumented',
#   'human',
#   'life',
#   'government',
#   'october',
#   'keene',
#   'keenevention',
#   'bitcoin',
#   'panel',
#   'shire',
#   'coinimal',
#   'coinimal',
#   'paypal',
#   'service'],
#  20151020: ['san',
#   'mateo',
#   'ready',
#   'blockchain',
#   'technology',
#   'guide',
#   'helpful',
#   'visitin',
#   'safe',
#   'guide',
#   'bitcoin',
#   'traveler',
#   'uk',
#   'micro',
#   'job',
#   'important',
#   'aspect',
#   'decentra',
#   'bitcoin',
#   'payment',
#   'perfect',
#   'sense',
#   'outsou'],
#  20151021: ['belief',
#   'large',
#   'portion',
#   'bitcoi',
#   'beware',
#   'bitcoin',
#   'economy',
#   'borderless',
#   'block',
#   'party',
#   'month',
#   'college',
#   'bitcoin',
#   'payment',
#   'company',
#   'bitpay',
#   'beta',
#   'exchange',
#   'copay',
#   'wallet',
#   'bitcoin',
#   'coinpoint',
#   'full',
#   'service',
#   'bitcoin',
#   'wallet',
#   'space',
#   'brief',
#   'look',
#   'bitcoin',
#   'wallet',
#   'statistic'],
#  20151022: ['money',
#   'interesting',
#   'thing',
#   'future',
#   'bitcoin',
#   'vehicle',
#   'google',
#   'jab',
#   'microsoft',
#   'google',
#   'cloud',
#   'attack',
#   'world',
#   'multitude',
#   'problem',
#   'nimber',
#   'logistics',
#   'system'],
#  20151023: ['october',
#   'th',
#   'google',
#   'youtube',
#   'content',
#   'user',
#   'society',
#   'easy',
#   'task',
#   'mobility',
#   'self',
#   'car',
#   'blockchai'],
#  20151024: ['traditional',
#   'enterprise',
#   'storage',
#   'traditional',
#   'enterprise',
#   'storage',
#   'group',
#   'individual',
#   'digital',
#   'currency',
#   'blockchain',
#   'alliance',
#   'bitcoin',
#   'law',
#   'department',
#   'justice',
#   'attempt',
#   'doj',
#   'apple',
#   'user',
#   'dev'],
#  20151025: ['internet',
#   'thing',
#   'iot',
#   'many',
#   'technolo',
#   'cannot',
#   'new',
#   'economy',
#   'suzanne',
#   'nguyen',
#   'bright',
#   'cuff',
#   'yo',
#   'meerkat',
#   'star',
#   'suzanne',
#   'nguyen',
#   'dream',
#   'bitcoin',
#   'lot',
#   'talk',
#   'day',
#   'key',
#   'car',
#   'innovation',
#   'com',
#   'few',
#   'new',
#   'mo',
#   'bitcoin',
#   'com',
#   'forum',
#   'star',
#   'ama',
#   'event'],
#  20151026: ['bitcoin',
#   'fervent',
#   'energy',
#   'bitcoin',
#   'alliance',
#   'european',
#   'union',
#   'bit',
#   'odd',
#   'creature',
#   'society',
#   'digital',
#   'age',
#   'today',
#   'alphapoint',
#   'announces',
#   'private',
#   'blockchain',
#   'soluti'],
#  20151027: ['most',
#   'people',
#   'bitcoin',
#   'com',
#   'fo',
#   'reddit',
#   'show',
#   'disrespect',
#   'biggest',
#   'bi',
#   'sport',
#   'fan',
#   'kind',
#   'authority',
#   'fantasy',
#   'sport',
#   'gamblin',
#   'fydis',
#   'present',
#   'app',
#   'onli'],
#  20151028: ['imagine',
#   'moment',
#   'hive',
#   'win',
#   'america',
#   'hackathon',
#   'financial',
#   'technology',
#   'bitcoin',
#   'com',
#   'fintech',
#   'blockchain',
#   'hottest',
#   'topic',
#   'business',
#   'worl',
#   'gender',
#   'imbalance',
#   'bitcoin',
#   'eco'],
#  20151029: ['intriguing',
#   'topic',
#   'bitco',
#   'bitcoin',
#   'company',
#   'successful',
#   'yesterday',
#   'united',
#   'state',
#   'senate',
#   'cybersecurity',
#   'threat',
#   'bil',
#   'bitcoin',
#   'wallet',
#   'provider',
#   'ninki',
#   'bitcoin',
#   'wallet',
#   'plan',
#   'grothe',
#   'møller',
#   'art',
#   'history',
#   'stud',
#   'social',
#   'technical',
#   'activism'],
#  20151030: ['offer',
#   'good',
#   'true',
#   'miner',
#   'center',
#   'premium',
#   'price',
#   'bitcoin',
#   'chance',
#   'ceo',
#   'bitcoin',
#   'exchange',
#   'wallet',
#   'ceo',
#   'participa',
#   'bitcoin',
#   'bit',
#   'curiosity',
#   'th',
#   'bitfilm',
#   'festival',
#   'vote',
#   'favorite'],
#  20151031: ['russian',
#   'ministry',
#   'finance',
#   'russian',
#   'bitcoiners',
#   'innovation',
#   'useful',
#   'manifestation',
#   'idea',
#   'blockchain',
#   'innovati',
#   'june',
#   'cryptocurrency',
#   'dash',
#   'dash',
#   'node',
#   'count'],
#  20151101: ['lbry',
#   'decentralized',
#   'sharing',
#   'platform',
#   'technology',
#   'house',
#   'ledger',
#   'bitcoin',
#   'blockchain',
#   'debit',
#   'card',
#   'popular',
#   'stricter',
#   'pre',
#   'card',
#   'regulation'],
#  20151102: ['bitcoin',
#   'private',
#   'key',
#   'bitcoin',
#   'security',
#   'internet',
#   'thing',
#   'biggest',
#   'ama',
#   'event',
#   'history',
#   'bitcoi',
#   'biggest',
#   'bitcoin',
#   'ama',
#   'event',
#   'histo',
#   'live',
#   'question',
#   'answer',
#   'session',
#   'circle',
#   'ceo',
#   'jeremy',
#   'allaire',
#   'talk',
#   'th',
#   'government',
#   'world',
#   'encryption',
#   'cold',
#   'war',
#   'government',
#   'v',
#   'internet'],
#  20151103: ['money',
#   'unique',
#   'thing',
#   'money',
#   'side',
#   'bitcoin',
#   'theory',
#   'history',
#   'bitcoin',
#   'new',
#   'ground',
#   'bitcoin',
#   'shuttle',
#   'bitcoin',
#   'price',
#   'recent',
#   'change',
#   'mainstre',
#   'blockchain',
#   'bitcoin',
#   'big',
#   'banking',
#   'babble'],
#  20151104: ['largest',
#   'ama',
#   'event',
#   'bitcoin',
#   'history',
#   'start',
#   'bitcoin',
#   'ama',
#   'recap',
#   'gavin',
#   'andresen',
#   'jeremy',
#   'bitcoin',
#   'ama',
#   'event',
#   'full',
#   'bitcoin',
#   'ama',
#   'recap',
#   'wences',
#   'kristov',
#   'first',
#   'waffle',
#   'house',
#   'door',
#   'restaurant',
#   'waffle',
#   'house'],
#  20151105: ['today',
#   'day',
#   'history',
#   'bitcoin',
#   'biggest',
#   'bitcoin',
#   'ama',
#   'history',
#   'ben',
#   'davenport',
#   'lot',
#   'excitement',
#   'discus',
#   'bitcoin',
#   'basic'],
#  20151106: ['social',
#   'network',
#   'zapchain',
#   'coinbase',
#   'enable',
#   'digital',
#   'compensation',
#   'money',
#   'powerful',
#   'drug',
#   'psychologicall',
#   'bitcoin',
#   'psychology'],
#  20151107: ['alexandria',
#   'knowledge',
#   'database',
#   'friday',
#   'weekend',
#   'bitcoin',
#   'ama',
#   'november',
#   'jeff',
#   'garzik',
#   'marsha',
#   'today',
#   'start',
#   'first',
#   'weekend',
#   'bitcoin',
#   'ama',
#   'november',
#   'mike',
#   'hearn',
#   'ognasty',
#   'influenced',
#   'transaction',
#   'malleability',
#   'attack'],
#  20151108: ['bitcoin',
#   'exchange',
#   'itbit',
#   'tradeblock',
#   'blockchains',
#   'big',
#   'data',
#   'super',
#   'sunday',
#   'occurrence',
#   'bitcoin',
#   'ama',
#   'november',
#   'super',
#   'sunday',
#   'davi',
#   'today',
#   'appreciated',
#   'theme',
#   'bitcoin',
#   'simple',
#   'security',
#   'guide',
#   'online'],
#  20151109: ['psychedelic',
#   'drug',
#   'bitcoin',
#   'psychedelic',
#   'drug',
#   'term',
#   'blockchain',
#   'hottest',
#   'co',
#   'blockchain',
#   'pr',
#   'image',
#   'average',
#   'coinify',
#   'denmark',
#   'payment',
#   'processor',
#   'coinify',
#   'merchant'],
#  20151110: ['many',
#   'recent',
#   'bitcoin',
#   'price',
#   'incre',
#   'bitcoin',
#   'global',
#   'purchase',
#   'volume',
#   'double',
#   'more',
#   'people',
#   'job',
#   'new',
#   'economy',
#   'job',
#   'bitcoin',
#   'bitcoin',
#   'blockchain',
#   'technology',
#   'satoshi',
#   'nakamoto'],
#  20151111: ['former',
#   'former',
#   'reddit',
#   'cryptocurrency',
#   'engineer',
#   'california',
#   'discussion',
#   'andrew',
#   'lee',
#   'purse',
#   'io',
#   'global',
#   'computer',
#   'powerhouse',
#   'microsoft',
#   'launch',
#   'new',
#   'cloud',
#   'thing',
#   'people',
#   'fiat',
#   'currency',
#   'bitcoin',
#   'free',
#   'fro',
#   'few',
#   'real',
#   'world',
#   'application',
#   'card',
#   'interview',
#   'georgy'],
#  20151112: ['metaexchange',
#   'metaexchange',
#   'selling',
#   'asset',
#   'token',
#   'prof',
#   'many',
#   'topic',
#   'discussion',
#   'day',
#   'diversity',
#   'beneficial',
#   'free',
#   'keene',
#   'bitcoin',
#   'machine',
#   'anniversary'],
#  20151113: ['house',
#   'year',
#   'bitcoin',
#   'third',
#   'annual',
#   'latin',
#   'american',
#   'bitcoin',
#   'confer',
#   'latin',
#   'american',
#   'bitcoin',
#   'conference',
#   'sneak',
#   'most',
#   'people',
#   'bitcoin',
#   'com',
#   'ama',
#   'recap',
#   'star',
#   'te',
#   'world',
#   'bitcoin',
#   'advance',
#   'bank',
#   'app',
#   'bitwage'],
#  20151114: ['bitcoin',
#   'com',
#   'official',
#   'sponsor',
#   'bitcoin',
#   'com',
#   'bitcoin',
#   'ii',
#   'bitcoin',
#   'community',
#   'infra',
#   'traditional',
#   'business',
#   'bitcoin',
#   'new',
#   'invention',
#   'bitcoin',
#   'business',
#   'insi'],
#  20151115: ['note',
#   'article',
#   'exchange',
#   'solvency',
#   'bitsh',
#   'first',
#   'konrad',
#   'graf',
#   'bitcoin',
#   'greatest',
#   'shortage',
#   'investment',
#   'opportuniti',
#   'delta',
#   'business',
#   'management',
#   'bitcoin',
#   'inve'],
#  20151116: ['airbitz',
#   'company',
#   'buy',
#   'feature',
#   'secret',
#   'nasdaq',
#   'close',
#   'nasdaq',
#   'blockchain',
#   'technology',
#   'judge',
#   'judy',
#   'bitcoin'],
#  20151117: ['bitcoin',
#   'digital',
#   'currency',
#   'initiative',
#   'mi',
#   'bitcoin',
#   'exchange',
#   'attack',
#   'updated',
#   'spell',
#   'genesis',
#   'inte',
#   'spell',
#   'genesis',
#   'early',
#   'beta',
#   'access',
#   'available',
#   'bank',
#   'other',
#   'unnece',
#   'belgian',
#   'pretend',
#   'crowdfunding'],
#  20151118: ['many',
#   'form',
#   'employment',
#   'website',
#   'bitcoin',
#   'freelance',
#   'job',
#   'proper',
#   'label',
#   'value',
#   'money',
#   'bitbond',
#   'new',
#   'big',
#   'mac',
#   'index',
#   'current',
#   'banking',
#   'system',
#   'fiat',
#   'currency',
#   'banking',
#   'system',
#   'obsolete',
#   'bitcoin',
#   'th'],
#  20151119: ['new',
#   'york',
#   'coin',
#   'mx',
#   'operator',
#   'guilty',
#   'dam',
#   'bitcoin',
#   'community',
#   'relief',
#   'effort',
#   'mari',
#   'various',
#   'bank',
#   'other',
#   'financial',
#   'institution',
#   'bankchain',
#   'part',
#   'implementation',
#   'problem',
#   'new',
#   'bitcoin',
#   'debit',
#   'card',
#   'bitcoin',
#   'debit',
#   'card',
#   'shift'],
#  20151120: ['bitcoin',
#   'skeptic',
#   'economist',
#   'jeffrey',
#   'denmark',
#   'cashless',
#   'society',
#   'economic',
#   'apartheid',
#   'new',
#   'south',
#   'wale',
#   'world',
#   'quantum',
#   'computer',
#   'possible',
#   'af'],
#  20151121: ['bitfury',
#   'bitcoin',
#   'smooth',
#   'ride',
#   'eur',
#   'european',
#   'union',
#   'bitcoin',
#   'high',
#   'card',
#   'fee',
#   'bor',
#   'reason',
#   'bitcoin',
#   'credit',
#   'card'],
#  20151122: ['bitcoin',
#   'adoption',
#   'mainstream',
#   'capacity',
#   'duo',
#   'blockchain',
#   'inter',
#   'few',
#   'outside',
#   'bit',
#   'bitcoin',
#   'currency',
#   'nxt',
#   'reveals',
#   'plan',
#   'bankchain',
#   'part',
#   'different',
#   'type'],
#  20151123: ['concept',
#   'bankchains',
#   'bankchain',
#   'part',
#   'iii',
#   'iou',
#   'bitcoin',
#   'com',
#   'blockchain',
#   'transition',
#   'power',
#   'bitcoin',
#   'zapchain',
#   'growth',
#   'viable'],
#  20151124: ['company',
#   'active',
#   'bitcoin',
#   'world',
#   'mainstream',
#   'medium',
#   'company',
#   'following',
#   'article',
#   'reader',
#   'submission',
#   'bitcoin',
#   'family',
#   'tha'],
#  20151125: ['bitcoin',
#   'com',
#   'wall',
#   'st',
#   'veteran',
#   'bitcoin',
#   'interesting',
#   'topic',
#   'bitco',
#   'death',
#   'note',
#   'incentive',
#   'system',
#   'price',
#   'bitcoin',
#   'bitcoin',
#   'big',
#   'mac',
#   'index',
#   'albre'],
#  20151126: ['kynetix',
#   'kynetix',
#   'blockchain',
#   'commodity',
#   'mar',
#   'bitcoin',
#   'outsider',
#   'bitcoin',
#   'new',
#   'global',
#   'currency',
#   'traditional',
#   'black',
#   'friday',
#   'victim',
#   'bitcoin',
#   'black',
#   'silver',
#   'lining',
#   'new',
#   'bitcoin',
#   'device',
#   'tixie',
#   'bitcoin',
#   'price',
#   'ticker'],
#  20151127: ['tuesday',
#   'november',
#   'uhuru',
#   'kenyatta',
#   'president',
#   'nominates',
#   'board',
#   'membe',
#   'recent',
#   'false',
#   'accusation',
#   'various',
#   'public',
#   'blockchain',
#   'bo',
#   'bitcoin',
#   'improvement',
#   'proposal',
#   'reusable',
#   'payment',
#   'code',
#   'privacy'],
#  20151128: ['american',
#   'airline',
#   'paymen',
#   'american',
#   'airline',
#   'argentin',
#   'note',
#   'editor',
#   'letter',
#   'lates',
#   'open',
#   'letter',
#   'ulbricht',
#   'true',
#   'libertar',
#   'past',
#   'few',
#   'month',
#   'clear',
#   'blockchain',
#   'technology',
#   'idea',
#   'bank'],
#  20151129: ['apple',
#   'pay',
#   'plan',
#   'china',
#   'adv',
#   'apple',
#   'pay',
#   'entrance',
#   'china',
#   'mean',
#   'holiday',
#   'season',
#   'bitcoin',
#   'line',
#   'social',
#   'messaging',
#   'futur',
#   'new',
#   'era',
#   'international',
#   'travel',
#   'worker'],
#  20151130: ['ol',
#   'physical',
#   'silver',
#   'bitcoin',
#   'wallet',
#   'early',
#   'technologist',
#   'ear',
#   'building',
#   'ramp',
#   'bitcoin',
#   'ecosystem',
#   'bitcoin',
#   'company',
#   'australia',
#   'bitcoin',
#   'grows',
#   'australia',
#   'coordinated'],
#  20151201: ['central',
#   'bank',
#   'country',
#   'central',
#   'bank',
#   'barbados',
#   'proposes',
#   'stock',
#   'market',
#   'nxt',
#   'asset',
#   'exchange',
#   'world',
#   'technology',
#   'pocket',
#   'sized',
#   'pc',
#   'offer',
#   'multiple',
#   'advantage'],
#  20151202: ['course',
#   'previous',
#   'article',
#   'bankchain',
#   'part',
#   'exchange',
#   'guest',
#   'post',
#   'erik',
#   'voorhees',
#   'appeal',
#   'zero',
#   'conf',
#   'many',
#   'way',
#   'digital',
#   'currency',
#   'bitcoin',
#   'new',
#   'uk',
#   'report',
#   'prof',
#   'terrorism',
#   'few',
#   'day',
#   'european',
#   'central',
#   'bank',
#   'impact',
#   'instant',
#   'sepa',
#   'transfer',
#   'europe'],
#  20151203: ['biggest',
#   'bitcoin',
#   'ama',
#   'event',
#   'history',
#   'st',
#   'bitcoin',
#   'com',
#   'ama',
#   'recap',
#   'antonopoulos',
#   'blockchain',
#   'info',
#   'sneak',
#   'peek',
#   'new',
#   'blockchain',
#   'hd',
#   'washington',
#   'sec',
#   'gaw',
#   'miner',
#   'ceo',
#   'bitcoin'],
#  20151204: ['wake',
#   'clampdown',
#   'daily',
#   'fantasy',
#   'sp',
#   'new',
#   'reality',
#   'fantasy',
#   'sport',
#   'mycelium',
#   'bitcoin',
#   'wallet',
#   'provider',
#   'close',
#   'bitcoin',
#   'har',
#   'great',
#   'thing',
#   'bitcoin',
#   'multisig',
#   'address',
#   'bit',
#   'hitchhiker',
#   'invisible',
#   'internet',
#   'long',
#   'mycelium',
#   'card',
#   'network'],
#  20151205: ['everyone',
#   'part',
#   'bitcoin',
#   'community',
#   'bitcoin',
#   'blockchain',
#   'coinbase',
#   'depth',
#   'look',
#   'coinbase',
#   'bitcoin',
#   'exchange',
#   'month',
#   'launch',
#   'facebook',
#   'latin',
#   'america',
#   'taringa',
#   'greek',
#   'government',
#   'move',
#   'greek',
#   'asset',
#   'declaration',
#   'battle',
#   'war'],
#  20151206: ['bitcoin',
#   'computer',
#   'suffers',
#   'percept',
#   'jeff',
#   'garzik',
#   'bitcoin',
#   'marketplace',
#   'amazon',
#   'etsy',
#   'bitcoin',
#   'com',
#   'bitcoin',
#   'com',
#   'video',
#   'scientific',
#   'discovery',
#   'technological',
#   'innov',
#   'driverless',
#   'car',
#   'bitcoin',
#   'th',
#   'san',
#   'francisco',
#   'crypto',
#   'company',
#   'purse',
#   'io',
#   'new',
#   'project',
#   'tritium'],
#  20151207: ['criminal',
#   'use',
#   'bitcoin',
#   'free',
#   'market',
#   'secret',
#   'india',
#   'india',
#   'mobile',
#   'internet',
#   'boom',
#   'way',
#   'december',
#   'th',
#   'developer',
#   'chris',
#   'elli',
#   'full',
#   'bitcoin',
#   'node',
#   'scaling',
#   'bitcoin',
#   'workshop',
#   'hong',
#   'kong'],
#  20151208: ['overstock',
#   'com',
#   'bitcoin',
#   'blockchain',
#   'fraud',
#   'report',
#   'uncommon',
#   'day',
#   'bitcoin',
#   'user',
#   'financial',
#   'socia',
#   'bank',
#   'expensive',
#   'inaccessible',
#   'many',
#   'credit',
#   'union',
#   'winning',
#   'formula'],
#  20151209: ['bit',
#   'discussion',
#   'concern',
#   'witness',
#   'concept',
#   'poi',
#   'cnbc',
#   'th',
#   'blockchain',
#   'bitcoin',
#   'note',
#   'editor',
#   'letter',
#   'lates',
#   'open',
#   'letter',
#   'ulbricht',
#   'happy'],
#  20151210: ['recent',
#   'attempt',
#   'iden',
#   'satoshi',
#   'irrelevant',
#   'quest',
#   'bitcoin',
#   'com',
#   'craig',
#   'sellars',
#   'craig',
#   'sellars',
#   'figure',
#   'bitcoin',
#   'black',
#   'friday',
#   'bitcoin',
#   'merchant',
#   'price',
#   'growth'],
#  20151211: ['recent',
#   'terror',
#   'attack',
#   'paris',
#   'french',
#   'gov',
#   'mull',
#   'public',
#   'wifi',
#   'tor',
#   'german',
#   'startup',
#   'iot',
#   'ethereum',
#   'computer',
#   'money',
#   'mental',
#   'association',
#   'peopl',
#   'crypto',
#   'psychology',
#   'initiation',
#   'text',
#   'unde'],
#  20151212: ['inside',
#   'ib',
#   'conference',
#   'blockchain',
#   'agenda',
#   'event',
#   'seoul',
#   'henry',
#   'jones',
#   'name',
#   'mysterious',
#   'man',
#   'wh',
#   'bitholla',
#   'homeless',
#   'mystery',
#   'man',
#   'largest',
#   'bank',
#   'sberbank',
#   'largest',
#   'bank',
#   'sberbank',
#   'confident'],
#  20151213: ['main',
#   'reason',
#   'bitcoin',
#   'block',
#   'gregory',
#   'maxwell',
#   'gavin',
#   'interest',
#   'many',
#   'problem',
#   'crisis',
#   'taki',
#   'ukranian',
#   'national',
#   'bank',
#   'interest',
#   'mauricio',
#   'macri',
#   'new',
#   'president',
#   'new',
#   'president',
#   'bitc'],
#  20151214: ['note',
#   'editor',
#   'letter',
#   'lates',
#   'open',
#   'letter',
#   'ulbricht',
#   'pain',
#   're',
#   'bitcoin',
#   'accessible',
#   'mycelium',
#   'swish',
#   'let',
#   'order',
#   'food',
#   'bill',
#   'year',
#   'solid',
#   'year',
#   'prof',
#   'bitcoin'],
#  20151215: ['fereshteh',
#   'forough',
#   'project',
#   'code',
#   'afghan',
#   'woman',
#   'people',
#   'active',
#   'bitcoin',
#   'ecosystem',
#   'wall',
#   'street',
#   'bullish',
#   'central',
#   'bank',
#   'kenya',
#   'cbk',
#   'central',
#   'bank',
#   'public'],
#  20151216: ['time',
#   'look',
#   'spell',
#   'genesis',
#   'introduces',
#   'player',
#   'world',
#   'unprecedented',
#   'pace',
#   'crypto',
#   'smart',
#   'contract',
#   'bitcoin',
#   'mining',
#   'game',
#   'undergone',
#   'several',
#   'bitfury',
#   'unveils',
#   'fastest',
#   'bitcoin',
#   'chip',
#   'ev'],
#  20151217: ['news',
#   'breakthrough',
#   'quantum',
#   'mechanic',
#   'internet',
#   'thing',
#   'holiday',
#   'typical',
#   'sentime',
#   'way',
#   'bitcoin',
#   'holiday',
#   'season',
#   'search',
#   'bitcoin',
#   'year',
#   'bitcoin',
#   'adoption'],
#  20151218: ['andreas',
#   'company',
#   'company',
#   'fintech',
#   'third',
#   'bringing',
#   'bitcoin',
#   'consumer',
#   'new',
#   'use',
#   'case',
#   'approacha',
#   'smart',
#   'contract',
#   'buzz',
#   'cry',
#   'ethereum',
#   'enthusiasm',
#   'devcon',
#   'interview',
#   'wi'],
#  20151219: ['mexico',
#   'city',
#   'hunt',
#   'satoshi',
#   'nakamoto',
#   'comic',
#   'book',
#   'andreas',
#   'antonopoulos',
#   'case',
#   'id',
#   'andreas',
#   'case',
#   'zerocoin',
#   'protocol',
#   'first',
#   'implementation',
#   'zerocoin',
#   'int'],
#  20151220: ['biggest',
#   'bitcoin',
#   'ama',
#   'history',
#   'bitcoin',
#   'ama',
#   'recap',
#   'factom',
#   'electrum',
#   'pantera',
#   'cat',
#   'life',
#   'bitcoin',
#   'dead',
#   'people',
#   'early',
#   'adoption',
#   'ph',
#   'knowledge',
#   'miner',
#   'next',
#   'early',
#   'adopter'],
#  20151221: ['spending',
#   'bitcoin',
#   'critical',
#   'part',
#   'bitcoin',
#   'payment',
#   'last',
#   'week',
#   'article',
#   'free',
#   'state',
#   'bitcoin',
#   'prohibition',
#   'headline',
#   'few',
#   'parallel',
#   'fintech',
#   'bitcoin',
#   'startup',
#   'mar',
#   'hour',
#   'multiple',
#   'bitcoins',
#   'tr',
#   'share',
#   'news',
#   'bitcoin',
#   'com',
#   'press'],
#  20151222: ['biggest',
#   'ama',
#   'event',
#   'bitcoin',
#   'ama',
#   'wu',
#   'jihan',
#   'bitmain',
#   'global',
#   'release',
#   'bitcoin',
#   'creation',
#   'legacy',
#   'bank',
#   'sure',
#   'pottersville',
#   'tale',
#   'blockchain',
#   'dream',
#   'team',
#   'day',
#   'block',
#   'size',
#   'debate',
#   'end'],
#  20151223: ['internet',
#   'connectivity',
#   'integral',
#   'role',
#   'high',
#   'speed',
#   'intern',
#   'arlington',
#   'va',
#   'december',
#   'btcs',
#   'crypto',
#   'blockchain',
#   'bitcoin',
#   'mythical',
#   'blockchain',
#   'bitcoin'],
#  20151224: ['vladimir',
#   'putin',
#   'blockchain',
#   'boston',
#   'enigma',
#   'data',
#   'private',
#   'google',
#   'company',
#   'blockchain'],
#  20151225: ['christmas',
#   'bitcoin',
#   'meme',
#   'crypto',
#   'graphic',
#   'million',
#   'people',
#   'world',
#   'big',
#   'bank',
#   'thousand',
#   'new',
#   'york',
#   'major',
#   'drawback',
#   'fintech',
#   'payment',
#   'distance',
#   'wireless',
#   'mo'],
#  20151226: ['cryptography',
#   'smart',
#   'contract',
#   'cou',
#   'crypto',
#   'smart',
#   'contract',
#   'internet',
#   'nano',
#   'thing',
#   'iont',
#   'internet',
#   'nano',
#   'thing',
#   'bitcoin',
#   'world',
#   'payment',
#   'addressing',
#   'paypal',
#   'touch',
#   'security',
#   'concern'],
#  20151227: ['day',
#   'christmas',
#   'bitcoin',
#   'price',
#   'bearish',
#   'major',
#   'topic',
#   'concern',
#   'china',
#   'internet',
#   'bitc'],
#  20151228: ['new',
#   'cryptesla',
#   'ransomware',
#   'round',
#   'ransomware',
#   'attack',
#   'large',
#   'uk',
#   'news',
#   'site',
#   'demand',
#   'financial',
#   'sector',
#   'main',
#   'taiwan',
#   'economic',
#   'woe',
#   'bitco',
#   'bitcoin',
#   'enthusiast',
#   'blockchain',
#   'investor',
#   'mar',
#   'marc',
#   'internet',
#   'th'],
#  20151229: ['course',
#   'recent',
#   'year',
#   'brea',
#   'blockchain',
#   'technology',
#   'today',
#   'best',
#   'defense',
#   'legacy',
#   'banking',
#   'institution',
#   'bank',
#   'more',
#   'ground',
#   'time',
#   'year',
#   'many',
#   'people',
#   'reason',
#   'christ'],
#  20151230: ['inc',
#   'computer',
#   'library',
#   'offer',
#   'enab',
#   'rapid',
#   'growth',
#   'digital',
#   'age',
#   'internet',
#   'therapy',
#   'bit',
#   'international',
#   'trade',
#   'bitcoin',
#   'blockchain',
#   'futu'],
#  20151231: ['privacy',
#   'centric',
#   'instant',
#   'cryptocur',
#   'dash',
#   'lamassu',
#   'integration',
#   'new',
#   'york',
#   'nasdaq',
#   'blockchain',
#   'linq',
#   'issue',
#   'chain',
#   'sh',
#   'bitcoin',
#   'fun',
#   'run',
#   'company',
#   'infra'],
#  20160101: ['secret',
#   'china',
#   'communication',
#   'bringing',
#   'additional',
#   'security',
#   'payment',
#   'se',
#   'magspoof',
#   'insecure',
#   'plastic',
#   'card',
#   'people',
#   'europe',
#   'ne',
#   'eu',
#   'taxpayer',
#   'bank',
#   'bailouts'],
#  20160102: ['technological',
#   'advance',
#   'massive',
#   'soci',
#   'techno',
#   'anarchy',
#   'blockchain',
#   'tech',
#   'india',
#   'headline',
#   'concern',
#   'bitcoin',
#   'best',
#   'form',
#   'money',
#   'holiday',
#   'time',
#   'unwanted',
#   'gift',
#   'th'],
#  20160103: ['nothing',
#   'alarming',
#   'luddite',
#   'mentality',
#   'ode',
#   'block',
#   'size',
#   'drama',
#   'ne',
#   'bitcoin',
#   'adoption',
#   'worl',
#   'outernet',
#   'more',
#   'real',
#   'life',
#   'use',
#   'case'],
#  20160104: ['father',
#   'child',
#   'value',
#   'bitcoin',
#   'kid',
#   'bitcoin',
#   'killer',
#   'apps',
#   'decentralized',
#   'marketplace',
#   'bitcoin',
#   'world',
#   'economy',
#   'frail',
#   'stat',
#   'bitcoin',
#   'ecosystem',
#   'potential',
#   'br'],
#  20160105: ['ireland',
#   'silk',
#   'road',
#   'moderator',
#   'extradition',
#   'lithuania',
#   'interest',
#   'lithuania',
#   'show',
#   'serious',
#   'intention',
#   'blockc',
#   'fan',
#   'data',
#   'chart',
#   'comparative',
#   'chart',
#   'analysis',
#   'bitcoin',
#   'bl'],
#  20160106: ['eu',
#   'bitcoin',
#   'exchange',
#   'bitstamp',
#   'gold',
#   'delivery',
#   'withdrawal',
#   'op',
#   'big',
#   'year',
#   'bitcoi',
#   'year',
#   'satoshi',
#   'traditional',
#   'banking',
#   'application',
#   'polit',
#   'politician',
#   'bank',
#   'update',
#   'article',
#   'bitcoin',
#   'principle',
#   'microeconomics'],
#  20160107: ['concept',
#   'cross',
#   'border',
#   'marketplace',
#   'soluti',
#   'proper',
#   'cross',
#   'border',
#   'marketplace',
#   'wit',
#   'bitcoin',
#   'virtual',
#   'reality'],
#  20160108: ['many',
#   'people',
#   'perfect',
#   'blockchain',
#   'major',
# ...
#   'thai',
#   'bank',
#   'account',
#   'local',
#   'cryptocu',
#   'popular',
#   'cryptocurrency',
#   'exchange',
#   'coinbase',
#   'irs',
#   'cu',
#   'coindash',
#   'eth',
#   'return',
#   'uzbekistan',
#   'road',
#   'legal',
#   'uzbekistan',
#   'bitcoin',
#   'support',
#   'dev',
#   'marketing',
#   'direc',
#   'arras',
#   'prepares',
#   'bitcoin',
#   'titl',
#   'resident',
#   'state',
#   'georgia',
#   'lawmaker',
#   'propose',
#   'tax',
#   'amendment'],
#  20180226: ['bitfract',
#   'beta',
#   'new',
#   'ser',
#   'bitfract',
#   'let',
#   'cryptocurrency',
#   'bitcoin',
#   'free',
#   'people',
#   'payment',
#   'merchant',
#   'explicit',
#   'recent',
#   'claim',
#   'bitcoin',
#   'navy',
#   'investigator',
#   'bitcoin',
#   'drug',
#   'payment',
#   'company',
#   'circle',
#   'exchange',
#   'poloniex',
#   'past',
#   'day',
#   'usd',
#   'market',
#   'market',
#   'update',
#   'volume',
#   'weaker',
#   'btc',
#   'price',
#   'anarchapulco',
#   'event',
#   'last',
#   'week',
#   'review',
#   'swiss',
#   'digital',
#   'bitbox',
#   'year',
#   'old',
#   'andrew',
#   'courey',
#   'massac',
#   'sixth',
#   'grader',
#   'page',
#   'book',
#   'bitcoin',
#   'crypto',
#   'world',
#   'ar',
#   'hacker',
#   'chic',
#   'get',
#   'bitcoin',
#   'periodic',
#   'table',
#   'crypto',
#   'life',
#   'everything',
#   'week',
#   'bitcoin',
#   'everything',
#   'price',
#   'many',
#   'major',
#   'cryptocurrency',
#   'exchange',
#   'icos',
#   'exchange',
#   'sign',
#   'ups',
#   'create',
#   'boom',
#   'aut',
#   'czech',
#   'inclined',
#   'value',
#   'cry',
#   'poll',
#   'more',
#   'popular',
#   'czech',
#   'february',
#   'award',
#   'most',
#   'ina',
#   'people',
#   'understand',
#   'cryptocurrency',
#   'sho',
#   'past',
#   'few',
#   'week',
#   'many',
#   'people',
#   'noti',
#   'transaction',
#   'good',
#   'fee',
#   'bad',
#   'poland',
#   'ministry',
#   'finance',
#   'repor',
#   'refutes',
#   'report',
#   'interest',
#   'vene'],
#  20180227: ['thirty',
#   'country',
#   'european',
#   'commiss',
#   'country',
#   'glob',
#   'multitude',
#   'representative',
#   'law',
#   'enforcem',
#   'hardcore',
#   'criminal',
#   'supreme',
#   'court',
#   'israel',
#   'temporary',
#   'israeli',
#   'supreme',
#   'court',
#   'forbids',
#   'bank',
#   'denyin',
#   'japanese',
#   'cryptocurrency',
#   'exchange',
#   'coincheck',
#   'japanese',
#   'exchange',
#   'considers',
#   'tie',
#   'angel',
#   'investor',
#   'founder',
#   'chinese',
#   'app',
#   'meit',
#   'chinese',
#   'entrepreneur',
#   'warns',
#   'mining',
#   'last',
#   'year',
#   'apple',
#   'co',
#   'founder',
#   'wozniak',
#   'apple',
#   'co',
#   'founder',
#   'steve',
#   'wozniak',
#   'bitcoin',
#   'major',
#   'thai',
#   'bank',
#   'terminat',
#   'thai',
#   'bank',
#   'shuts',
#   'account',
#   'local',
#   'bitwala',
#   'bitwala',
#   'full',
#   'crypto',
#   'lot',
#   'talk',
#   'th',
#   'la',
#   'stripper',
#   'bitcoin',
#   'qr',
#   'tattoo',
#   'past',
#   'few',
#   'month',
#   'government',
#   'justice',
#   'cryptocurrency'],
#  20180228: ['week',
#   'bitcoin',
#   'friendly',
#   'financial',
#   'in',
#   'digital',
#   'currency',
#   'group',
#   'friend',
#   'several',
#   'lawyer',
#   'cha',
#   'lawyer',
#   'challenge',
#   'cryptocurr',
#   'more',
#   'graphic',
#   'card',
#   'report',
#   'crypto',
#   'miner',
#   'gpus',
#   'la',
#   'week',
#   'bitcoin',
#   'cash',
#   'network',
#   'more',
#   'infrastructure',
#   'support',
#   'bitcoin',
#   'japan',
#   'kumamoto',
#   'energy',
#   'local',
#   'power',
#   'japanese',
#   'electricity',
#   'company',
#   'excess',
#   'solar',
#   'low',
#   'income',
#   'area',
#   'city',
#   'detroit',
#   'se',
#   'bitcoin',
#   'atm',
#   'michigan',
#   'most',
#   'popul',
#   'scheme',
#   'tweet',
#   'scammer',
#   'crypto',
#   'twitter',
#   'twitte',
#   'debate',
#   'bitcoin',
#   'craig',
#   'satoshi',
#   'wright',
#   'billion',
#   'le',
#   'hour',
#   'today',
#   'stance',
#   'bitcoin',
#   'chairman',
#   'switzerland',
#   'stock',
#   'exchange',
#   'swiss',
#   'stock',
#   'exchange',
#   'chairman',
#   'nation',
#   'uk',
#   'man',
#   'living',
#   'amsterdam',
#   'british',
#   'man',
#   'amsterdam',
#   'world',
#   'affluent',
#   'person',
#   'bill',
#   'bill',
#   'crypto',
#   'death'],
#  20180301: ['moscow',
#   'bankruptcy',
#   'court',
#   'cry',
#   'court',
#   'crypto',
#   'debt',
#   'payment',
#   'fr',
#   'chart',
#   'lot',
#   'crypto',
#   'asset',
#   'transaction',
#   'data',
#   'crypto',
#   'recession',
#   'dutch',
#   'multinational',
#   'financial',
#   'provider',
#   'rabo',
#   'dutch',
#   'bank',
#   'bitcoin',
#   'high',
#   'risk',
#   'week',
#   'institutional',
#   'counter',
#   'genesis',
#   'launch',
#   'crypto',
#   'loan',
#   'service',
#   'security',
#   'exchange',
#   'commission',
#   'sec',
#   'subpoena',
#   'icos',
#   'towards',
#   'regulation',
#   'cryptocurrency',
#   'investing',
#   'goldmoney',
#   'cash',
#   'cold',
#   'monday',
#   'circle',
#   'poloniex',
#   'deal',
#   'future',
#   'cr',
#   'allure',
#   'free',
#   'electricity',
#   'louisiana',
#   'attorney',
#   'general',
#   'staff',
#   'state',
#   'financial',
#   'monitoring',
#   'service',
#   'ukra',
#   'ukraine',
#   'financial',
#   'watchdog',
#   'clarifies',
#   'venezuelan',
#   'government',
#   'new',
#   'cl',
#   'venezuela',
#   'claim',
#   'cryptocurrency',
#   'thai',
#   'government',
#   'grow',
#   'thai',
#   'regulator',
#   'race',
#   'popularit',
#   'week',
#   'popular',
#   'cryptocurrency',
#   'service',
#   'coinbase',
#   'change',
#   'tax',
#   'private',
#   'business',
#   'world',
#   'future',
#   'employee',
#   'week',
#   'local',
#   'japanese',
#   'news',
#   'outlet',
#   'report',
#   'customer',
#   'class',
#   'action',
#   'lawsuit',
#   'company',
#   'firm',
#   'license',
#   'crypto',
#   'small',
#   'island',
#   'nation',
#   'le',
#   'offshore',
#   'tax',
#   'haven',
#   'island',
#   'saint',
#   'petersburg',
#   'city',
#   'court',
#   'court',
#   'strike',
#   'ban',
#   'bitcoin',
#   'site'],
#  20180302: ['week',
#   'company',
#   'proud',
#   'bitcoin',
#   'com',
#   'wallet',
#   'russia',
#   'ministry',
#   'telecom',
#   'mass',
#   'communic',
#   'russian',
#   'ministry',
#   'offer',
#   'crypto',
#   'excha',
#   'digital',
#   'marketing',
#   'guide',
#   'cauti',
#   'single',
#   'tweet',
#   'walto',
#   'late',
#   'bitcoin',
#   'payment',
#   'processor',
#   'bit',
#   'bitpay',
#   'launch',
#   'cash',
#   'debit',
#   'card',
#   'top',
#   'ups',
#   'germany',
#   'lead',
#   'european',
#   'union',
#   'germany',
#   'tread',
#   'bitcoin',
#   'taxation',
#   'commissioner',
#   'financial',
#   'stability',
#   'financia',
#   'eu',
#   'patience',
#   'urge',
#   'global',
#   'crypto',
#   'regul',
#   'audience',
#   'intelligence',
#   'compan',
#   'data',
#   'company',
#   'crypto',
#   'adoption',
#   'soci',
#   'cryptocurrency',
#   'enthusiast',
#   'australia',
#   'australian',
#   'new',
#   'agency',
#   'fract',
#   'cryptocurrency',
#   'exchange',
#   'app',
#   'government',
#   'crypto',
#   'exchange',
#   'north',
#   'korea',
#   'north',
#   'korea',
#   'bitcoins',
#   'tax',
#   'exemption',
#   'profit',
#   'crypto',
#   'crypto',
#   'tax',
#   'break',
#   'official',
#   'russia',
#   'time',
#   'sentence',
#   'day',
#   'cryptocurrency',
#   'scam',
#   'largest',
#   'institutional',
#   'jp',
#   'morgan',
#   'chase',
#   'fear',
#   'crypto',
#   'disruptive',
#   'com',
#   'regional',
#   'report',
#   'china',
#   'police',
#   'police',
#   'force',
#   'reveals',
#   'exchange',
#   'australia',
#   'new',
#   'legislatio',
#   'aussie',
#   'crypto',
#   'trader',
#   'tax',
#   'crackdown',
#   'ahe'],
#  20180303: ['latest',
#   'cryptocurrency',
#   'project',
#   'easy',
#   'neo',
#   'chinese',
#   'blockchain',
#   'neo',
#   'success',
#   'total',
#   'disa',
#   'week',
#   'private',
#   'bank',
#   'liechtenstein',
#   'bank',
#   'offer',
#   'holder',
#   'mobile',
#   'cybersecurity',
#   'firm',
#   'sikur',
#   'new',
#   'hack',
#   'proof',
#   'security',
#   'phone',
#   'featur',
#   'mexico',
#   'bill',
#   'cryptocurrency',
#   'mexican',
#   'cryptocurrency',
#   'regulation',
#   'satoshi',
#   'revolution',
#   'revolution',
#   'wendy',
#   'mcelroy',
#   'silence',
#   'soul',
#   'crypto',
#   'government',
#   'ecuador',
#   'rebel',
#   'bitcoiners',
#   'ecuador',
#   'open',
#   'first',
#   'crypto',
#   'cryptocurrency',
#   'market',
#   'rise',
#   'market',
#   'update',
#   'crypto',
#   'market',
#   'cash',
#   'bch',
#   'roll',
#   'scorin',
#   'quarter',
#   'dollar',
#   'bitc',
#   'cryptocurrency',
#   'investment',
#   'belgian',
#   'tax',
#   'authority',
#   'crypto',
#   'inves',
#   'technology',
#   'young',
#   'tweens',
#   'next',
#   'generation',
#   'politician',
#   'cry'],
#  20180304: ['class',
#   'action',
#   'lawsuit',
#   'coinb',
#   'class',
#   'action',
#   'complaint',
#   'coinbase',
#   'concern',
#   'russian',
#   'trader',
#   'bittrex',
#   'block',
#   'resident',
#   'north',
#   'korea',
#   'iran',
#   'major',
#   'network',
#   'pawn',
#   'shop',
#   'ukraine',
#   'la',
#   'major',
#   'pawnshop',
#   'network',
#   'ukraine',
#   'launching',
#   'cr',
#   'last',
#   'week',
#   'new',
#   'anti',
#   'money',
#   'new',
#   'malaysian',
#   'cryptocurrency',
#   'regulation',
#   'canada',
#   'hottest',
#   'destin',
#   'bitfarms',
#   'crypt',
#   'report',
#   'major',
#   'manufacturer',
#   'grap',
#   'gpu',
#   'producer',
#   'drop',
#   'demand',
#   'crypto',
#   'cryptocurrency',
#   'market',
#   'today',
#   'wall',
#   'bitcoin',
#   'dominance',
#   'indian',
#   'crypto',
#   'token',
#   'marketplace',
#   'indian',
#   'token',
#   'marketplace',
#   'trading',
#   'bitgo',
#   'jameson',
#   'lopp',
#   'bitgo',
#   'employe',
#   'jameson',
#   'lopp',
#   'bitgo',
#   'casa',
#   'walle',
#   'local',
#   'police',
#   'iceland',
#   'crime',
#   'mil',
#   'bitcoi',
#   'interest',
#   'cryptocurrency',
#   'kazakhstan',
#   'interest',
#   'cryptocurrency',
#   'fold'],
#  20180305: ['crypto',
#   'regulation',
#   'ru',
#   'kaliningrad',
#   'offer',
#   'tax',
#   'break',
#   'bitco',
#   'time',
#   'economic',
#   'uncertainty',
#   'bitcoin',
#   'flou',
#   'ripple',
#   'soar',
#   'coinbase',
#   'rumor',
#   'recent',
#   'patent',
#   'filing',
#   'reveals',
#   'paypal',
#   'file',
#   'patent',
#   'expedited',
#   'cryptocurren',
#   'march',
#   'international',
#   'pro',
#   'liberty',
#   'non',
#   'liberty',
#   'con',
#   'freedom',
#   'bitcoin',
#   'korea',
#   'real',
#   'name',
#   'system',
#   'cryptocurre',
#   'korea',
#   'mandatory',
#   'crypto',
#   'real',
#   'name',
#   'system',
#   'supreme',
#   'court',
#   'russia',
#   'russian',
#   'supreme',
#   'court',
#   'fate',
#   'bi',
#   'past',
#   'week',
#   'popular',
#   'cr',
#   'cryptocurrency',
#   'exchange',
#   'withdrawal',
#   'fee',
#   'genesis',
#   'block',
#   'symbolism',
#   'law',
#   'agency',
#   'success',
#   'year',
#   'old',
#   'sent',
#   'prison',
#   'bitcoin',
#   'bitcoin',
#   'internet',
#   'week',
#   'bitcoin',
#   'courtroom',
#   'day',
#   'average',
#   'number',
#   'daily',
#   'btc',
#   'transaction',
#   'volume',
#   'year',
#   'low'],
#  20180306: ['myspace',
#   'facebook',
#   'analogy',
#   'decentralized',
#   'exchange',
#   'idex',
#   'interest',
#   'towards',
#   'belarus',
#   'more',
#   'belarusian',
#   'crypto',
#   'question',
#   'le',
#   'asia',
#   'cryptocurrency',
#   'recep',
#   'taiwanese',
#   'airline',
#   'cryptocurrency',
#   'pay',
#   'country',
#   'share',
#   'underperfo',
#   'chinese',
#   'altcoins',
#   'controversial',
#   'owner',
#   'web',
#   'portal',
#   'bitc',
#   'curious',
#   'case',
#   'cobra',
#   'pecul',
#   'hft',
#   'giant',
#   'virtu',
#   'target',
#   'appa',
#   'high',
#   'frequency',
#   'trading',
#   'firm',
#   'threatens',
#   'week',
#   'creator',
#   'cashaddress',
#   'custom',
#   'cash',
#   'address',
#   'south',
#   'korean',
#   'travel',
#   'website',
#   'south',
#   'korean',
#   'travel',
#   'site',
#   'hote',
#   'new',
#   'initial',
#   'coin',
#   'offering',
#   'ico',
#   'miro',
#   'bank',
#   'ico',
#   'miroskii',
#   'entire',
#   'tea',
#   'week',
#   'japanese',
#   'financial',
#   'service',
#   'mana',
#   'sbi',
#   'holding',
#   'claim',
#   'stake',
#   'hardw',
#   'grayscale',
#   'investment',
#   'launch',
#   'grayscale',
#   'launch',
#   'investment',
#   'trust',
#   'russian',
#   'ministry',
#   'finance',
#   'russia',
#   'draft',
#   'law',
#   'use',
#   'cr',
#   'québec',
#   'canada',
#   'interested',
#   'bank',
#   'bitcoin',
#   'odd',
#   'bedfellow',
#   'data',
#   'reveals',
#   'banking',
#   'sector',
#   'south',
#   'korean',
#   'government',
#   'de',
#   'korean',
#   'government',
#   'official',
#   'fr'],
#  20180307: ['brazil',
#   'security',
#   'exchange',
#   'commission',
#   'brazilian',
#   'security',
#   'exchange',
#   'commission',
#   'stable',
#   'bittrex',
#   'competitor',
#   'trueusd',
#   'regu',
#   'number',
#   'domain',
#   'cryptocurrency',
#   'mini',
#   'cryptocurrency',
#   'mining',
#   'cryptocurrency',
#   'retirement',
#   'account',
#   'firm',
#   'bit',
#   'retirement',
#   'account',
#   'solution',
#   'bitira',
#   'offer',
#   'court',
#   'financial',
#   'regulator',
#   'legislator',
#   'bitcoin',
#   'commodity',
#   'platform',
#   'venezuela',
#   'pick',
#   'platform',
#   'petro',
#   'language',
#   'learner',
#   'student',
#   'cryptocurrency',
#   'ico',
#   'blockchain',
#   'spring',
#   'discussion',
#   'attack',
#   'optimization',
#   'slush',
#   'pool',
#   'world',
#   'richest',
#   'people',
#   'wealthy',
#   'crypto',
#   'don',
#   'popular',
#   'exchange',
#   'coinbase',
#   'coinbase',
#   'first',
#   'crypto',
#   'index',
#   'fund',
#   'firm',
#   'crescent',
#   'electric',
#   'suppl',
#   'new',
#   'study',
#   'cost',
#   'btc',
#   'cryptocurrency',
#   'community',
#   'full',
#   'entrep',
#   'marshall',
#   'sovereign',
#   'cryptocurre',
#   'speculative',
#   'instrument',
#   'un',
#   'russian',
#   'social',
#   'networking',
#   'platform',
#   'popular',
#   'social',
#   'network',
#   'russia',
#   'bi'],
#  20180308: ['mt',
#   'gox',
#   'mark',
#   'release',
#   'bail',
#   'gox',
#   'soap',
#   'opera',
#   'karpeles',
#   'release',
#   'binance',
#   'center',
#   'bot',
#   'binance',
#   'bug',
#   'trader',
#   'month',
#   'law',
#   'firm',
#   'llp',
#   'pu',
#   'research',
#   'paper',
#   'issuer',
#   'ico',
#   'token',
#   'week',
#   'popular',
#   'wallet',
#   'provider',
#   'bread',
#   'wallet',
#   'provider',
#   'bread',
#   'bitcoin',
#   'cash',
#   'suppor',
#   'wednesday',
#   'regulator',
#   'sec',
#   'unlawful',
#   'crypto',
#   'previous',
#   'effort',
#   'th',
#   'chinese',
#   'internet',
#   'regulator',
#   'cryptocurren',
#   'gmo',
#   'internet',
#   'monthly',
#   'report',
#   'japanese',
#   'conglomerate',
#   'gmo',
#   'bitco',
#   'major',
#   'hardware',
#   'producer',
#   'venture',
#   'new',
#   'player',
#   'asrock',
#   'gpu',
#   'price',
#   'marke',
#   'market',
#   'update',
#   'crypto',
#   'value',
#   'drop',
#   'japanese',
#   'financial',
#   'regulator',
#   'japan',
#   'punishes',
#   'cryptocurrency',
#   'exchange',
#   'stau',
#   'ex',
#   'trump',
#   'chief',
#   'strategist',
#   'bannon',
#   'cryptocurren',
#   'korean',
#   'crypto',
#   'exchange',
#   'bithumb',
#   'bithumb',
#   'kiosk',
#   'restaurant',
#   'fo',
#   'business',
#   'india',
#   'regulatory',
#   'loophole',
#   'startup',
#   'india',
#   'ac',
#   'more',
#   'half',
#   'romanian',
#   'city',
#   'young',
#   'romanian',
#   'last',
#   'week',
#   'official',
#   'small',
#   'town',
#   'pla',
#   'plattsburgh',
#   'official',
#   'bitcoin',
#   'miner'],
#  20180309: ['talk',
#   'increased',
#   'regulation',
#   'icos',
#   'brush',
#   'regulatory',
#   'concern',
#   'japanese',
#   'exchange',
#   'coincheck',
#   'coincheck',
#   'hack',
#   'victim',
#   'new',
#   'crypto',
#   'debit',
#   'card',
#   'multiple',
#   'currency',
#   'wirex',
#   'bitcoin',
#   'debit',
#   'card',
#   'europe',
#   'singlepoint',
#   'payment',
#   'sol',
#   'singlepoint',
#   'launch',
#   'payment',
#   'solution',
#   'french',
#   'company',
#   'qarnot',
#   'crypto',
#   'heater',
#   'mine',
#   'digital',
#   'currency',
#   'whi',
#   'cryptocurrency',
#   'worming',
#   'broa',
#   'lil',
#   'windex',
#   'problem',
#   'last',
#   'month',
#   'spate',
#   'high',
#   'profil',
#   'most',
#   'forked',
#   'coin',
#   'more',
#   'hassle',
#   'public',
#   'document',
#   'mining',
#   'giant',
#   'ant',
#   'creek',
#   'new',
#   'type',
#   'credit',
#   'card',
#   'user',
#   'credit',
#   'card',
#   'user',
#   'environment',
#   'har',
#   'europe',
#   'clock',
#   'slow',
#   'crypto',
#   'mi',
#   'cryptocurrency',
#   'popularity',
#   'russia',
#   'russian',
#   'bitcoin',
#   'great',
#   'present',
#   'course',
#   'past',
#   'few',
#   'week',
#   'cryptocurrency',
#   'interest',
#   'wane',
#   'searche'],
#  20180310: ['personal',
#   'computer',
#   'hacker',
#   'computer',
#   'mining',
#   'australian',
#   'authority',
#   'bit',
#   'bitcoin',
#   'sport',
#   'site',
#   'investigatio',
#   'conjunction',
#   'various',
#   'administrat',
#   'bitcoin',
#   'auction',
#   'drug',
#   'bust',
#   'week',
#   'wall',
#   'street',
#   'analyst',
#   'bitcoin',
#   'misery',
#   'index',
#   'entry',
#   'way',
#   'thai',
#   'deputy',
#   'prime',
#   'minister',
#   'th',
#   'thailand',
#   'dodge',
#   'cryptocurrency',
#   'belgian',
#   'financial',
#   'authority',
#   'belgium',
#   'warns',
#   'cryptocurrency',
#   'trading',
#   'egyptian',
#   'government',
#   'report',
#   'show',
#   'cryptocu',
#   'bitcoin',
#   'cash',
#   'bch',
#   'market',
#   'look',
#   'week',
#   'cash',
#   'market'],
#  ...}

# %%
date_token_dict.values()
# Out:
# dict_values([['week', 'beginning', 'alleged', 'silk', 'ro', 'bitcoin', 'news', 'roundup', 'january', 'th'], ['coinbase', 'completion', 'bitcoin', 'news', 'roundup', 'january', 'th'], ['last', 'week', 'timer', 'news', 'roundup', 'february', 'st'], ['few', 'week', 'new', 'hampshire', 'house', 're', 'bitcoin', 'news', 'roundup', 'february', 'nd'], ['move', 'reminiscent', 'time', 'bitcoin', 'news', 'roundup', 'march', 'st'], ['ultra', 'stealth', 'bitcoin', 'company', 'name', 'bitcoin', 'news', 'roundup', 'march', 'th'], ['commerce', 'giant', 'bitcoin', 'news', 'roundup', 'march', 'nd'], ['bitcoin', 'news', 'roundup', 'march', 'th'], ['circle', 'internet', 'financial', 'ltd', 'news', 'roundup'], ['welcome', 'new', 'bitcoin', 'com'], ['close', 'bitcoin', 'news', 'roundup'], ['future', 'bitcoin', 'journalism', 'current', 'financial', 'infrastructure', 'ecosy', 'red', 'cross', 'donation', 'astray', 'time'], ['bitcoin', 'encryption', 'freedo'], ['sidechains', 'development', 'blockstream', 'release', 'sidechain', 'prototype'], ['wednesday', 'june', 'rd', 'new', 'york', 'department', 'bitcoin', 'news', 'roundup', 'june', 'th', 'regardless', 'thing', 'bitcoin', 'charitable', 'cause', 'bi'], ['mainstream', 'medium', 'blockchain', 'ownership'], ['bitcoin', 'bank', 'bi'], ['various', 'company', 'world', 'consumerism', 'debit', 'card'], ['think', 'business', 'blockchain', 'digitization'], ['blockchain', 'technology', 'data'], ['video', 'game', 'play', 'role', 'mo'], ['prolific', 'aspect', 'bitcoin', 'bitcoin', 'way', 'value', 'technology', 'power', 'digital', 'technology', 'bu'], ['most', 'people', 'bitcoin', 'community', 'tha', 'credit', 'work', 'bitcoin', 'economy'], ['bitcoin', 'network', 'improper', 'network', 'block', 'validation', 'mastercard', 'test', 'facial', 'recognition', 'technology'], ['more', 'popular', 'way', 'bitco', 'bitcoin', 'documentary', 'oudated', 'time', 'blockchain', 'technology', 'corporation', 'btc', 'global', 'inc', 'blockchai'], ['complex', 'greek', 'crisis', 'professor', 'crisis', 'solution', 'pressing', 'debate', 'world', 'european', 'head', 'data', 'protection', 'le'], ['first', 'time', 'history', 'gold', 'gold', 'backseat', 'greek', 'mtgox', 'bankruptcy', 'truste', 'deadline', 'mtgox', 'bankruptcy', 'claim', 'bitcoin', 'blockchain', 'technology', 'bitmessage', 'proper', 'peer'], ['editor', 'note', 'article', 'legal', 'fear', 'ross', 'ulbricht', 'appeal', 'many', 'eye', 'greece', 'china', 'stock', 'market'], ['debate', 'bitcoin', 'gold', 'gold', 'innovative', 're', 'current', 'age', 'digital', 'technology', 'power', 'consumer', 'bitcoin', 'digital', 'currency', 'heralde', 'bitcoin', 'pillar'], ['june', 'nyse', 'tra', 'bitcoin', 'do', 'light', 'matter', 'security', 'privacy', 'director', 'call', 'decryption', 'tool'], ['bitcoin', 'other', 'technology', 'interactive', 'education', 'robot', 'bitlicense', 'controversial', 'ben', 'lawsky', 'door', 'bitcoin', 'recent', 'talk', 'discussion', 'digital', 'governance'], ['surprise', 'anyone', 'world', 'next', 'logical', 'step', 'rise', 'inside', 'chicago', 'conference', 'bitgive', 'foundation', 'new', 'initiative', 'adoption', 'rate', 'bitcoin', 'center', 'chicago', 'bitcoin', 'incu'], ['bitcoin', 'regardless', 'coinbase', 'outage', 'reminder', 'bit', 'article', 'sterlin', 'blockchain', 'towards', 'sovereignty'], ['august', 'rd', 'keynote', 'fintech', 'conferenc', 'keynote', 'ledger', 'main', 'concern', 'bitcoin', 'whet', 'bitcoin', 'review', 'interesting', 'trend', 'bitcoin', 'service', 'user', 'account', 'data'], ['bitcoin', 'uphill', 'battle', 'cash', 'v', 'bitcoin', 'bitcoin', 'superior', 'people', 'dollar', 'force', 'mathematics', 'fiat', 'v', 'cryptocurrency', 'overstock', 'patrick', 'byrne', 'com', 'able'], ['first', 'quarter', 'bitcoin', 'venture', 'bitcoin', 'investment', 'numbe', 'week', 'vladimir', 'russian', 'vladimir', 'putin', 'favor', 'bitcoin', 'online', 'marketplace', 'bitcoin', 'transparent', 'marketplace'], ['imagine', 'mother', 'pretend', 'bitcoin', 'm ...

# %% [markdown]
# # ■ Frequently metioned countries

# %%
countries = ['japanese','chinese','korean','russian','indian','uk']

# %%
con_df = pd.DataFrame()

for i in countries:
    date = [int(str(i)[0:4]) for i in list(date_token_dict.keys())]
    freq = list(map(lambda x: x.count(i), list(date_token_dict.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])

# %% [markdown]
# ## 2017.x Distribution

# %%
con_df = pd.DataFrame()

dict_for_month = {k: v for k, v in date_token_dict.items() if k > 20170101 and k < 20180101}

for i in countries:
    date = [int(str(i)[4:6]) for i in list(dict_for_month.keys())]
    freq = list(map(lambda x: x.count(i), list(dict_for_month.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])

# %% [markdown]
# ## 2017.11.x Distribution

# %%
con_df = pd.DataFrame()

dict_for_month = {k: v for k, v in date_token_dict.items() if k > 20171101 and k < 20171201}

for i in countries:
    date = [int(str(i)[6:8]) for i in list(dict_for_month.keys())]
    freq = list(map(lambda x: x.count(i), list(dict_for_month.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])

# %% [markdown]
# ## 2017.12.x Distribution

# %%
con_df = pd.DataFrame()

dict_for_month = {k: v for k, v in date_token_dict.items() if k > 20171201 and k < 20180101}

for i in countries:
    date = [int(str(i)[6:8]) for i in list(dict_for_month.keys())]
    freq = list(map(lambda x: x.count(i), list(dict_for_month.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])

# %% [markdown]
# ## 2018.x Distribution

# %%
con_df = pd.DataFrame()

dict_for_month = {k: v for k, v in date_token_dict.items() if k > 20180101 and k < 20190101}

for i in countries:
    date = [int(str(i)[4:6]) for i in list(dict_for_month.keys())]
    freq = list(map(lambda x: x.count(i), list(dict_for_month.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])

# %% [markdown]
# ## 2018.1.x Distribution

# %%
con_df = pd.DataFrame()

dict_for_month = {k: v for k, v in date_token_dict.items() if k > 20171231 and k < 20180201}

for i in countries:
    date = [int(str(i)[6:8]) for i in list(dict_for_month.keys())]
    freq = list(map(lambda x: x.count(i), list(dict_for_month.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])

# %% [markdown]
# # ■ Frequently mentioned words

# %%
words = ['mining','regulation','platform','security','miner','investor','government','tax','currency','exchange']

# %%
con_df = pd.DataFrame()

for i in words:
    date = list(date_token_dict.keys())
    freq = list(map(lambda x: x.count(i), list(date_token_dict.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])

# %% [markdown]
# ## 2017.x Distribution

# %%
con_df = pd.DataFrame()

dict_for_month = {k: v for k, v in date_token_dict.items() if k > 20170101 and k < 20180101}

for i in words:
    date = [int(str(i)[4:6]) for i in list(dict_for_month.keys())]
    freq = list(map(lambda x: x.count(i), list(dict_for_month.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])

# %% [markdown]
# ## 2017.11.x Distribution

# %%
con_df = pd.DataFrame()

dict_for_month = {k: v for k, v in date_token_dict.items() if k > 20171101 and k < 20171201}

for i in words:
    date = [int(str(i)[6:8]) for i in list(dict_for_month.keys())]
    freq = list(map(lambda x: x.count(i), list(dict_for_month.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])

# %% [markdown]
# ## 2017.12.x Distribution

# %%
con_df = pd.DataFrame()

dict_for_month = {k: v for k, v in date_token_dict.items() if k > 20171201 and k < 20180101}

for i in words:
    date = [int(str(i)[6:8]) for i in list(dict_for_month.keys())]
    freq = list(map(lambda x: x.count(i), list(dict_for_month.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])

# %% [markdown]
# ## 2018.x Distribution

# %%
con_df = pd.DataFrame()

dict_for_month = {k: v for k, v in date_token_dict.items() if k > 20180101 and k < 20190101}

for i in words:
    date = [int(str(i)[4:6]) for i in list(dict_for_month.keys())]
    freq = list(map(lambda x: x.count(i), list(dict_for_month.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])

# %% [markdown]
# ## 2018.1.x Distribution

# %%
con_df = pd.DataFrame()

dict_for_month = {k: v for k, v in date_token_dict.items() if k > 20171231 and k < 20180201}

for i in words:
    date = [int(str(i)[6:8]) for i in list(dict_for_month.keys())]
    freq = list(map(lambda x: x.count(i), list(dict_for_month.values())))
    word = i
    
    con_df = pd.concat([con_df, pd.DataFrame({'date':date, 'freq':freq, 'word':word})], axis=0)

fig = plt.figure(figsize=(15,10))
ax1 = fig.add_subplot(1, 1, 1)
ax1 = sns.violinplot(x='word',y='date',data=con_df[con_df['freq'] != 0])
